# %%
from sklearn.cluster import KMeans
from sklearn import metrics
import numpy as np
import pandas as pd
import math
pd.set_option('display.max_colwidth', -1)

# %% [markdown]
# # Table Prediction

# %%
#path = 'C:/Users/D072202/Desktop/result_data2/predicatesembedder_2019_05_29_23_06_33_455527/stratified_embeddings.csv'
path = 'C:/Users/D072202/DeepAnyMatch/DeepAnyMatch/result_data/OAEI_short_walk_tsne_2019_06_06_18_08_42_874286/stratified_embeddings.csv'
df = pd.read_csv(path, encoding="UTF-8")
columns = [col for col in df.columns if col not in ['label','category','origin','Unnamed: 0']]
df.head()
# Out:
#    Unnamed: 0         x0         x1  \
# 0  0          -5.388889  -14.294527
# 1  1          -4.253796   3.581477
# 2  2           14.786997 -1.498006
# 3  3          -3.671815   0.678229
# 4  4          -1.695098  -0.801912
#
#                                                                           label  \
# 0  http://dbkwik.webdatacommons.org/darkscape/resource/iron_ceremonial_sword_iv
# 1  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 2  http://dbkwik.webdatacommons.org/darkscape/class/item
# 3  http://darkscape.wikia.com/wiki/special:filepath/avernic_wand.png?width=300
# 4  http://purl.org/dc/elements/1.1/rights
#
#                                                    category  origin
# 0  http://dbkwik.webdatacommons.org/darkscape/class/bonuses  graph1
# 1  none                                                      graph1
# 2  http://www.w3.org/2002/07/owl#class                       graph1
# 3  http://dbkwik.webdatacommons.org/ontology/image           graph1
# 4  none                                                      graph1

# %%
columns
# Out:
# ['x0', 'x1']

# %%
df = df.loc[~(df.category=='http://www.w3.org/2000/01/rdf-schema#property') & ~(df.category=='http://www.w3.org/2000/01/rdf-schema#class')]

# %%
df.loc[~(df.category=='none')].head()
# Out:
#    Unnamed: 0         x0         x1  \
# 0  0          -5.388889  -14.294527
# 2  2           14.786997 -1.498006
# 3  3          -3.671815   0.678229
# 6  6          -4.253311  -0.841286
# 8  8           1.573011   4.785627
#
#                                                                                         label  \
# 0  http://dbkwik.webdatacommons.org/darkscape/resource/iron_ceremonial_sword_iv
# 2  http://dbkwik.webdatacommons.org/darkscape/class/item
# 3  http://darkscape.wikia.com/wiki/special:filepath/avernic_wand.png?width=300
# 6  http://darkscape.wikia.com/wiki/special:filepath/eagles'_peak_lodestone_icon.png?width=300
# 8  http://darkscape.wikia.com/wiki/special:filepath/steel_key_crimson.png?width=300
#
#                                                    category  origin
# 0  http://dbkwik.webdatacommons.org/darkscape/class/bonuses  graph1
# 2  http://www.w3.org/2002/07/owl#class                       graph1
# 3  http://dbkwik.webdatacommons.org/ontology/image           graph1
# 6  http://dbkwik.webdatacommons.org/ontology/image           graph1
# 8  http://dbkwik.webdatacommons.org/ontology/image           graph1

# %%
#df = df.loc[df.category.isin(set(df.groupby(['category']).count().loc[:,'x0'].loc[df.groupby(['category']).count().loc[:,'x0']>1].index))]
df = df.loc[df.category.isin(df.groupby(['category']).count().index.values)]

# %%
clusters = pd.DataFrame([], columns=columns+['label','origin'])
for cat in set(df['category'].tolist()):
    tmp = df.loc[df.category==cat]
    origin = (df.loc[df.category==cat,'origin']).iloc[0]
    model = KMeans(n_clusters=1).fit(np.array(tmp[columns]))
    clusters = pd.concat([clusters, pd.DataFrame(np.concatenate( (np.array(model.cluster_centers_) , np.array([[cat, origin]]) ) , axis=1), columns=columns+['label','origin'])])
clusters
# Out:
#                      x0                   x1  \
# 0   14.020666279973119   -12.782096227553764
# 0   5.467786049999999    3.1032697999999996
# 0   12.93601667755102    -11.122051163265306
# 0   1.155904634933091    -17.193530040397434
# 0   15.065369            5.4860373
# 0   3.4310386166666667   -9.525825183333334
# 0   8.417725923076922    -8.644027653846154
# 0   11.025206383018867   -20.882772482783018
# 0   3.87146369205298     -10.903392741721854
# 0   12.055651346153846   -11.12240751923077
# 0   7.216765428571429    -9.085886357142858
# 0   10.337862708571429   -9.873693695238096
# 0   12.6703396875        -9.740675475
# 0   11.101401191304348   -9.74357567826087
# 0   4.091764915217391    -11.525769936956522
# 0   2.3615646485843373   -13.011679273493977
# 0   9.3092233            -5.9536923999999996
# 0   13.487079            -12.623222979166666
# 0   8.180518656410257    -13.027231802564103
# 0   8.443298366666667    -1.5697189333333326
# 0   13.667752045454545   -12.321269636363636
# 0   11.869413302007874   -16.182246173228346
# 0   12.382983852941177   -13.483965647058824
# 0   -5.546351611114461   -16.46928665150741
# 0   10.493620824413146   -11.721060599530517
# 0   4.267606133333333    -10.93927625
# 0   9.665025354166668    -8.784890958333333
# 0   10.2531081           -10.434035658333332
# 0   14.163066326879271   -3.9087541164160973
# 0   19.00875873049002    -11.807967609800363
# ..                ...                    ...
# 0   3.6854150000000003   -9.656811
# 0   -0.80646837          3.6379303999999997
# 0   7.633908326960258    -8.495173363802364
# 0   5.620518700000001    -18.373910000000002
# 0   6.998045420379147    -10.5931926507109
# 0   1.1020940999999997   -10.907323057142857
# 0   -3.1286476000000003  0.027897025
# 0   16.100846333333333   -2.8258688333333333
# 0   -2.4672923           4.289984
# 0   9.298260329669118    -12.663040912867647
# 0   0.9592535068739289   -18.453314976684606
# 0   2.191087475147929    -10.891595911242604
# 0   7.302149225          -5.0019877500000005
# 0   8.175055280108108    -13.794451282432432
# 0   -2.3687370588235295  -17.675049235294118
# 0   10.449314603571429   -12.047170069642856
# 0   0.2746471999999999   -13.093594777777778
# 0   12.700618333333333   -10.349131
# 0   7.024185644444445    -8.0081861
# 0   8.543752466666666    -2.9787744666666667
# 0   1.2546992921481284   -15.724610887700535
# 0   11.181795273164557   -21.10793137341772
# 0   9.259547048333333    -8.145918286519445
# 0   1.5029219162068963   -13.417741489655173
# 0   -4.2152646           -17.509648846153848
# 0   12.098629887837838   -10.410954504054054
# 0   4.3114431            -1.2459599999999997
# 0   19.1118325           -11.641048999999999
# 0   14.83335675          -9.123159391666666
# 0   13.248552322580645   -13.821530161290323
#
#                                                                             label  \
# 0   http://dbkwik.webdatacommons.org/darkscape/class/non-player_character
# 0   http://dbkwik.webdatacommons.org/oldschoolrunescape/class/event_other
# 0   http://dbkwik.webdatacommons.org/oldschoolrunescape/class/emote
# 0   http://dbkwik.webdatacommons.org/darkscape/class/item
# 0   http://dbkwik.webdatacommons.org/darkscape/class/skin
# 0   http://dbkwik.webdatacommons.org/oldschoolrunescape/class/prayer
# 0   http://dbkwik.webdatacommons.org/darkscape/class/poh_monster
# 0   http://dbkwik.webdatacommons.org/oldschoolrunescape/class/construction
# 0   http://dbkwik.webdatacommons.org/darkscape/class/familiar
# 0   http://dbkwik.webdatacommons.org/darkscape/class/island
# 0   http://dbkwik.webdatacommons.org/oldschoolrunescape/class/poh_monster
# 0   http://dbkwik.webdatacommons.org/darkscape/class/dungeon
# 0   http://dbkwik.webdatacommons.org/oldschoolrunescape/class/region
# 0   http://dbkwik.webdatacommons.org/oldschoolrunescape/class/mines
# 0   http://dbkwik.webdatacommons.org/oldschoolrunescape/class/hunter
# 0   http://dbkwik.webdatacommons.org/oldschoolrunescape/class/spell
# 0   http://dbkwik.webdatacommons.org/darkscape/class/emote
# 0   http://dbkwik.webdatacommons.org/oldschoolrunescape/class/npc
# 0   http://dbkwik.webdatacommons.org/oldschoolrunescape/class/pet
# 0   http://dbkwik.webdatacommons.org/oldschoolrunescape/class/game
# 0   http://dbkwik.webdatacommons.org/darkscape/class/npc
# 0   http://dbkwik.webdatacommons.org/oldschoolrunescape/class/shop
# 0   http://dbkwik.webdatacommons.org/oldschoolrunescape/class/bar
# 0   http://dbkwik.webdatacommons.org/darkscape/class/bonuses
# 0   http://dbkwik.webdatacommons.org/darkscape/class/quest
# 0   http://dbkwik.webdatacommons.org/darkscape/class/task_set
# 0   http://dbkwik.webdatacommons.org/oldschoolrunescape/class/skill
# 0   http://dbkwik.webdatacommons.org/darkscape/class/minigame
# 0   http://www.w3.org/2004/02/skos/core#concept
# 0   http://dbkwik.webdatacommons.org/oldschoolrunescape/class/music
# ..                                                              ...
# 0   http://dbkwik.webdatacommons.org/darkscape/class/monster_lite
# 0   http://dbkwik.webdatacommons.org/darkscape/class/episode
# 0   http://dbkwik.webdatacommons.org/darkscape/class/monster
# 0   http://dbkwik.webdatacommons.org/darkscape/class/bonuses_historical
# 0   http://dbkwik.webdatacommons.org/oldschoolrunescape/class/monster
# 0   http://dbkwik.webdatacommons.org/oldschoolrunescape/class/currency
# 0   http://dbkwik.webdatacommons.org/darkscape/class/location
# 0   http://dbkwik.webdatacommons.org/darkscape/class/threat_area
# 0   http://dbkwik.webdatacommons.org/oldschoolrunescape/class/general_item
# 0   http://dbkwik.webdatacommons.org/darkscape/class/interactive_scenery
# 0   http://dbkwik.webdatacommons.org/oldschoolrunescape/class/item
# 0   http://dbkwik.webdatacommons.org/darkscape/class/spell
# 0   http://dbkwik.webdatacommons.org/oldschoolrunescape/class/company
# 0   http://dbkwik.webdatacommons.org/oldschoolrunescape/class/interactive_scenery
# 0   http://dbkwik.webdatacommons.org/oldschoolrunescape/class/set
# 0   http://dbkwik.webdatacommons.org/oldschoolrunescape/class/quest
# 0   http://dbkwik.webdatacommons.org/oldschoolrunescape/class/fruit_tree
# 0   http://dbkwik.webdatacommons.org/darkscape/class/region
# 0   http://dbkwik.webdatacommons.org/darkscape/class/monster_new
# 0   http://dbkwik.webdatacommons.org/darkscape/class/
# 0   http://dbkwik.webdatacommons.org/darkscape/class/recipe
# 0   http://dbkwik.webdatacommons.org/darkscape/class/construction
# 0   http://dbkwik.webdatacommons.org/oldschoolrunescape/class/switch
# 0   http://dbkwik.webdatacommons.org/oldschoolrunescape/class/tree
# 0   http://dbkwik.webdatacommons.org/darkscape/class/set
# 0   http://dbkwik.webdatacommons.org/oldschoolrunescape/class/city
# 0   http://dbkwik.webdatacommons.org/darkscape/class/game
# 0   http://dbkwik.webdatacommons.org/darkscape/class/music
# 0   http://dbkwik.webdatacommons.org/oldschoolrunescape/class/deity
# 0   http://dbkwik.webdatacommons.org/darkscape/class/bar
#
#     origin
# 0   graph1
# 0   graph2
# 0   graph2
# 0   graph1
# 0   graph1
# 0   graph2
# 0   graph1
# 0   graph2
# 0   graph1
# 0   graph1
# 0   graph2
# 0   graph1
# 0   graph2
# 0   graph2
# 0   graph2
# 0   graph2
# 0   graph1
# 0   graph2
# 0   graph2
# 0   graph2
# 0   graph1
# 0   graph2
# 0   graph2
# 0   graph1
# 0   graph1
# 0   graph1
# 0   graph2
# 0   graph1
# 0   graph1
# 0   graph2
# ..     ...
# 0   graph1
# 0   graph1
# 0   graph1
# 0   graph1
# 0   graph2
# 0   graph2
# 0   graph1
# 0   graph1
# 0   graph2
# 0   graph1
# 0   graph2
# 0   graph1
# 0   graph2
# 0   graph2
# 0   graph2
# 0   graph2
# 0   graph2
# 0   graph1
# 0   graph1
# 0   graph1
# 0   graph1
# 0   graph1
# 0   graph2
# 0   graph2
# 0   graph1
# 0   graph2
# 0   graph1
# 0   graph1
# 0   graph2
# 0   graph1
#
# [107 rows x 4 columns]

# %%
clusters.loc[clusters.origin == 'graph1', 'cartesianproductkey1'] = 0
clusters.loc[clusters.origin == 'graph1', 'cartesianproductkey2'] = 1
clusters.loc[clusters.origin == 'graph2', 'cartesianproductkey1'] = 1
clusters.loc[clusters.origin == 'graph2', 'cartesianproductkey2'] = 0
clusters = clusters.loc[~ (clusters.label == 'none')]
clusters1 = pd.merge(clusters,clusters,left_on='cartesianproductkey1', right_on='cartesianproductkey2',how='inner')
clusters2 = pd.merge(clusters,clusters,left_on='cartesianproductkey2', right_on='cartesianproductkey1',how='inner')
clusters = pd.concat([clusters1, clusters2])
clusters = clusters.drop(['cartesianproductkey1_x'], axis=1)
clusters = clusters.drop(['cartesianproductkey2_x'], axis=1)
clusters = clusters.drop(['cartesianproductkey1_y'], axis=1)
clusters = clusters.drop(['cartesianproductkey2_y'], axis=1)
clusters.head()
# Out:
#                  x0_x                 x1_x  \
# 0  14.020666279973119  -12.782096227553764
# 1  14.020666279973119  -12.782096227553764
# 2  14.020666279973119  -12.782096227553764
# 3  14.020666279973119  -12.782096227553764
# 4  14.020666279973119  -12.782096227553764
#
#                                                                  label_x  \
# 0  http://dbkwik.webdatacommons.org/darkscape/class/non-player_character
# 1  http://dbkwik.webdatacommons.org/darkscape/class/non-player_character
# 2  http://dbkwik.webdatacommons.org/darkscape/class/non-player_character
# 3  http://dbkwik.webdatacommons.org/darkscape/class/non-player_character
# 4  http://dbkwik.webdatacommons.org/darkscape/class/non-player_character
#
#   origin_x                x0_y                 x1_y  \
# 0  graph1   5.467786049999999   3.1032697999999996
# 1  graph1   12.93601667755102   -11.122051163265306
# 2  graph1   3.4310386166666667  -9.525825183333334
# 3  graph1   11.025206383018867  -20.882772482783018
# 4  graph1   7.216765428571429   -9.085886357142858
#
#                                                                   label_y  \
# 0  http://dbkwik.webdatacommons.org/oldschoolrunescape/class/event_other
# 1  http://dbkwik.webdatacommons.org/oldschoolrunescape/class/emote
# 2  http://dbkwik.webdatacommons.org/oldschoolrunescape/class/prayer
# 3  http://dbkwik.webdatacommons.org/oldschoolrunescape/class/construction
# 4  http://dbkwik.webdatacommons.org/oldschoolrunescape/class/poh_monster
#
#   origin_y
# 0  graph2
# 1  graph2
# 2  graph2
# 3  graph2
# 4  graph2

# %%
#clusters['x0_x'] = clusters['x0_x'].astype('float64')
#clusters['x0_y'] = clusters['x0_y'].astype('float64')
#clusters['x1_x'] = clusters['x1_x'].astype('float64')
#clusters['x1_y'] = clusters['x1_y'].astype('float64')
for index, row in clusters.iterrows():
        x1 = row['x0_x']
        y1 = row['x1_x']
        x2 = row['x0_y']
        y2 = row['x1_y']
        dist = math.sqrt( (x2 - x1)**2 + (y2 - y1)**2 )
        clusters.loc[index, 'dist'] = dist
clusters = clusters.loc[clusters.dist>0.0]
clusters.head()
# Out:
#         x0_x       x1_x  \
# 0  14.020666 -12.782096
# 1  14.020666 -12.782096
# 2  14.020666 -12.782096
# 3  14.020666 -12.782096
# 4  14.020666 -12.782096
#
#                                                                  label_x  \
# 0  http://dbkwik.webdatacommons.org/darkscape/class/non-player_character
# 1  http://dbkwik.webdatacommons.org/darkscape/class/non-player_character
# 2  http://dbkwik.webdatacommons.org/darkscape/class/non-player_character
# 3  http://dbkwik.webdatacommons.org/darkscape/class/non-player_character
# 4  http://dbkwik.webdatacommons.org/darkscape/class/non-player_character
#
#   origin_x       x0_y       x1_y  \
# 0  graph1   5.467786   3.103270
# 1  graph1   12.936017 -11.122051
# 2  graph1   3.431039  -9.525825
# 3  graph1   11.025206 -20.882772
# 4  graph1   7.216765  -9.085886
#
#                                                                   label_y  \
# 0  http://dbkwik.webdatacommons.org/oldschoolrunescape/class/event_other
# 1  http://dbkwik.webdatacommons.org/oldschoolrunescape/class/emote
# 2  http://dbkwik.webdatacommons.org/oldschoolrunescape/class/prayer
# 3  http://dbkwik.webdatacommons.org/oldschoolrunescape/class/construction
# 4  http://dbkwik.webdatacommons.org/oldschoolrunescape/class/poh_monster
#
#   origin_y       dist
# 0  graph2   18.041525
# 1  graph2   1.982981
# 2  graph2   11.078967
# 3  graph2   8.636767
# 4  graph2   7.743064

# %%
print('Now matching ' + str(set(clusters['label_x'])))
# Out:
# Now matching {'http://dbkwik.webdatacommons.org/darkscape/class/non-player_character', 'http://dbkwik.webdatacommons.org/oldschoolrunescape/class/event_other', 'http://dbkwik.webdatacommons.org/oldschoolrunescape/class/emote', 'http://dbkwik.webdatacommons.org/darkscape/class/item', 'http://dbkwik.webdatacommons.org/oldschoolrunescape/class/prayer', 'http://dbkwik.webdatacommons.org/darkscape/class/poh_monster', 'http://dbkwik.webdatacommons.org/oldschoolrunescape/class/construction', 'http://dbkwik.webdatacommons.org/darkscape/class/familiar', 'http://dbkwik.webdatacommons.org/darkscape/class/island', 'http://dbkwik.webdatacommons.org/oldschoolrunescape/class/poh_monster', 'http://dbkwik.webdatacommons.org/darkscape/class/dungeon', 'http://dbkwik.webdatacommons.org/oldschoolrunescape/class/region', 'http://dbkwik.webdatacommons.org/oldschoolrunescape/class/mines', 'http://dbkwik.webdatacommons.org/oldschoolrunescape/class/hunter', 'http://dbkwik.webdatacommons.org/oldschoolrunescape/class/spell', 'http://dbkwik.webdatacommons.org/darkscape/class/emote', 'http://dbkwik.webdatacommons.org/oldschoolrunescape/class/npc', 'http://dbkwik.webdatacommons.org/oldschoolrunescape/class/pet', 'http://dbkwik.webdatacommons.org/oldschoolrunescape/class/game', 'http://dbkwik.webdatacommons.org/darkscape/class/npc', 'http://dbkwik.webdatacommons.org/oldschoolrunescape/class/shop', 'http://dbkwik.webdatacommons.org/oldschoolrunescape/class/bar', 'http://dbkwik.webdatacommons.org/darkscape/class/bonuses', 'http://dbkwik.webdatacommons.org/darkscape/class/quest', 'http://dbkwik.webdatacommons.org/darkscape/class/task_set', 'http://dbkwik.webdatacommons.org/oldschoolrunescape/class/skill', 'http://dbkwik.webdatacommons.org/darkscape/class/minigame', 'http://www.w3.org/2004/02/skos/core#concept', 'http://dbkwik.webdatacommons.org/oldschoolrunescape/class/music', 'http://dbkwik.webdatacommons.org/darkscape/class/interactive_scenery_multi', 'http://dbkwik.webdatacommons.org/oldschoolrunescape/class/achievement_diary', 'http://dbkwik.webdatacommons.org/darkscape/class/skill', 'http://www.w3.org/2002/07/owl#class', 'http://dbkwik.webdatacommons.org/darkscape/class/conquest', 'http://dbkwik.webdatacommons.org/oldschoolrunescape/class/battle', 'http://dbkwik.webdatacommons.org/darkscape/class/character', 'http://dbkwik.webdatacommons.org/darkscape/class/guild', 'http://dbkwik.webdatacommons.org/darkscape/class/wisp', 'http://dbkwik.webdatacommons.org/oldschoolrunescape/class/event', 'http://dbkwik.webdatacommons.org/oldschoolrunescape/class/bonuses', 'http://dbkwik.webdatacommons.org/darkscape/class/switch', 'http://dbkwik.webdatacommons.org/darkscape/class/pet', 'http://dbkwik.webdatacommons.org/darkscape/class/rock', 'http://dbkwik.webdatacommons.org/darkscape/class/fruit_tree', 'http://dbkwik.webdatacommons.org/darkscape/class/room', 'http://dbkwik.webdatacommons.org/ontology/image', 'http://dbkwik.webdatacommons.org/oldschoolrunescape/class/guild', 'http://dbkwik.webdatacommons.org/darkscape/class/deity', 'http://dbkwik.webdatacommons.org/darkscape/class/prayer', 'http://dbkwik.webdatacommons.org/darkscape/class/city', 'http://dbkwik.webdatacommons.org/oldschoolrunescape/class/island', 'http://dbkwik.webdatacommons.org/oldschoolrunescape/class/seed', 'http://dbkwik.webdatacommons.org/oldschoolrunescape/class/area', 'http://dbkwik.webdatacommons.org/darkscape/class/area', 'http://dbkwik.webdatacommons.org/darkscape/class/monster_multi', 'http://dbkwik.webdatacommons.org/darkscape/class/npc_multi', 'http://dbkwik.webdatacommons.org/oldschoolrunescape/class/recipe', 'http://dbkwik.webdatacommons.org/oldschoolrunescape/class/dungeon', 'http://dbkwik.webdatacommons.org/darkscape/class/miniquest', 'http://dbkwik.webdatacommons.org/darkscape/class/shop', 'http://dbkwik.webdatacommons.org/oldschoolrunescape/class/non-player_character', 'http://dbkwik.webdatacommons.org/darkscape/class/hunter', 'http://dbkwik.webdatacommons.org/darkscape/class/ability', 'ht ...

# %%
while len(clusters)>0:
    match = clusters.loc[clusters.dist == clusters['dist'].min()]
    clusters = clusters.drop(match.index, axis=0)
    for val in match.label_x.values:
        x = clusters.loc[(clusters.label_x == val) | (clusters.label_y == val)]
        clusters = clusters.drop(x.index, axis=0)
    print(str(match[:2].label_x.values)+"\n")
# Out:
# ['http://dbkwik.webdatacommons.org/darkscape/class/guild'
#  'http://dbkwik.webdatacommons.org/oldschoolrunescape/class/mines']
#
# ['http://dbkwik.webdatacommons.org/darkscape/class/music'
#  'http://dbkwik.webdatacommons.org/oldschoolrunescape/class/music']
#
# ['http://dbkwik.webdatacommons.org/darkscape/class/area'
#  'http://dbkwik.webdatacommons.org/oldschoolrunescape/class/city']
#
# ['http://dbkwik.webdatacommons.org/darkscape/class/tree'
#  'http://dbkwik.webdatacommons.org/oldschoolrunescape/class/tree']
#
# ['http://dbkwik.webdatacommons.org/darkscape/class/ability'
#  'http://dbkwik.webdatacommons.org/oldschoolrunescape/class/prayer']
#
# ['http://dbkwik.webdatacommons.org/darkscape/class/construction'
#  'http://dbkwik.webdatacommons.org/oldschoolrunescape/class/construction']
#
# ['http://dbkwik.webdatacommons.org/darkscape/class/quest'
#  'http://dbkwik.webdatacommons.org/oldschoolrunescape/class/quest']
#
# ['http://dbkwik.webdatacommons.org/darkscape/class/npc'
#  'http://dbkwik.webdatacommons.org/oldschoolrunescape/class/npc']
#
# ['http://dbkwik.webdatacommons.org/darkscape/class/dungeon'
#  'http://dbkwik.webdatacommons.org/oldschoolrunescape/class/guild']
#
# ['http://dbkwik.webdatacommons.org/darkscape/class/interactive_scenery_multi'
#  'http://dbkwik.webdatacommons.org/oldschoolrunescape/class/island']
#
# ['http://dbkwik.webdatacommons.org/darkscape/class/fruit_tree'
#  'http://dbkwik.webdatacommons.org/oldschoolrunescape/class/seed']
#
# ['http://dbkwik.webdatacommons.org/darkscape/class/non-player_character'
#  'http://dbkwik.webdatacommons.org/oldschoolrunescape/class/non-player_character']
#
# ['http://dbkwik.webdatacommons.org/darkscape/class/city'
#  'http://dbkwik.webdatacommons.org/oldschoolrunescape/class/emote']
#
# ['http://dbkwik.webdatacommons.org/darkscape/class/deity'
#  'http://dbkwik.webdatacommons.org/oldschoolrunescape/class/deity']
#
# ['http://dbkwik.webdatacommons.org/darkscape/class/pet'
#  'http://dbkwik.webdatacommons.org/oldschoolrunescape/class/skill']
#
# ['http://dbkwik.webdatacommons.org/darkscape/class/rock'
#  'http://dbkwik.webdatacommons.org/oldschoolrunescape/class/rock']
#
# ['http://dbkwik.webdatacommons.org/darkscape/class/region'
#  'http://dbkwik.webdatacommons.org/oldschoolrunescape/class/region']
#
# ['http://dbkwik.webdatacommons.org/darkscape/class/task_set'
#  'http://dbkwik.webdatacommons.org/oldschoolrunescape/class/hunter']
#
# ['http://dbkwik.webdatacommons.org/darkscape/class/hunter'
#  'http://dbkwik.webdatacommons.org/oldschoolrunescape/class/spell']
#
# ['http://dbkwik.webdatacommons.org/darkscape/class/monster'
#  'http://dbkwik.webdatacommons.org/oldschoolrunescape/class/poh_monster']
#
# ['http://dbkwik.webdatacommons.org/darkscape/class/shop'
#  'http://dbkwik.webdatacommons.org/oldschoolrunescape/class/shop']
#
# ['http://dbkwik.webdatacommons.org/darkscape/class/minigame'
#  'http://dbkwik.webdatacommons.org/oldschoolrunescape/class/dungeon']
#
# ['http://dbkwik.webdatacommons.org/darkscape/class/bar'
#  'http://dbkwik.webdatacommons.org/oldschoolrunescape/class/bar']
#
# ['http://dbkwik.webdatacommons.org/darkscape/class/poh_monster'
#  'http://dbkwik.webdatacommons.org/oldschoolrunescape/class/switch']
#
# ['http://dbkwik.webdatacommons.org/darkscape/class/item'
#  'http://dbkwik.webdatacommons.org/oldschoolrunescape/class/recipe']
#
# ['http://dbkwik.webdatacommons.org/darkscape/class/skill'
#  'http://dbkwik.webdatacommons.org/oldschoolrunescape/class/area']
#
# ['http://dbkwik.webdatacommons.org/darkscape/class/island'
#  'http://dbkwik.webdatacommons.org/oldschoolrunescape/class/event']
#
# ['http://dbkwik.webdatacommons.org/darkscape/class/spell'
#  'http://dbkwik.webdatacommons.org/oldschoolrunescape/class/currency']
#
# ['http://dbkwik.webdatacommons.org/darkscape/class/interactive_scenery'
#  'http://dbkwik.webdatacommons.org/oldschoolrunescape/class/pet']
#
# ['http://dbkwik.webdatacommons.org/darkscape/class/'
#  'http://dbkwik.webdatacommons.org/oldschoolrunescape/class/battle']
#
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#property'
#  'http://dbkwik.webdatacommons.org/oldschoolrunescape/class/company']
#
# ['http://dbkwik.webdatacommons.org/darkscape/class/set'
#  'http://dbkwik.webdatacommons.org/oldschoolrunescape/class/bonuses']
#
# ['http://dbkwik.webdatacommons.org/darkscape/class/conquest'
#  'http://dbkwik.webdatacommons.org/oldschoolrunescape/class/monster']
#
# ['http://dbkwik.webdatacommons.org/darkscape/class/prayer'
#  'http://dbkwik.webdatacommons.org/oldschoolrunescape/class/achievement_diary']
#
# ['http://dbkwik.webdatacommons.org/darkscape/class/farming'
#  'http://dbkwik.webdatacommons.org/oldschoolrunescape/class/fruit_tree']
#
# ['http://dbkwik.webdatacommons.org/darkscape/class/recipe'
#  'http://dbkwik.webdatacommons.org/oldschoolrunescape/class/item']
#
# ['http://dbkwik.webdatacommons.org/darkscape/class/character'
#  'http://dbkwik.webdatacommons.org/oldschoolrunescape/class/game']
#
# ['http://dbkwik.webdatacommons.org/darkscape/class/wisp'
#  'http://dbkwik.webdatacommons.org/oldschoolrunescape/class/interactive_scenery']
#
# ['http://dbkwik.webdatacommons.org/darkscape/class/bonuses'
#  'http://dbkwik.webdatacommons.org/oldschoolrunescape/class/set']
#
# ['http://dbkwik.webdatacommons.org/darkscape/class/game'
#  'http://dbkwik.webdatacommons.org/oldschoolrunescape/class/event_other']
#
# ['http://dbkwik.webdatacommons.org/darkscape/class/room'
#  'http://dbkwik.webdatacommons.org/oldschoolrunescape/class/monster_v1']

# %% [markdown]
# # Property Prediction

# %%
pd.options.display.max_colwidth = 500

# %%
#path = 'C:/Users/D072202/DeepAnyMatch/DeepAnyMatch/result_data/predicatesembedder_2019_05_30_12_49_02_518581/stratified_embeddings.csv'
#path = 'C:/Users/D072202/DeepAnyMatch/DeepAnyMatch/result_data/predicatesembedder_2019_05_30_20_32_59_972344/stratified_embeddings.csv'
path = 'C:/Users/D072202/DeepAnyMatch/DeepAnyMatch/result_data/OAEI_short_walk_tsne_2019_06_06_18_08_42_874286/stratified_embeddings.csv'

#path = 'C:/Users/D072202/Desktop/result_data2/hilti 2d alltriplessaved simpletriples_1_2019_05_27_14_03_20_890516/stratified_embeddings.csv'
df = pd.read_csv(path, encoding="UTF-8")
df.head()
# Out:
#    Unnamed: 0         x0         x1  \
# 0  0          -5.388889  -14.294527
# 1  1          -4.253796   3.581477
# 2  2           14.786997 -1.498006
# 3  3          -3.671815   0.678229
# 4  4          -1.695098  -0.801912
#
#                                                                           label  \
# 0  http://dbkwik.webdatacommons.org/darkscape/resource/iron_ceremonial_sword_iv
# 1  http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 2  http://dbkwik.webdatacommons.org/darkscape/class/item
# 3  http://darkscape.wikia.com/wiki/special:filepath/avernic_wand.png?width=300
# 4  http://purl.org/dc/elements/1.1/rights
#
#                                                    category  origin
# 0  http://dbkwik.webdatacommons.org/darkscape/class/bonuses  graph1
# 1  none                                                      graph1
# 2  http://www.w3.org/2002/07/owl#class                       graph1
# 3  http://dbkwik.webdatacommons.org/ontology/image           graph1
# 4  none                                                      graph1

# %%
d = df.loc[(df.category=='http://www.w3.org/2000/01/rdf-schema#property')]#.sample(n=100)
#d = d.loc[d.label.isin(['http://rdata2graph.sap.com/hilti_erp/property/mara_fert.maktx','http://rdata2graph.sap.com/hilti_web/property/products.name','http://rdata2graph.sap.com/hilti_erp/property/mara_fert.prdha','http://rdata2graph.sap.com/hilti_web/property/categories.name',])]

import matplotlib.pyplot as plt
plt.figure(figsize=(6,6))
for i, label in enumerate(set(d.label.tolist())):
        x, y = df.loc[df.label==label,'x'].values[0], df.loc[df.label==label,'y'].values[0]
        plt.scatter(x, y)
        plt.annotate(label, xy=(x, y), xytext=(5,3),
            textcoords='offset points', ha='right', va='bottom')
plt.show()

# %%
#d = df.loc[(df.category=='http://www.w3.org/2000/01/rdf-schema#property')].sample(n=200)
#d = d.loc[d.label.isin(['http://rdata2graph.sap.com/hilti_erp/property/mara_fert.maktx','http://rdata2graph.sap.com/hilti_web/property/products.name','http://rdata2graph.sap.com/hilti_erp/property/mara_fert.prdha','http://rdata2graph.sap.com/hilti_web/property/categories.name',])]

import matplotlib.pyplot as plt
plt.figure(figsize=(6,6))
for i, label in enumerate(set(d.label.tolist())):
        x, y = df.loc[df.label==label,'x'].values[0], df.loc[df.label==label,'y'].values[0]
        plt.scatter(x, y)
        plt.annotate(label, xy=(x, y), xytext=(5,3),
            textcoords='offset points', ha='right', va='bottom')
plt.show()

# %%
for index, row in df.loc[(df.category=='http://www.w3.org/2000/01/rdf-schema#property') & (df.origin=='graph1')].iterrows():
    if not 'maktx' in row['label'] and not 'prdha' in row['label']:
        continue
    tempdf = dict()
    x1 = row['x']
    y1 = row['y']
    for index2, row2 in df.loc[(df.category=='http://www.w3.org/2000/01/rdf-schema#property') & (df.origin=='graph2')].iterrows():
        x2 = row2['x']
        y2 = row2['y']
        dist = math.sqrt( (x2 - x1)**2 + (y2 - y1)**2 )
        tempdf[row2['label']] = dist
    mini = list(tempdf.keys())[0]
    for k,v in tempdf.items():
        print(k + "-> " + str(v))
        if v < tempdf[mini] and not k == row['label']:
            mini = k
    print(row['label'] + ", " + mini + ", " + str(tempdf[mini]))

# %%
import numpy as np

# %%
a = df.loc[(df.category=='http://www.w3.org/1999/02/22-rdf-syntax-ns#property') & (df.origin=='graph1')]
b = df.loc[(df.category=='http://www.w3.org/1999/02/22-rdf-syntax-ns#property') & (df.origin=='graph2')]
a.loc[:,'mergekey'] = 0
b.loc[:,'mergekey'] = 0
c = a.merge(b, left_on='mergekey',right_on='mergekey')
c['diff'] = ( (c.x0_x - c.x0_y).pow(2) + (c.x1_x - c.x1_y).pow(2) ).apply(np.sqrt)
c['diff'] = c['diff'].abs()
import sklearn
cos_sim = sklearn.metrics.pairwise.paired_cosine_distances(c[['x0_x','x1_x']], c[['x0_y','x1_x']])
c['cos_diff'] = pd.DataFrame(cos_sim)
c['cos_diff'] = c['cos_diff'].abs()

c.head()
# Out:
# C:\Users\D072202\AppData\Local\Continuum\anaconda3\envs\py36\lib\site-packages\pandas\core\indexing.py:362: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# C:\Users\D072202\AppData\Local\Continuum\anaconda3\envs\py36\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
#    Unnamed: 0_x       x0_x      x1_x  \
# 0  31            16.227043 -6.831844
# 1  31            16.227043 -6.831844
# 2  31            16.227043 -6.831844
# 3  31            16.227043 -6.831844
# 4  31            16.227043 -6.831844
#
#                                                         label_x  \
# 0  http://dbkwik.webdatacommons.org/darkscape/property/location
# 1  http://dbkwik.webdatacommons.org/darkscape/property/location
# 2  http://dbkwik.webdatacommons.org/darkscape/property/location
# 3  http://dbkwik.webdatacommons.org/darkscape/property/location
# 4  http://dbkwik.webdatacommons.org/darkscape/property/location
#
#                                             category_x origin_x  mergekey  \
# 0  http://www.w3.org/1999/02/22-rdf-syntax-ns#property  graph1   0
# 1  http://www.w3.org/1999/02/22-rdf-syntax-ns#property  graph1   0
# 2  http://www.w3.org/1999/02/22-rdf-syntax-ns#property  graph1   0
# 3  http://www.w3.org/1999/02/22-rdf-syntax-ns#property  graph1   0
# 4  http://www.w3.org/1999/02/22-rdf-syntax-ns#property  graph1   0
#
#    Unnamed: 0_y       x0_y       x1_y  \
# 0  75461         7.922579  -8.347506
# 1  75467        -1.189327  -10.694866
# 2  75473         13.628150 -15.749624
# 3  75545         14.597542 -11.072526
# 4  75553         16.482655 -6.620364
#
#                                                                     label_y  \
# 0  http://dbkwik.webdatacommons.org/oldschoolrunescape/property/alwaysdrops
# 1  http://dbkwik.webdatacommons.org/oldschoolrunescape/property/quest
# 2  http://dbkwik.webdatacommons.org/oldschoolrunescape/property/special
# 3  http://dbkwik.webdatacommons.org/oldschoolrunescape/property/race
# 4  http://dbkwik.webdatacommons.org/oldschoolrunescape/property/location
#
#                                             category_y origin_y       diff  \
# 0  http://www.w3.org/1999/02/22-rdf-syntax-ns#property  graph2   8.441644
# 1  http://www.w3.org/1999/02/22-rdf-syntax-ns#property  graph2   17.839644
# 2  http://www.w3.org/1999/02/22-rdf-syntax-ns#property  graph2   9.288759
# 3  http://www.w3.org/1999/02/22-rdf-syntax-ns#property  graph2   4.542979
# 4  http://www.w3.org/1999/02/22-rdf-syntax-ns#property  graph2   0.331755
#
#    cos_diff
# 0  0.048621
# 1  0.775790
# 2  0.002190
# 3  0.000770
# 4  0.000015

# %%
c=c.sort_values(by=['diff'])
c.head(10)
# Out:
#         Unnamed: 0_x       x0_x       x1_x  \
# 173207  62232        -0.893499  -10.717052
# 185528  64533         0.786994  -14.618589
# 180891  63559         19.040081  1.793831
# 6231    431           8.559848  -3.745431
# 274378  72923        -0.639465  -11.226589
# 256231  72090        -0.657223  -11.196630
# 247240  71582         0.838140  -14.687978
# 236708  70787        -0.839811  -10.724772
# 116500  48007         8.551665  -3.760371
# 156462  59213        -0.658029  -10.840188
#
#                                                                label_x  \
# 173207  http://dbkwik.webdatacommons.org/darkscape/property/combat
# 185528  http://dbkwik.webdatacommons.org/darkscape/property/yield
# 180891  http://dbkwik.webdatacommons.org/darkscape/property/former
# 6231    http://dbkwik.webdatacommons.org/darkscape/property/boots
# 274378  http://dbkwik.webdatacommons.org/darkscape/property/cookingexp
# 256231  http://dbkwik.webdatacommons.org/darkscape/property/servings
# 247240  http://dbkwik.webdatacommons.org/darkscape/property/produce
# 236708  http://dbkwik.webdatacommons.org/darkscape/property/aspeed
# 116500  http://dbkwik.webdatacommons.org/darkscape/property/type
# 156462  http://dbkwik.webdatacommons.org/darkscape/property/gold
#
#                                                  category_x origin_x  \
# 173207  http://www.w3.org/1999/02/22-rdf-syntax-ns#property  graph1
# 185528  http://www.w3.org/1999/02/22-rdf-syntax-ns#property  graph1
# 180891  http://www.w3.org/1999/02/22-rdf-syntax-ns#property  graph1
# 6231    http://www.w3.org/1999/02/22-rdf-syntax-ns#property  graph1
# 274378  http://www.w3.org/1999/02/22-rdf-syntax-ns#property  graph1
# 256231  http://www.w3.org/1999/02/22-rdf-syntax-ns#property  graph1
# 247240  http://www.w3.org/1999/02/22-rdf-syntax-ns#property  graph1
# 236708  http://www.w3.org/1999/02/22-rdf-syntax-ns#property  graph1
# 116500  http://www.w3.org/1999/02/22-rdf-syntax-ns#property  graph1
# 156462  http://www.w3.org/1999/02/22-rdf-syntax-ns#property  graph1
#
#         mergekey  Unnamed: 0_y       x0_y       x1_y  \
# 173207  0         119464       -0.893815  -10.721136
# 185528  0         123756        0.787407  -14.622917
# 180891  0         110133        19.035840  1.791051
# 6231    0         122132        8.554854  -3.747235
# 274378  0         107094       -0.633728  -11.228201
# 256231  0         83612        -0.654736  -11.202243
# 247240  0         120097        0.831162  -14.687001
# 236708  0         77127        -0.847039  -10.724924
# 116500  0         90938         8.551126  -3.752515
# 156462  0         96004        -0.655831  -10.847762
#
#                                                                           label_y  \
# 173207  http://dbkwik.webdatacommons.org/oldschoolrunescape/property/experience
# 185528  http://dbkwik.webdatacommons.org/oldschoolrunescape/property/checkhealth
# 180891  http://dbkwik.webdatacommons.org/oldschoolrunescape/property/clear
# 6231    http://dbkwik.webdatacommons.org/oldschoolrunescape/property/shieldimg
# 274378  http://dbkwik.webdatacommons.org/oldschoolrunescape/property/cookinglevel
# 256231  http://dbkwik.webdatacommons.org/oldschoolrunescape/property/servings
# 247240  http://dbkwik.webdatacommons.org/oldschoolrunescape/property/produce
# 236708  http://dbkwik.webdatacommons.org/oldschoolrunescape/property/materials
# 116500  http://dbkwik.webdatacommons.org/oldschoolrunescape/property/ringlink
# 156462  http://dbkwik.webdatacommons.org/oldschoolrunescape/property/level
#
#                                                  category_y origin_y  \
# 173207  http://www.w3.org/1999/02/22-rdf-syntax-ns#property  graph2
# 185528  http://www.w3.org/1999/02/22-rdf-syntax-ns#property  graph2
# 180891  http://www.w3.org/1999/02/22-rdf-syntax-ns#property  graph2
# 6231    http://www.w3.org/1999/02/22-rdf-syntax-ns#property  graph2
# 274378  http://www.w3.org/1999/02/22-rdf-syntax-ns#property  graph2
# 256231  http://www.w3.org/1999/02/22-rdf-syntax-ns#property  graph2
# 247240  http://www.w3.org/1999/02/22-rdf-syntax-ns#property  graph2
# 236708  http://www.w3.org/1999/02/22-rdf-syntax-ns#property  graph2
# 116500  http://www.w3.org/1999/02/22-rdf-syntax-ns#property  graph2
# 156462  http://www.w3.org/1999/02/22-rdf-syntax-ns#property  graph2
#
#             diff      cos_diff
# 173207  0.004096  4.287211e-10
# 185528  0.004348  3.975438e-10
# 180891  0.005071  2.164264e-10
# 6231    0.005310  2.297603e-08
# 274378  0.005959  1.297391e-07
# 256231  0.006139  2.448253e-08
# 247240  0.007046  1.121199e-07
# 236708  0.007230  2.243204e-07
# 116500  0.007875  2.697188e-10
# 156462  0.007886  2.039829e-08

# %%
props = list()
relation_props = list()
getprops('C:/Users/D072202/RData2Graph/rdata2graph/data/sap_hilti_data/MARA_FERT')
getprops('C:/Users/D072202/RData2Graph/rdata2graph/data/sap_hilti_data/V137')
getprops('C:/Users/D072202/RData2Graph/rdata2graph/data/sap_hilti_data/T006')
getprops('C:/Users/D072202/RData2Graph/rdata2graph/data/sap_hilti_data/T023')
getprops('C:/Users/D072202/RData2Graph/rdata2graph/data/sap_hilti_data/T179')

# %%
def getprops(path):
    with open(path, mode="r", encoding="UTF-8") as f:
        for line in f:
            line = line.split(",")
            for prop in line:
                try:
                    p = prop.split(";")[1]
                    if p=="":
                        p = prop.split(";")[0].split(".")[1]
                        props.append(p)
                    else:
                        props.append(p)
                        relation_props.append(p)
                except:
                    pass
            break

# %%
for i in range(len(props)):
    props[i] = "."+props[i]
props
# Out:
# ['.MBRSH',
#  '.MATKL',
#  '.PRDHA',
#  '.MAKTX',
#  '.id',
#  '.id',
#  '.Branchenbezeichnung',
#  '.MBr',
#  '.BBr',
#  '.FlRef',
#  '.MANDT',
#  '.id',
#  '.KZEX3',
#  '.KZEX6',
#  '.ANDEC',
#  '.KZKEH',
#  '.KZWOB',
#  '.KZ1EH',
#  '.KZ2EH',
#  '.DIMID',
#  '.ZAEHL',
#  '.NENNR',
#  '.EXP10',
#  '.ADDKO',
#  '.EXPON',
#  '.DECAN',
#  '.ISOCODE',
#  '.PRIMARY',
#  '.TEMP_VALUE',
#  '.TEMP_UNIT',
#  '.FAMUNIT',
#  '.PRESS_VAL',
#  '.PRESS_UNIT',
#  '.MSEH3',
#  '.MSEH6',
#  '.MSEHT',
#  '.MANDT',
#  '.id',
#  '.BEGRU',
#  '.GEWEI',
#  '.EKWSL',
#  '.ZZ_EKGRP',
#  '.ZZ_INACTIVE',
#  '.WGBEZ',
#  '.id',
#  '.Description',
#  '.levelno']

# %%
for i in range(len(relation_props)):
    relation_props[i] = "."+relation_props[i]
relation_props
# Out:
# ['.MBRSH', '.MATKL', '.PRDHA', '.id', '.id', '.id', '.id', '.id']

# %%
tmp = c
for index, row in tmp.iterrows():
    found_x = False
    found_y = False
    for p in props:
        if p.lower() == row.label_x.lower()[-len(p.lower()):]:
            found_x = True
    if found_x:
        pass
    else:
        c = c.loc[~(c.index==index)]
c.head(20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-51-a88b69d78f2c> in <module>
#       3     found_x = False
#       4     found_y = False
# ----> 5     for p in props:
#       6         if p.lower() == row.label_x.lower()[-len(p.lower()):]:
#       7             found_x = True
#
# NameError: name 'props' is not defined

# %%
tmp = c
for index, row in tmp.iterrows():
    found_x = False
    for p in relation_props:
        if p.lower() == row.label_x.lower()[-len(p.lower()):]:
            found_x = True
    if found_x:
        c = c.loc[~(c.index==index)]
c.head(20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-52-7095dbaad344> in <module>
#       2 for index, row in tmp.iterrows():
#       3     found_x = False
# ----> 4     for p in relation_props:
#       5         if p.lower() == row.label_x.lower()[-len(p.lower()):]:
#       6             found_x = True
#
# NameError: name 'relation_props' is not defined

# %%
while len(c)>0:
    lbl_x = c.iloc[0].label_x
    lbl_y = c.iloc[0].label_y
    c = c.loc[~(c.label_x==lbl_x) & ~(c.label_y==lbl_y)]
    print(lbl_x + ", " + lbl_y)
# Out:
# http://dbkwik.webdatacommons.org/darkscape/property/combat, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/experience
# http://dbkwik.webdatacommons.org/darkscape/property/yield, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/checkhealth
# http://dbkwik.webdatacommons.org/darkscape/property/former, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/clear
# http://dbkwik.webdatacommons.org/darkscape/property/boots, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/shieldimg
# http://dbkwik.webdatacommons.org/darkscape/property/cookingexp, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/cookinglevel
# http://dbkwik.webdatacommons.org/darkscape/property/servings, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/servings
# http://dbkwik.webdatacommons.org/darkscape/property/produce, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/produce
# http://dbkwik.webdatacommons.org/darkscape/property/aspeed, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/materials
# http://dbkwik.webdatacommons.org/darkscape/property/type, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/ringlink
# http://dbkwik.webdatacommons.org/darkscape/property/gold, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/level
# http://dbkwik.webdatacommons.org/darkscape/property/fishingexp, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/fishingexp
# http://dbkwik.webdatacommons.org/darkscape/property/effect, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/effect
# http://dbkwik.webdatacommons.org/darkscape/property/hiscores, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/altar
# http://dbkwik.webdatacommons.org/darkscape/property/person, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/publisher
# http://dbkwik.webdatacommons.org/darkscape/property/food, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/bank
# http://dbkwik.webdatacommons.org/darkscape/property/healthxp, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/harvestxp
# http://dbkwik.webdatacommons.org/darkscape/property/fishinglevel, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/cookingexp
# http://dbkwik.webdatacommons.org/darkscape/property/check, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/payment
# http://dbkwik.webdatacommons.org/darkscape/property/payment, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/harvest
# http://dbkwik.webdatacommons.org/darkscape/property/anim, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/element
# http://dbkwik.webdatacommons.org/darkscape/property/p2p, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/runecrafting
# http://dbkwik.webdatacommons.org/darkscape/property/damage, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/animresize
# http://dbkwik.webdatacommons.org/darkscape/property/lphealed, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/fishinglevel
# http://dbkwik.webdatacommons.org/darkscape/property/members, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/duration
# http://dbkwik.webdatacommons.org/darkscape/property/newsdate, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/task
# http://dbkwik.webdatacommons.org/darkscape/property/morvran, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/krystilia
# http://dbkwik.webdatacommons.org/darkscape/property/patch, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/patch
# http://dbkwik.webdatacommons.org/darkscape/property/legs, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/shieldlink
# http://dbkwik.webdatacommons.org/darkscape/property/spria, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/immunetopoison
# http://dbkwik.webdatacommons.org/darkscape/property/hint, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/location
# http://dbkwik.webdatacommons.org/darkscape/property/ingredients, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/ingredients
# http://dbkwik.webdatacommons.org/darkscape/property/tools, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/noburnlevel
# http://dbkwik.webdatacommons.org/darkscape/property/herblore, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/mining
# http://dbkwik.webdatacommons.org/darkscape/property/turael, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/slayexp
# http://dbkwik.webdatacommons.org/darkscape/property/hunter, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/strength
# http://dbkwik.webdatacommons.org/darkscape/property/row7info, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/products
# http://dbkwik.webdatacommons.org/darkscape/property/instructions, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/instructions
# http://dbkwik.webdatacommons.org/darkscape/property/version, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/s
# http://dbkwik.webdatacommons.org/darkscape/property/divination, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/lamp
# http://dbkwik.webdatacommons.org/darkscape/property/sof, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/cosmic
# http://dbkwik.webdatacommons.org/darkscape/property/attack, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/flatpack
# http://dbkwik.webdatacommons.org/darkscape/property/animresize, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/rune
# http://dbkwik.webdatacommons.org/darkscape/property/fishingmethod, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/fishingmethod
# http://dbkwik.webdatacommons.org/darkscape/property/fishingspot, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/fishingspot
# http://dbkwik.webdatacommons.org/darkscape/property/harvest, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/plant
# http://dbkwik.webdatacommons.org/darkscape/property/noteable, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/street
# http://dbkwik.webdatacommons.org/darkscape/property/firemaking, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/slayer
# http://dbkwik.webdatacommons.org/darkscape/property/chaos, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/body
# http://dbkwik.webdatacommons.org/darkscape/property/runecrafting, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/firemaking
# http://dbkwik.webdatacommons.org/darkscape/property/concept, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/wdifficulty
# http://dbkwik.webdatacommons.org/darkscape/property/farming, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/woodcutting
# http://dbkwik.webdatacommons.org/darkscape/property/lapalok, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/rarity
# http://dbkwik.webdatacommons.org/darkscape/property/thieving, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/fishing
# http://dbkwik.webdatacommons.org/darkscape/property/seedsper, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/check
# http://dbkwik.webdatacommons.org/darkscape/property/demonym, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/music
# http://dbkwik.webdatacommons.org/darkscape/property/ore, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/respawn
# http://dbkwik.webdatacommons.org/darkscape/property/tradable, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/euipable
# http://dbkwik.webdatacommons.org/darkscape/property/trap, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/trap
# http://dbkwik.webdatacommons.org/darkscape/property/sumona, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/mazchna
# http://dbkwik.webdatacommons.org/darkscape/property/affmelee, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/lp
# http://dbkwik.webdatacommons.org/darkscape/property/fletching, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/attack
# http://dbkwik.webdatacommons.org/darkscape/property/requirements, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/cacheid
# http://dbkwik.webdatacommons.org/darkscape/property/woodcutting, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/defence
# http://dbkwik.webdatacommons.org/darkscape/property/crafting, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/crafting
# http://dbkwik.webdatacommons.org/darkscape/property/smithing, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/cooking
# http://dbkwik.webdatacommons.org/darkscape/property/plant, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/time
# http://dbkwik.webdatacommons.org/darkscape/property/hotspot, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/hotspot
# http://dbkwik.webdatacommons.org/darkscape/property/agility, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/ranged
# http://dbkwik.webdatacommons.org/darkscape/property/seed, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/seed
# http://dbkwik.webdatacommons.org/darkscape/property/retaliate, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/retaliate
# http://dbkwik.webdatacommons.org/darkscape/property/helm, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/ringimg
# http://dbkwik.webdatacommons.org/darkscape/property/clevel, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/herblore
# http://dbkwik.webdatacommons.org/darkscape/property/dungeoneering, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/fletching
# http://dbkwik.webdatacommons.org/darkscape/property/stunimmune, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/quantitynotes
# http://dbkwik.webdatacommons.org/darkscape/property/spellbook, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/spellbook
# http://dbkwik.webdatacommons.org/darkscape/property/vannaka, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/immunevenom
# http://dbkwik.webdatacommons.org/darkscape/property/slayer, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/agility
# http://dbkwik.webdatacommons.org/darkscape/property/fishing, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/construction
# http://dbkwik.webdatacommons.org/darkscape/property/gloves, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/ammolink
# http://dbkwik.webdatacommons.org/darkscape/property/kuradal, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/vannaka
# http://dbkwik.webdatacommons.org/darkscape/property/constitution, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/smithing
# http://dbkwik.webdatacommons.org/darkscape/property/leaddesign, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/mat4img
# http://dbkwik.webdatacommons.org/darkscape/property/south, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/areas
# http://dbkwik.webdatacommons.org/darkscape/property/cooking, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/thieving
# http://dbkwik.webdatacommons.org/darkscape/property/questrequired, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/guild
# http://dbkwik.webdatacommons.org/darkscape/property/chaeldar, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/turael
# http://dbkwik.webdatacommons.org/darkscape/property/mining, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/farming
# http://dbkwik.webdatacommons.org/darkscape/property/duradel, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/immunepoison
# http://dbkwik.webdatacommons.org/darkscape/property/freeplay, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/dungeoneering
# http://dbkwik.webdatacommons.org/darkscape/property/buy, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/stock
# http://dbkwik.webdatacommons.org/darkscape/property/intcat, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/colours
# http://dbkwik.webdatacommons.org/darkscape/property/t, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/removalupdate
# http://dbkwik.webdatacommons.org/darkscape/property/summoning, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/hunter
# http://dbkwik.webdatacommons.org/darkscape/property/cookinglevel, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/skillxp
# http://dbkwik.webdatacommons.org/darkscape/property/number, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/qp
# http://dbkwik.webdatacommons.org/darkscape/property/body, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/weaplink
# http://dbkwik.webdatacommons.org/darkscape/property/street, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/heals
# http://dbkwik.webdatacommons.org/darkscape/property/element, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/anim
# http://dbkwik.webdatacommons.org/darkscape/property/harvestxp, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/plantxp
# http://dbkwik.webdatacommons.org/darkscape/property/north, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/east
# http://dbkwik.webdatacommons.org/darkscape/property/construction, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/magic
# http://dbkwik.webdatacommons.org/darkscape/property/rune1num, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/rune3num
# http://dbkwik.webdatacommons.org/darkscape/property/aggressive, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/cb
# http://dbkwik.webdatacommons.org/darkscape/property/weakness, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/weakness
# http://dbkwik.webdatacommons.org/darkscape/property/author, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/media
# http://dbkwik.webdatacommons.org/darkscape/property/modes, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/employee_23
# http://dbkwik.webdatacommons.org/darkscape/property/exp, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/rune2num
# http://dbkwik.webdatacommons.org/darkscape/property/mazchna, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/duradel
# http://dbkwik.webdatacommons.org/darkscape/property/cape, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/ammoimg
# http://dbkwik.webdatacommons.org/darkscape/property/accessdate, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/ikod
# http://dbkwik.webdatacommons.org/darkscape/property/lifepoints, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/buy
# http://dbkwik.webdatacommons.org/darkscape/property/sell, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/sell
# http://dbkwik.webdatacommons.org/darkscape/property/noburnlevel, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/lphealed
# http://dbkwik.webdatacommons.org/darkscape/property/range, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/mat1qty
# http://dbkwik.webdatacommons.org/darkscape/property/immunetostun, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/hitpoints
# http://dbkwik.webdatacommons.org/darkscape/property/quote, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/industry
# http://dbkwik.webdatacommons.org/darkscape/property/animal, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/member
# http://dbkwik.webdatacommons.org/darkscape/property/drinkssold, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/drinkssold
# http://dbkwik.webdatacommons.org/darkscape/property/width, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/c
# http://dbkwik.webdatacommons.org/darkscape/property/developer, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/developer
# http://dbkwik.webdatacommons.org/darkscape/property/url, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/diarykaramja
# http://dbkwik.webdatacommons.org/darkscape/property/stacks, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/mat3price
# http://dbkwik.webdatacommons.org/darkscape/property/rune2num, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/rune1num
# http://dbkwik.webdatacommons.org/darkscape/property/tele, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/tele
# http://dbkwik.webdatacommons.org/darkscape/property/row6info, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/founded
# http://dbkwik.webdatacommons.org/darkscape/property/poisonous, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/maxhit
# http://dbkwik.webdatacommons.org/darkscape/property/cost, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/earth
# http://dbkwik.webdatacommons.org/darkscape/property/soul, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/goal
# http://dbkwik.webdatacommons.org/darkscape/property/slaylvl, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/hp
# http://dbkwik.webdatacommons.org/darkscape/property/mdmg, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/noteable
# http://dbkwik.webdatacommons.org/darkscape/property/ring, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/necklink
# http://dbkwik.webdatacommons.org/darkscape/property/general, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/maxdropqty
# http://dbkwik.webdatacommons.org/darkscape/property/sgs, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/usesmelee
# http://dbkwik.webdatacommons.org/darkscape/property/immunetopoison, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/slayxp
# http://dbkwik.webdatacommons.org/darkscape/property/voice, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/composer
# http://dbkwik.webdatacommons.org/darkscape/property/earth, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/damage
# http://dbkwik.webdatacommons.org/darkscape/property/notes, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/notes
# http://dbkwik.webdatacommons.org/darkscape/property/gender, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/number
# http://dbkwik.webdatacommons.org/darkscape/property/loc, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/endupdate
# http://dbkwik.webdatacommons.org/darkscape/property/religion, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/adjective
# http://dbkwik.webdatacommons.org/darkscape/property/tertiary, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/nostaff
# http://dbkwik.webdatacommons.org/darkscape/property/lamp, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/soul
# http://dbkwik.webdatacommons.org/darkscape/property/inv, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/rstr
# http://dbkwik.webdatacommons.org/darkscape/property/descr, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/locations
# http://dbkwik.webdatacommons.org/darkscape/property/fight, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/place
# http://dbkwik.webdatacommons.org/darkscape/property/staff, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/staff
# http://dbkwik.webdatacommons.org/darkscape/property/max, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/exp
# http://dbkwik.webdatacommons.org/darkscape/property/row4info, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/version
# http://dbkwik.webdatacommons.org/darkscape/property/mainmusic, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/skill200m
# http://dbkwik.webdatacommons.org/darkscape/property/bait, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/bait
# http://dbkwik.webdatacommons.org/darkscape/property/logs, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/cutexp
# http://dbkwik.webdatacommons.org/darkscape/property/row5info, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/platforms
# http://dbkwik.webdatacommons.org/darkscape/property/loot, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/loot
# http://dbkwik.webdatacommons.org/darkscape/property/lp, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/mdmg
# http://dbkwik.webdatacommons.org/darkscape/property/hphealed, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/hphealed
# http://dbkwik.webdatacommons.org/darkscape/property/mat4price, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/mat1price
# http://dbkwik.webdatacommons.org/darkscape/property/2hweapon, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/ammonum
# http://dbkwik.webdatacommons.org/darkscape/property/neck, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/weapimg
# http://dbkwik.webdatacommons.org/darkscape/property/start, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/start
# http://dbkwik.webdatacommons.org/darkscape/property/bane, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/orb
# http://dbkwik.webdatacommons.org/darkscape/property/task, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/total
# http://dbkwik.webdatacommons.org/darkscape/property/achtryn, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/nieve
# http://dbkwik.webdatacommons.org/darkscape/property/untradetert, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/harvestexp
# http://dbkwik.webdatacommons.org/darkscape/property/orb, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/banana
# http://dbkwik.webdatacommons.org/darkscape/property/crop, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/yield
# http://dbkwik.webdatacommons.org/darkscape/property/growlvl, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/growlvl
# http://dbkwik.webdatacommons.org/darkscape/property/special, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/item
# http://dbkwik.webdatacommons.org/darkscape/property/slayxp, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/chaeldar
# http://dbkwik.webdatacommons.org/darkscape/property/kills, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/kills
# http://dbkwik.webdatacommons.org/darkscape/property/banks, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/altars
# http://dbkwik.webdatacommons.org/darkscape/property/attackspeed, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/combat
# http://dbkwik.webdatacommons.org/darkscape/property/publisher, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/month
# http://dbkwik.webdatacommons.org/darkscape/property/limit, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/day
# http://dbkwik.webdatacommons.org/darkscape/property/slayerxp, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/group
# http://dbkwik.webdatacommons.org/darkscape/property/west, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/north
# http://dbkwik.webdatacommons.org/darkscape/property/growexp, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/growexp
# http://dbkwik.webdatacommons.org/darkscape/property/genre, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/_3cspanstyle
# http://dbkwik.webdatacommons.org/darkscape/property/shield, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/neckimg
# http://dbkwik.webdatacommons.org/darkscape/property/usefor, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/limit
# http://dbkwik.webdatacommons.org/darkscape/property/defence, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/att
# http://dbkwik.webdatacommons.org/darkscape/property/mountains, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/kingdom
# http://dbkwik.webdatacommons.org/darkscape/property/gemw, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/aggressive
# http://dbkwik.webdatacommons.org/darkscape/property/movement, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/alwaysdrops
# http://dbkwik.webdatacommons.org/darkscape/property/update, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/year
# http://dbkwik.webdatacommons.org/darkscape/property/ashes, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/mat4qty
# http://dbkwik.webdatacommons.org/darkscape/property/pocket, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/gloveslink
# http://dbkwik.webdatacommons.org/darkscape/property/ostyle, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/quest
# http://dbkwik.webdatacommons.org/darkscape/property/room, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/room
# http://dbkwik.webdatacommons.org/darkscape/property/aka, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/animal
# http://dbkwik.webdatacommons.org/darkscape/property/namenotes, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/nw
# http://dbkwik.webdatacommons.org/darkscape/property/guilds, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/banks
# http://dbkwik.webdatacommons.org/darkscape/property/stores, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/stores
# http://dbkwik.webdatacommons.org/darkscape/property/removalupdate, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/teams
# http://dbkwik.webdatacommons.org/darkscape/property/raritynotes, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/wave
# http://dbkwik.webdatacommons.org/darkscape/property/day, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/rsw
# http://dbkwik.webdatacommons.org/darkscape/property/mat, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/mat2price
# http://dbkwik.webdatacommons.org/darkscape/property/experience, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/immune
# http://dbkwik.webdatacommons.org/darkscape/property/bg, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/format
# http://dbkwik.webdatacommons.org/darkscape/property/capital, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/taskmasters
# http://dbkwik.webdatacommons.org/darkscape/property/players, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/water
# http://dbkwik.webdatacommons.org/darkscape/property/degrades, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/def
# http://dbkwik.webdatacommons.org/darkscape/property/end, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/date
# http://dbkwik.webdatacommons.org/darkscape/property/quanity, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/mindropqty
# http://dbkwik.webdatacommons.org/darkscape/property/category, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/input
# http://dbkwik.webdatacommons.org/darkscape/property/id, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/fire
# http://dbkwik.webdatacommons.org/darkscape/property/lendable, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/mage
# http://dbkwik.webdatacommons.org/darkscape/property/maxhit, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/raritynotes
# http://dbkwik.webdatacommons.org/darkscape/property/techsupport, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/investors
# http://dbkwik.webdatacommons.org/darkscape/property/species, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/float
# http://dbkwik.webdatacommons.org/darkscape/property/weapon, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/capelink
# http://dbkwik.webdatacommons.org/darkscape/property/east, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/aka
# http://dbkwik.webdatacommons.org/darkscape/property/plural, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/sumona
# http://dbkwik.webdatacommons.org/darkscape/property/month, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/stocklabel
# http://dbkwik.webdatacommons.org/darkscape/property/map, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/se
# http://dbkwik.webdatacommons.org/darkscape/property/logsgemw, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/cutlvl
# http://dbkwik.webdatacommons.org/darkscape/property/time, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/mat2qty
# http://dbkwik.webdatacommons.org/darkscape/property/quantity, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/slaylvl
# http://dbkwik.webdatacommons.org/darkscape/property/mstyle, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/range
# http://dbkwik.webdatacommons.org/darkscape/property/areas, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/south
# http://dbkwik.webdatacommons.org/darkscape/property/space, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/logsgemw
# http://dbkwik.webdatacommons.org/darkscape/property/altars, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/air
# http://dbkwik.webdatacommons.org/darkscape/property/macc, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/attackspeed
# http://dbkwik.webdatacommons.org/darkscape/property/lectern, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/constitution
# http://dbkwik.webdatacommons.org/darkscape/property/obelisk, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/blood
# http://dbkwik.webdatacommons.org/darkscape/property/nr, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/slayercat
# http://dbkwik.webdatacommons.org/darkscape/property/ingredient, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/amount
# http://dbkwik.webdatacommons.org/darkscape/property/location, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/west
# http://dbkwik.webdatacommons.org/darkscape/property/clear, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/interval
# http://dbkwik.webdatacommons.org/darkscape/property/displayname, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/icon
# http://dbkwik.webdatacommons.org/darkscape/property/oacc, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/members
# http://dbkwik.webdatacommons.org/darkscape/property/magic, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/poisonous
# http://dbkwik.webdatacommons.org/darkscape/property/released, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/headquarters
# http://dbkwik.webdatacommons.org/darkscape/property/ranged, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/gemw
# http://dbkwik.webdatacommons.org/darkscape/property/input, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/extracss
# http://dbkwik.webdatacommons.org/darkscape/property/tier, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/attbns
# http://dbkwik.webdatacommons.org/darkscape/property/mat2img, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/gevalue
# http://dbkwik.webdatacommons.org/darkscape/property/qp, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/diff
# http://dbkwik.webdatacommons.org/darkscape/property/odmg, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/value
# http://dbkwik.webdatacommons.org/darkscape/property/format, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/sw
# http://dbkwik.webdatacommons.org/darkscape/property/quotesource, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/capital
# http://dbkwik.webdatacommons.org/darkscape/property/mainaccuracy, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/strbns
# http://dbkwik.webdatacommons.org/darkscape/property/offaccuracy, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/quantity
# http://dbkwik.webdatacommons.org/darkscape/property/tot, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/images
# http://dbkwik.webdatacommons.org/darkscape/property/alignment, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/alignment
# http://dbkwik.webdatacommons.org/darkscape/property/status, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/reward
# http://dbkwik.webdatacommons.org/darkscape/property/offdamage, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/rngbns
# http://dbkwik.webdatacommons.org/darkscape/property/recsize, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/slay
# http://dbkwik.webdatacommons.org/darkscape/property/questseries, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/cannon
# http://dbkwik.webdatacommons.org/darkscape/property/recolour, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/borderc
# http://dbkwik.webdatacommons.org/darkscape/property/extracss, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/caption
# http://dbkwik.webdatacommons.org/darkscape/property/environment, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/nr
# http://dbkwik.webdatacommons.org/darkscape/property/life, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/gender
# http://dbkwik.webdatacommons.org/darkscape/property/strength, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/shop
# http://dbkwik.webdatacommons.org/darkscape/property/flatpack, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/release
# http://dbkwik.webdatacommons.org/darkscape/property/prayer, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/dcrush
# http://dbkwik.webdatacommons.org/darkscape/property/maindamage, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/dstab
# http://dbkwik.webdatacommons.org/darkscape/property/armour, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/dslash
# http://dbkwik.webdatacommons.org/darkscape/property/alwaysdrops, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/drops
# http://dbkwik.webdatacommons.org/darkscape/property/stackable, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/str
# http://dbkwik.webdatacommons.org/darkscape/property/equipable, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/aspeed
# http://dbkwik.webdatacommons.org/darkscape/property/skillrequired, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/law
# http://dbkwik.webdatacommons.org/darkscape/property/tradeable, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/drange
# http://dbkwik.webdatacommons.org/darkscape/property/rows, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/dragon
# http://dbkwik.webdatacommons.org/darkscape/property/dif, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/steve
# http://dbkwik.webdatacommons.org/darkscape/property/book, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/drain
# http://dbkwik.webdatacommons.org/darkscape/property/obelisks, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/nature
# http://dbkwik.webdatacommons.org/darkscape/property/maintype, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/volatile
# http://dbkwik.webdatacommons.org/darkscape/property/slayercat, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/monster
# http://dbkwik.webdatacommons.org/darkscape/property/attackstyle, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/removal
# http://dbkwik.webdatacommons.org/darkscape/property/water, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/chaos
# http://dbkwik.webdatacommons.org/darkscape/property/speed, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/edible
# http://dbkwik.webdatacommons.org/darkscape/property/coords, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/coords
# http://dbkwik.webdatacommons.org/darkscape/property/store, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/high
# http://dbkwik.webdatacommons.org/darkscape/property/level, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/dmagic
# http://dbkwik.webdatacommons.org/darkscape/property/usexp, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/alchvalue
# http://dbkwik.webdatacommons.org/darkscape/property/edible, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/low
# http://dbkwik.webdatacommons.org/darkscape/property/aka_3f, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/adze
# http://dbkwik.webdatacommons.org/darkscape/property/_, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/barcolor
# http://dbkwik.webdatacommons.org/darkscape/property/growthtime, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/lectern
# http://dbkwik.webdatacommons.org/darkscape/property/fire, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/mind
# http://dbkwik.webdatacommons.org/darkscape/property/return, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/storevalue
# http://dbkwik.webdatacommons.org/darkscape/property/weight, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/acrush
# http://dbkwik.webdatacommons.org/darkscape/property/points, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/tools
# http://dbkwik.webdatacommons.org/darkscape/property/value, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/aslash
# http://dbkwik.webdatacommons.org/darkscape/property/recommendations, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/disadvantages
# http://dbkwik.webdatacommons.org/darkscape/property/exchange, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/store
# http://dbkwik.webdatacommons.org/darkscape/property/low, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/astab
# http://dbkwik.webdatacommons.org/darkscape/property/high, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/exchange
# http://dbkwik.webdatacommons.org/darkscape/property/quantitynotes, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/infofc
# http://dbkwik.webdatacommons.org/darkscape/property/price, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/rocks
# http://dbkwik.webdatacommons.org/darkscape/property/guild, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/death
# http://dbkwik.webdatacommons.org/darkscape/property/smuggler, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/arange
# http://dbkwik.webdatacommons.org/darkscape/property/require, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/update
# http://dbkwik.webdatacommons.org/darkscape/property/affweakness, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/style
# http://dbkwik.webdatacommons.org/darkscape/property/affranged, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/attackstyle
# http://dbkwik.webdatacommons.org/darkscape/property/advantages, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/other
# http://dbkwik.webdatacommons.org/darkscape/property/platforms, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/prize
# http://dbkwik.webdatacommons.org/darkscape/property/imagefile, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/multicb
# http://dbkwik.webdatacommons.org/darkscape/property/memory, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/immunetostun
# http://dbkwik.webdatacommons.org/darkscape/property/materials, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/amagic
# http://dbkwik.webdatacommons.org/darkscape/property/noinv, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/clean
# http://dbkwik.webdatacommons.org/darkscape/property/date, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/genre
# http://dbkwik.webdatacommons.org/darkscape/property/storevalue, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/weight
# http://dbkwik.webdatacommons.org/darkscape/property/gevalue, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/tradeable
# http://dbkwik.webdatacommons.org/darkscape/property/skills, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/emoteholiday
# http://dbkwik.webdatacommons.org/darkscape/property/mat3img, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/gemwname
# http://dbkwik.webdatacommons.org/darkscape/property/seller, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/recommendations
# http://dbkwik.webdatacommons.org/darkscape/property/alchvalue, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/stackable
# http://dbkwik.webdatacommons.org/darkscape/property/mat1price, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/equipable
# http://dbkwik.webdatacommons.org/darkscape/property/thaler, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/astral
# http://dbkwik.webdatacommons.org/darkscape/property/skillxp, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/prayer
# http://dbkwik.webdatacommons.org/darkscape/property/maxmelee, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/astyle
# http://dbkwik.webdatacommons.org/darkscape/property/items, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/runes
# http://dbkwik.webdatacommons.org/darkscape/property/ringimg, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/heraldic
# http://dbkwik.webdatacommons.org/darkscape/property/mat2price, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/lendable
# http://dbkwik.webdatacommons.org/darkscape/property/abilities, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/otherdrops
# http://dbkwik.webdatacommons.org/darkscape/property/duration, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/questmem
# http://dbkwik.webdatacommons.org/darkscape/property/spiria, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/infoc
# http://dbkwik.webdatacommons.org/darkscape/property/morchella, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/itemxp
# http://dbkwik.webdatacommons.org/darkscape/property/features, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/features
# http://dbkwik.webdatacommons.org/darkscape/property/style, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/slot
# http://dbkwik.webdatacommons.org/darkscape/property/year, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/discontinuation
# http://dbkwik.webdatacommons.org/darkscape/property/file, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/guildfree
# http://dbkwik.webdatacommons.org/darkscape/property/addwriting, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/xrate
# http://dbkwik.webdatacommons.org/darkscape/property/owner, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/alsoknownas
# http://dbkwik.webdatacommons.org/darkscape/property/pack, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/general
# http://dbkwik.webdatacommons.org/darkscape/property/questhelp, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/class
# http://dbkwik.webdatacommons.org/darkscape/property/other, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/note
# http://dbkwik.webdatacommons.org/darkscape/property/refnotes, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/p2p
# http://dbkwik.webdatacommons.org/darkscape/property/cooldown, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/image
# http://dbkwik.webdatacommons.org/darkscape/property/ammo, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/helmlink
# http://dbkwik.webdatacommons.org/darkscape/property/disguise, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/borders
# http://dbkwik.webdatacommons.org/darkscape/property/composer, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/guildmem
# http://dbkwik.webdatacommons.org/darkscape/property/sea, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/sea
# http://dbkwik.webdatacommons.org/darkscape/property/usepay, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/logs
# http://dbkwik.webdatacommons.org/darkscape/property/achievement, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/summoning
# http://dbkwik.webdatacommons.org/darkscape/property/skill, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/mat
# http://dbkwik.webdatacommons.org/darkscape/property/euipable, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/idc
# http://dbkwik.webdatacommons.org/darkscape/property/row8info, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/buylimit
# http://dbkwik.webdatacommons.org/darkscape/property/examinetext, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/warning
# http://dbkwik.webdatacommons.org/darkscape/property/cheathead, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/nemesis
# http://dbkwik.webdatacommons.org/darkscape/property/ikod, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/mat3qty
# http://dbkwik.webdatacommons.org/darkscape/property/dev, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/assigned
# http://dbkwik.webdatacommons.org/darkscape/property/npcs, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/mountains
# http://dbkwik.webdatacommons.org/darkscape/property/monster, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/cat
# http://dbkwik.webdatacommons.org/darkscape/property/mind, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/type
# http://dbkwik.webdatacommons.org/darkscape/property/multicb, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/alt
# http://dbkwik.webdatacommons.org/darkscape/property/nature, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/rune4num
# http://dbkwik.webdatacommons.org/darkscape/property/notot, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/dsummon
# http://dbkwik.webdatacommons.org/darkscape/property/neckimg, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/equip
# http://dbkwik.webdatacommons.org/darkscape/property/riddle, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/combatant
# http://dbkwik.webdatacommons.org/darkscape/property/rocks, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/monsters
# http://dbkwik.webdatacommons.org/darkscape/property/releasedate, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/engine
# http://dbkwik.webdatacommons.org/darkscape/property/blood, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/cost
# http://dbkwik.webdatacommons.org/darkscape/property/agressive, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/plantexp
# http://dbkwik.webdatacommons.org/darkscape/property/editorial, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/keypeople
# http://dbkwik.webdatacommons.org/darkscape/property/reward, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/minigame
# http://dbkwik.webdatacommons.org/darkscape/property/smallmap, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/mat2img
# http://dbkwik.webdatacommons.org/darkscape/property/row2info, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/victor
# http://dbkwik.webdatacommons.org/darkscape/property/adjective, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/miniquest
# http://dbkwik.webdatacommons.org/darkscape/property/gemwname, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/trimmed
# http://dbkwik.webdatacommons.org/darkscape/property/enhancer, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/have
# http://dbkwik.webdatacommons.org/darkscape/property/stun, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/text
# http://dbkwik.webdatacommons.org/darkscape/property/activity, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/white
# http://dbkwik.webdatacommons.org/darkscape/property/row3title, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/obelisks
# http://dbkwik.webdatacommons.org/darkscape/property/sound, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/label
# http://dbkwik.webdatacommons.org/darkscape/property/reclevel, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/vocals
# http://dbkwik.webdatacommons.org/darkscape/property/imagesize, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/xp
# http://dbkwik.webdatacommons.org/darkscape/property/desc, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/leader
# http://dbkwik.webdatacommons.org/darkscape/property/boltxp, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/id
# http://dbkwik.webdatacommons.org/darkscape/property/flavour, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/interface
# http://dbkwik.webdatacommons.org/darkscape/property/membersall, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/width
# http://dbkwik.webdatacommons.org/darkscape/property/currency, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/emoteunlock
# http://dbkwik.webdatacommons.org/darkscape/property/cutlvl, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/profit
# http://dbkwik.webdatacommons.org/darkscape/property/aura, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/symbol
# http://dbkwik.webdatacommons.org/darkscape/property/details, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/tradable
# http://dbkwik.webdatacommons.org/darkscape/property/examine, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/name
# http://dbkwik.webdatacommons.org/darkscape/property/cutexp, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/inputs
# http://dbkwik.webdatacommons.org/darkscape/property/mat7price, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/blessed
# http://dbkwik.webdatacommons.org/darkscape/property/c, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/quote
# http://dbkwik.webdatacommons.org/darkscape/property/monsters, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/length
# http://dbkwik.webdatacommons.org/darkscape/property/jadinko, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/outputs
# http://dbkwik.webdatacommons.org/darkscape/property/flower, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/recurrencetime
# http://dbkwik.webdatacommons.org/darkscape/property/off, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/primary
# http://dbkwik.webdatacommons.org/darkscape/property/name, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/examine
# http://dbkwik.webdatacommons.org/darkscape/property/editing, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/player
# http://dbkwik.webdatacommons.org/darkscape/property/tree, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/activitytime
# http://dbkwik.webdatacommons.org/darkscape/property/herb, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/otherbenefits
# http://dbkwik.webdatacommons.org/darkscape/property/leadartist, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/grimy
# http://dbkwik.webdatacommons.org/darkscape/property/weap, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/inv
# http://dbkwik.webdatacommons.org/darkscape/property/recommended, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/fight
# http://dbkwik.webdatacommons.org/darkscape/property/custodian, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/religion
# http://dbkwik.webdatacommons.org/darkscape/property/death, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/kept
# http://dbkwik.webdatacommons.org/darkscape/property/puzzle, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/outcome
# http://dbkwik.webdatacommons.org/darkscape/property/info, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/currency
# http://dbkwik.webdatacommons.org/darkscape/property/harvestheaven, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/skill
# http://dbkwik.webdatacommons.org/darkscape/property/characters, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/hostchannel
# http://dbkwik.webdatacommons.org/darkscape/property/alchable, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/infos
# http://dbkwik.webdatacommons.org/darkscape/property/swap, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/farmlvl
# http://dbkwik.webdatacommons.org/darkscape/property/glovesimg, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/absorbmagic
# http://dbkwik.webdatacommons.org/darkscape/property/ability, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/clevel
# http://dbkwik.webdatacommons.org/darkscape/property/ammoimg, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/absorbranged
# http://dbkwik.webdatacommons.org/darkscape/property/berry, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/category
# http://dbkwik.webdatacommons.org/darkscape/property/weapimg, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/absorbmelee
# http://dbkwik.webdatacommons.org/darkscape/property/colour, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/animeresize
# http://dbkwik.webdatacommons.org/darkscape/property/secdev, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/modes
# http://dbkwik.webdatacommons.org/darkscape/property/immunetoreflect, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/convert
# http://dbkwik.webdatacommons.org/darkscape/property/profit, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/ammunition
# http://dbkwik.webdatacommons.org/darkscape/property/capeimg, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/praye
# http://dbkwik.webdatacommons.org/darkscape/property/plantxp, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/details
# http://dbkwik.webdatacommons.org/darkscape/property/chathead, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/alchable
# http://dbkwik.webdatacommons.org/darkscape/property/image, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/capeimg
# http://dbkwik.webdatacommons.org/darkscape/property/orange, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/activity
# http://dbkwik.webdatacommons.org/darkscape/property/destroy, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/destroy
# http://dbkwik.webdatacommons.org/darkscape/property/coretest, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/w
# http://dbkwik.webdatacommons.org/darkscape/property/animation, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/commander
# http://dbkwik.webdatacommons.org/darkscape/property/caption, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/bootslink
# http://dbkwik.webdatacommons.org/darkscape/property/adrenaline, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/advantages
# http://dbkwik.webdatacommons.org/darkscape/property/row3info, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/edit
# http://dbkwik.webdatacommons.org/darkscape/property/row8title, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/questcape
# http://dbkwik.webdatacommons.org/darkscape/property/qa, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/guildall
# http://dbkwik.webdatacommons.org/darkscape/property/releasetest, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/champ
# http://dbkwik.webdatacommons.org/darkscape/property/assdev, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/questfree
# http://dbkwik.webdatacommons.org/darkscape/property/audio, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/data
# http://dbkwik.webdatacommons.org/darkscape/property/shieldimg, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/price
# http://dbkwik.webdatacommons.org/darkscape/property/walkthrough, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/champall
# http://dbkwik.webdatacommons.org/darkscape/property/difficulty, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/released
# http://dbkwik.webdatacommons.org/darkscape/property/bodyimg, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/clay
# http://dbkwik.webdatacommons.org/darkscape/property/catpion, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/helmimg
# http://dbkwik.webdatacommons.org/darkscape/property/row2title, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/units
# http://dbkwik.webdatacommons.org/darkscape/property/title, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/require
# http://dbkwik.webdatacommons.org/darkscape/property/energy, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/disassembly
# http://dbkwik.webdatacommons.org/darkscape/property/row7title, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/musicall
# http://dbkwik.webdatacommons.org/darkscape/property/graphics, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/info
# http://dbkwik.webdatacommons.org/darkscape/property/length, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/preceded
# http://dbkwik.webdatacommons.org/darkscape/property/total, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/bootsimg
# http://dbkwik.webdatacommons.org/darkscape/property/filename, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/end
# http://dbkwik.webdatacommons.org/darkscape/property/align, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/succeeded
# http://dbkwik.webdatacommons.org/darkscape/property/rangedcrit, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/glovesimg
# http://dbkwik.webdatacommons.org/darkscape/property/f2p, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/bodyimg
# http://dbkwik.webdatacommons.org/darkscape/property/meleecrit, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/legsimg
# http://dbkwik.webdatacommons.org/darkscape/property/writing, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/page
# http://dbkwik.webdatacommons.org/darkscape/property/magiccrit, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/legslink
# http://dbkwik.webdatacommons.org/darkscape/property/review, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/desc
# http://dbkwik.webdatacommons.org/darkscape/property/item, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/skillrequired
# http://dbkwik.webdatacommons.org/darkscape/property/alt, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/req
# http://dbkwik.webdatacommons.org/darkscape/property/symbol, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/filename
# http://dbkwik.webdatacommons.org/darkscape/property/text, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/questrequired
# http://dbkwik.webdatacommons.org/darkscape/property/hitpoints, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/bodylink
# http://dbkwik.webdatacommons.org/darkscape/property/set, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/speed
# http://dbkwik.webdatacommons.org/darkscape/property/series, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/align
# http://dbkwik.webdatacommons.org/darkscape/property/alsoknownas, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/obelisk
# http://dbkwik.webdatacommons.org/darkscape/property/row6title, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/clue
# http://dbkwik.webdatacommons.org/darkscape/property/ge, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/secondary
# http://dbkwik.webdatacommons.org/darkscape/property/link, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/race
# http://dbkwik.webdatacommons.org/darkscape/property/row4title, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/demonym
# http://dbkwik.webdatacommons.org/darkscape/property/assignedby, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/food
# http://dbkwik.webdatacommons.org/darkscape/property/inventory, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/species
# http://dbkwik.webdatacommons.org/darkscape/property/key, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/rsc
# http://dbkwik.webdatacommons.org/darkscape/property/cannon, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/emote
# http://dbkwik.webdatacommons.org/darkscape/property/size, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/mat1img
# http://dbkwik.webdatacommons.org/darkscape/property/row5title, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/rs
# http://dbkwik.webdatacommons.org/darkscape/property/colours, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/quests
# http://dbkwik.webdatacommons.org/darkscape/property/description, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/difficulty
# http://dbkwik.webdatacommons.org/darkscape/property/arange, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/twohanded
# http://dbkwik.webdatacommons.org/darkscape/property/alchemy, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/mat3img
# http://dbkwik.webdatacommons.org/darkscape/property/ascension, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/description
# http://dbkwik.webdatacommons.org/darkscape/property/mat1img, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/sound
# http://dbkwik.webdatacommons.org/darkscape/property/disadvantages, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/enhancer
# http://dbkwik.webdatacommons.org/darkscape/property/otherdrops, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/series
# http://dbkwik.webdatacommons.org/darkscape/property/health, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/items
# http://dbkwik.webdatacommons.org/darkscape/property/music, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/inventory
# http://dbkwik.webdatacommons.org/darkscape/property/age, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/title
# http://dbkwik.webdatacommons.org/darkscape/property/leader, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/hint
# http://dbkwik.webdatacommons.org/darkscape/property/kingdom, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/guilds
# http://dbkwik.webdatacommons.org/darkscape/property/enriched, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/recommended
# http://dbkwik.webdatacommons.org/darkscape/property/icon, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/file
# http://dbkwik.webdatacommons.org/darkscape/property/imagebackground, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/rewards
# http://dbkwik.webdatacommons.org/darkscape/property/float, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/instruments
# http://dbkwik.webdatacommons.org/darkscape/property/hotspotimage, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/owner
# http://dbkwik.webdatacommons.org/darkscape/property/immunetodeflect, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/requirements
# http://dbkwik.webdatacommons.org/darkscape/property/ccost, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/special
# http://dbkwik.webdatacommons.org/darkscape/property/doors, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/seller
# http://dbkwik.webdatacommons.org/darkscape/property/hotspots, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/displayname
# http://dbkwik.webdatacommons.org/darkscape/property/quests, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/npcs
# http://dbkwik.webdatacommons.org/darkscape/property/baseexp, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/magicdamage
# http://dbkwik.webdatacommons.org/darkscape/property/amagic, http://dbkwik.webdatacommons.org/oldschoolrunescape/property/rangestr

# %% [markdown]
# ## Property matching by average

# %%
#path = 'C:/Users/D072202/DeepAnyMatch/DeepAnyMatch/result_data/predicatesembedder_2019_05_30_12_49_02_518581/stratified_embeddings.csv'
#path = 'C:/Users/D072202/DeepAnyMatch/DeepAnyMatch/result_data/predicatesembedder_2019_05_30_20_32_59_972344/stratified_embeddings.csv'
path = 'C:/Users/D072202/DeepAnyMatch/DeepAnyMatch/result_data/predicatesembedder_2019_05_31_13_25_45_684831/predicate_embeddings.csv'

#path = 'C:/Users/D072202/Desktop/result_data2/hilti 2d alltriplessaved simpletriples_1_2019_05_27_14_03_20_890516/stratified_embeddings.csv'
df = pd.read_csv(path, encoding="UTF-8")
df.head()
# Out:
#    Unnamed: 0         x         y  \
# 0           0  1.583728 -1.759576
# 1           1  0.608689 -0.824827
# 2           2  0.579716 -0.814725
# 3           3  1.469065 -1.333530
# 4           4  0.617569 -0.866903
#
#                                                             label  \
# 0  http://rdata2graph.sap.com/hilti_erp/property/mara_fert.maktx0
# 1          http://rdata2graph.sap.com/hilti_erp/property/v137.id1
# 2          http://rdata2graph.sap.com/hilti_erp/property/t023.id2
# 3          http://rdata2graph.sap.com/hilti_erp/property/t179.id3
# 4                http://www.w3.org/1999/02/22-rdf-syntax-ns#type4
#
#                                                   original_label  origin
# 0  http://rdata2graph.sap.com/hilti_erp/property/mara_fert.maktx  graph1
# 1          http://rdata2graph.sap.com/hilti_erp/property/v137.id  graph1
# 2          http://rdata2graph.sap.com/hilti_erp/property/t023.id  graph1
# 3          http://rdata2graph.sap.com/hilti_erp/property/t179.id  graph1
# 4                http://www.w3.org/1999/02/22-rdf-syntax-ns#type  graph1

# %%
clusters = pd.DataFrame([], columns=['x','y','label','origin'])
for original_label in set(df['original_label'].tolist()):
    tmp = df.loc[df.original_label==original_label]
    origin = (df.loc[df.original_label==original_label,'origin']).iloc[0]
    model = KMeans(n_clusters=1).fit(np.array(tmp[['x','y']]))
    clusters = pd.concat([clusters, pd.DataFrame(np.concatenate( (np.array(model.cluster_centers_) , np.array([[original_label, origin]]) ) , axis=1), columns=['x','y','label','origin'])])
clusters
# Out:
#                        x                    y  \
# 0    -1.5742232902472617  -2.0840017424394186
# 0     0.2636454224543861  -2.3822720499409447
# 0   0.008407227973534622  -1.3295423509658937
# 0  -0.025851954679402493  -1.3022899050982704
# 0   -0.05049706433333332  -0.8105403766666667
# 0    -0.5137308975086486  -1.3231408395405406
# 0   0.043115388122302235   -3.062463104556355
# 0    0.05199309379064747  -2.3042384270983214
# 0     0.4894172428603744  -2.1389125085829384
# 0     0.0944975744139151  -1.3209951341981132
# 0    0.19500188211660296   -1.978497102110849
# 0   -0.05226292904999998  -0.7927633016666666
# 0     -1.004074732440743  -1.6171385587641356
# 0     -1.150542740379483  -1.4316374454684975
# 0    0.17759593220539166   -1.247300135289124
# 0    -1.1776581596704363  -1.3253474923828756
# 0    -1.4173679793336027  -1.4500648296930534
# 0     0.4442275019362275  -1.7549849080616113
# 0    -0.9922530315218093  -1.2319228331340872
# 0         -0.76586309375  -1.0654498216666666
# 0    -0.9955917346012115  -1.2354023804038772
# 0    0.25764978395335547  -1.1355437338246446
# 0    0.06304374976108885  -1.2445896911281447
# 0    -1.2376605732334411  -1.3805998988691437
# 0   -0.06239124149999999          -0.80930567
# 0     0.3156580383928492  -1.5771025789592403
# 0   -0.04247094166666667  -0.8088547433333333
# 0    -0.5323613566666667  -0.8485598761111112
#
#                                                                     label  \
# 0                http://rdata2graph.sap.com/hilti_erp/property/t023.wgbez
# 0          http://rdata2graph.sap.com/hilti_erp/property/t179.description
# 0                         http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 0                   http://rdata2graph.sap.com/hilti_erp/property/t023.id
# 0                  http://rdata2graph.sap.com/hilti_erp/property/v137.mbr
# 0                            http://www.w3.org/2000/01/rdf-schema#comment
# 0    http://rdata2graph.sap.com/hilti_web/property/categories.description
# 0           http://rdata2graph.sap.com/hilti_web/property/categories.name
# 0      http://rdata2graph.sap.com/hilti_web/property/products.description
# 0                   http://rdata2graph.sap.com/hilti_erp/property/t179.id
# 0           http://rdata2graph.sap.com/hilti_erp/property/mara_fert.maktx
# 0  http://rdata2graph.sap.com/hilti_erp/property/v137.branchenbezeichnung
# 0              http://rdata2graph.sap.com/hilti_erp/property/t023.wgbez60
# 0                http://rdata2graph.sap.com/hilti_erp/property/t023.mandt
# 0              http://rdata2graph.sap.com/hilti_erp/property/t179.levelno
# 0             http://rdata2graph.sap.com/hilti_erp/property/t023.zz_ekgrp
# 0                http://rdata2graph.sap.com/hilti_erp/property/t023.begru
# 0             http://rdata2graph.sap.com/hilti_web/property/products.name
# 0                http://rdata2graph.sap.com/hilti_erp/property/t023.gewei
# 0                             http://www.w3.org/2000/01/rdf-schema#domain
# 0          http://rdata2graph.sap.com/hilti_erp/property/t023.zz_inactive
# 0              http://rdata2graph.sap.com/hilti_web/property/products.pid
# 0                   http://rdata2graph.sap.com/hilti_erp/property/v137.id
# 0                http://rdata2graph.sap.com/hilti_erp/property/t023.ekwsl
# 0                  http://rdata2graph.sap.com/hilti_erp/property/v137.bbr
# 0             http://rdata2graph.sap.com/hilti_web/property/categories.id
# 0                http://rdata2graph.sap.com/hilti_erp/property/v137.flref
# 0                              http://www.w3.org/2000/01/rdf-schema#label
#
#    origin
# 0  graph1
# 0  graph1
# 0  graph1
# 0  graph1
# 0  graph1
# 0  graph1
# 0  graph2
# 0  graph2
# 0  graph2
# 0  graph1
# 0  graph1
# 0  graph1
# 0  graph1
# 0  graph1
# 0  graph1
# 0  graph1
# 0  graph1
# 0  graph2
# 0  graph1
# 0  graph1
# 0  graph1
# 0  graph2
# 0  graph1
# 0  graph1
# 0  graph1
# 0  graph2
# 0  graph1
# 0  graph1

# %%
clusters.loc[clusters.origin == 'graph1', 'cartesianproductkey1'] = 0
clusters.loc[clusters.origin == 'graph1', 'cartesianproductkey2'] = 1
clusters.loc[clusters.origin == 'graph2', 'cartesianproductkey1'] = 1
clusters.loc[clusters.origin == 'graph2', 'cartesianproductkey2'] = 0
clusters = clusters.loc[~ (clusters.label == 'none')]
clusters1 = pd.merge(clusters,clusters,left_on='cartesianproductkey1', right_on='cartesianproductkey2',how='inner')
clusters2 = pd.merge(clusters,clusters,left_on='cartesianproductkey2', right_on='cartesianproductkey1',how='inner')
clusters = pd.concat([clusters1, clusters2])
clusters = clusters.drop(['cartesianproductkey1_x'], axis=1)
clusters = clusters.drop(['cartesianproductkey2_x'], axis=1)
clusters = clusters.drop(['cartesianproductkey1_y'], axis=1)
clusters = clusters.drop(['cartesianproductkey2_y'], axis=1)
clusters.head()
# Out:
#                    x_x                  y_x  \
# 0  -1.5742232902472617  -2.0840017424394186
# 1  -1.5742232902472617  -2.0840017424394186
# 2  -1.5742232902472617  -2.0840017424394186
# 3  -1.5742232902472617  -2.0840017424394186
# 4  -1.5742232902472617  -2.0840017424394186
#
#                                                     label_x origin_x  \
# 0  http://rdata2graph.sap.com/hilti_erp/property/t023.wgbez   graph1
# 1  http://rdata2graph.sap.com/hilti_erp/property/t023.wgbez   graph1
# 2  http://rdata2graph.sap.com/hilti_erp/property/t023.wgbez   graph1
# 3  http://rdata2graph.sap.com/hilti_erp/property/t023.wgbez   graph1
# 4  http://rdata2graph.sap.com/hilti_erp/property/t023.wgbez   graph1
#
#                     x_y                  y_y  \
# 0  0.043115388122302235   -3.062463104556355
# 1   0.05199309379064747  -2.3042384270983214
# 2    0.4894172428603744  -2.1389125085829384
# 3    0.4442275019362275  -1.7549849080616113
# 4   0.25764978395335547  -1.1355437338246446
#
#                                                                 label_y  \
# 0  http://rdata2graph.sap.com/hilti_web/property/categories.description
# 1         http://rdata2graph.sap.com/hilti_web/property/categories.name
# 2    http://rdata2graph.sap.com/hilti_web/property/products.description
# 3           http://rdata2graph.sap.com/hilti_web/property/products.name
# 4            http://rdata2graph.sap.com/hilti_web/property/products.pid
#
#   origin_y
# 0   graph2
# 1   graph2
# 2   graph2
# 3   graph2
# 4   graph2

# %%
clusters['x_x'] = clusters['x_x'].astype('float64')
clusters['x_y'] = clusters['x_y'].astype('float64')
clusters['y_x'] = clusters['y_x'].astype('float64')
clusters['y_y'] = clusters['y_y'].astype('float64')
for index, row in clusters.iterrows():
        x1 = row['x_x']
        y1 = row['y_x']
        x2 = row['x_y']
        y2 = row['y_y']
        dist = math.sqrt( (x2 - x1)**2 + (y2 - y1)**2 )
        clusters.loc[index, 'dist'] = dist
clusters = clusters.loc[clusters.dist>0.0]
clusters.head()
# Out:
#         x_x       y_x  \
# 0 -1.574223 -2.084002
# 1 -1.574223 -2.084002
# 2 -1.574223 -2.084002
# 3 -1.574223 -2.084002
# 4 -1.574223 -2.084002
#
#                                                     label_x origin_x  \
# 0  http://rdata2graph.sap.com/hilti_erp/property/t023.wgbez   graph1
# 1  http://rdata2graph.sap.com/hilti_erp/property/t023.wgbez   graph1
# 2  http://rdata2graph.sap.com/hilti_erp/property/t023.wgbez   graph1
# 3  http://rdata2graph.sap.com/hilti_erp/property/t023.wgbez   graph1
# 4  http://rdata2graph.sap.com/hilti_erp/property/t023.wgbez   graph1
#
#         x_y       y_y  \
# 0  0.043115 -3.062463
# 1  0.051993 -2.304238
# 2  0.489417 -2.138913
# 3  0.444228 -1.754985
# 4  0.257650 -1.135544
#
#                                                                 label_y  \
# 0  http://rdata2graph.sap.com/hilti_web/property/categories.description
# 1         http://rdata2graph.sap.com/hilti_web/property/categories.name
# 2    http://rdata2graph.sap.com/hilti_web/property/products.description
# 3           http://rdata2graph.sap.com/hilti_web/property/products.name
# 4            http://rdata2graph.sap.com/hilti_web/property/products.pid
#
#   origin_y      dist
# 0   graph2  1.890283
# 1   graph2  1.641062
# 2   graph2  2.064371
# 3   graph2  2.045091
# 4   graph2  2.062845

# %%
print('Now matching ' + str(set(clusters['label_x'])))
# Out:
# Now matching {'http://rdata2graph.sap.com/hilti_erp/property/t023.wgbez', 'http://rdata2graph.sap.com/hilti_erp/property/t179.description', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/v137.mbr', 'http://www.w3.org/2000/01/rdf-schema#comment', 'http://rdata2graph.sap.com/hilti_web/property/categories.description', 'http://rdata2graph.sap.com/hilti_web/property/categories.name', 'http://rdata2graph.sap.com/hilti_web/property/products.description', 'http://rdata2graph.sap.com/hilti_erp/property/t179.id', 'http://rdata2graph.sap.com/hilti_erp/property/mara_fert.maktx', 'http://rdata2graph.sap.com/hilti_erp/property/v137.branchenbezeichnung', 'http://rdata2graph.sap.com/hilti_erp/property/t023.wgbez60', 'http://rdata2graph.sap.com/hilti_erp/property/t023.mandt', 'http://rdata2graph.sap.com/hilti_erp/property/t179.levelno', 'http://rdata2graph.sap.com/hilti_erp/property/t023.zz_ekgrp', 'http://rdata2graph.sap.com/hilti_erp/property/t023.begru', 'http://rdata2graph.sap.com/hilti_web/property/products.name', 'http://rdata2graph.sap.com/hilti_erp/property/t023.gewei', 'http://www.w3.org/2000/01/rdf-schema#domain', 'http://rdata2graph.sap.com/hilti_erp/property/t023.zz_inactive', 'http://rdata2graph.sap.com/hilti_web/property/products.pid', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.ekwsl', 'http://rdata2graph.sap.com/hilti_erp/property/v137.bbr', 'http://rdata2graph.sap.com/hilti_web/property/categories.id', 'http://rdata2graph.sap.com/hilti_erp/property/v137.flref', 'http://www.w3.org/2000/01/rdf-schema#label'}

# %%
mappings = list()
dists = list()
while len(clusters)>0:
    match = clusters.loc[clusters.dist == clusters['dist'].min()]
    clusters = clusters.drop(match.index, axis=0)
    dists.append(match.dist.values[0])
    for val in match.label_x.values:
        x = clusters.loc[(clusters.label_x == val) | (clusters.label_y == val)]
        clusters = clusters.drop(x.index, axis=0)
    mappings.append((str(match[:2].label_x.values)))

# %%
model = KMeans(n_clusters=2).fit(np.array(dists).reshape(-1,1))

# %%
for mapping in mappings[:list(model.predict(np.array(dists).reshape(-1,1))).index(1)]:
    print(mapping)
# Out:
# ['http://rdata2graph.sap.com/hilti_erp/property/t179.levelno'
#  'http://rdata2graph.sap.com/hilti_web/property/products.pid']
# ['http://rdata2graph.sap.com/hilti_erp/property/t179.description'
#  'http://rdata2graph.sap.com/hilti_web/property/categories.name']
# ['http://rdata2graph.sap.com/hilti_erp/property/mara_fert.maktx'
#  'http://rdata2graph.sap.com/hilti_web/property/products.name']
# ['http://rdata2graph.sap.com/hilti_erp/property/t179.id'
#  'http://rdata2graph.sap.com/hilti_web/property/categories.id']
