# %%
import pandas as pd

# %%
df = pd.read_csv('C:\\Users\\D072202\\DeepAnyMatch\\DeepAnyMatch\\result_data\\hilti\\HILTI_w2v_steps_walklength1_2019_06_18_18_23_35_354350\\possible_matches.csv_merged.csv',sep="\t")
df.head()
# Out:
#    Unnamed: 0     src_0     src_1     src_2     src_3     src_4     src_5  \
# 0           0 -0.337761 -1.064190  2.627357  1.943610  2.902333  1.178696
# 1           1  0.918738  2.345728  2.228559  2.387622  1.581136  0.677656
# 2           2  1.827864  0.905644 -0.476271 -1.210594  3.061833  2.496121
# 3           3 -0.447161 -0.318282  2.554388 -0.271548  1.556789  3.341794
# 4           4  1.214062  1.547799  2.144877  1.826792  1.527097  1.082916
#
#       src_6     src_7     src_8  ...  label  syntactic_diff  src_tgt_angle  \
# 0 -1.484824 -2.599172  2.591950  ...    1.0        0.000000       0.863586
# 1  0.438235 -0.182594  0.569251  ...    0.0        0.482759       0.613700
# 2  0.003508 -3.046188  3.107526  ...    0.0        0.615385       0.591334
# 3 -1.506378 -1.495706  2.453148  ...    0.0        0.066667       0.837712
# 4 -1.520046 -1.976678  1.100136  ...    0.0        0.137931       0.827372
#
#    src_angle_to_origin  tgt_angle_to_origin  src_veclen  tgt_veclen  \
# 0             0.495944             0.514300    7.505842    7.265775
# 1             0.721177             0.494182    7.741276    5.978023
# 2             0.445615             0.450244    7.288298    6.002305
# 3             0.461629             0.400484    7.156521    6.583231
# 4             0.556814             0.571258    5.771136    6.343470
#
#    src_tgt_veclen                                             src_id  \
# 0        3.864780  http://rdata2graph.sap.com/hilti_erp/measuring...
# 1        6.234027  http://rdata2graph.sap.com/hilti_erp/fastener_...
# 2        6.116314  http://rdata2graph.sap.com/hilti_erp/stator_11...
# 3        3.952269  http://rdata2graph.sap.com/hilti_erp/data_cabl...
# 4        3.600975  http://rdata2graph.sap.com/hilti_erp/fastener_...
#
#                                               tgt_id
# 0  http://rdata2graph.sap.com/hilti_web/measuring...
# 1  http://rdata2graph.sap.com/hilti_web/fastener_...
# 2  http://rdata2graph.sap.com/hilti_web/stator_11...
# 3  http://rdata2graph.sap.com/hilti_web/data_cabl...
# 4  http://rdata2graph.sap.com/hilti_web/fastener_...
#
# [5 rows x 51 columns]

# %%
f = open('C:\\Users\\D072202\\DeepAnyMatch\\DeepAnyMatch\\result_data\\hilti\\HILTI_w2v_steps_walklength1_2019_06_18_18_23_35_354350\\w2v_training_material.csv','r')
#training_material = [x.split(" ") for x in f.read().replace("], ","").replace("[[","[".replace("]]","]").replace("'","").replace(",","").split("[") if not x.split(" ")==['']]
training_material = [x.split(" ") for x in f.read().split("\n") if not x.split(" ")==['']]

# %%
tmp = list()
for t in training_material:
    tmp2 = list()
    for t2 in t:
        if not t2=='':
            tmp2.append(t2)
    tmp.append(tmp2)
training_material=tmp
training_material[:2]
# Out:
# [['http://rdata2graph.sap.com/hilti_erp/graco_ultra_max_ii_695#c2bce0a9-aa7b-45ff-9f09-7c004e697566',
#   'http://rdata2graph.sap.com/hilti_erp/property/mara_fert.maktx',
#   'graco',
#   'ultra',
#   'max',
#   'ii',
#   '695'],
#  ['http://rdata2graph.sap.com/hilti_erp/graco_ultra_max_ii_695#c2bce0a9-aa7b-45ff-9f09-7c004e697566',
#   'http://rdata2graph.sap.com/hilti_erp/property/t023.id',
#   'http://rdata2graph.sap.com/hilti_erp/#3a799970-cea9-42d4-bdfc-fd134949cb0a',
#   'http://rdata2graph.sap.com/hilti_erp/property/t023.begru',
#   '0001']]

# %%
out = list()
for header in ['src_'+str(i) for i in range(round((len(df.columns)-12)/2))] + ['tgt_'+str(i) for i in range(round((len(df.columns)-12)/2))]:
    tmp = df.sort_values(by=[header])
    o = compute_intersect(tmp[:10]['src_id'].tolist() + tmp[-10:]['src_id'].to_list() + tmp[round(len(tmp)/2)-5:round(len(tmp)/2)+5]['src_id'].to_list(), header)
    out.append(o)
# Out:
# ------------
# Intersect for src_0:
# ['http://rdata2graph.sap.com/hilti_erp/property/mara_fert.maktx', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.flref', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.mbr', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.branchenbezeichnung', 'befestigungsindustri', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.bbr', 'http://rdata2graph.sap.com/hilti_erp/property/t179.id', 'http://rdata2graph.sap.com/hilti_erp/property/t179.description', 'http://rdata2graph.sap.com/hilti_erp/property/t179.id', 'http://rdata2graph.sap.com/hilti_erp/property/t179.levelno', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.mandt', '100', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.wgbez', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.wgbez60', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.begru', '0001', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.ekwsl', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.gewei', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.zz_inactive', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.zz_ekgrp']
#
# ------------
# Intersect for src_1:
# ['http://rdata2graph.sap.com/hilti_erp/property/mara_fert.maktx', 'http://rdata2graph.sap.com/hilti_erp/property/t179.id', 'http://rdata2graph.sap.com/hilti_erp/property/t179.description', 'http://rdata2graph.sap.com/hilti_erp/property/t179.id', 'http://rdata2graph.sap.com/hilti_erp/property/t179.levelno', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.flref', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.mbr', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.branchenbezeichnung', 'befestigungsindustri', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.bbr', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.ekwsl', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.mandt', '100', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.begru', '0001', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.gewei', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.wgbez60', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.zz_inactive', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.wgbez', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.zz_ekgrp']
#
# ------------
# Intersect for src_2:
# ['http://rdata2graph.sap.com/hilti_erp/property/mara_fert.maktx', 'http://rdata2graph.sap.com/hilti_erp/property/t179.id', 'http://rdata2graph.sap.com/hilti_erp/property/t179.description', 'http://rdata2graph.sap.com/hilti_erp/property/t179.id', 'http://rdata2graph.sap.com/hilti_erp/property/t179.levelno', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.flref', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.mbr', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.branchenbezeichnung', 'befestigungsindustri', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.bbr', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.gewei', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.zz_inactive', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.begru', '0001', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.wgbez60', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.wgbez', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.ekwsl', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.mandt', '100', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.zz_ekgrp']
#
# ------------
# Intersect for src_3:
# ['http://rdata2graph.sap.com/hilti_erp/property/mara_fert.maktx', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.begru', '0001', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.gewei', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.zz_inactive', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.wgbez60', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.wgbez', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.ekwsl', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.zz_ekgrp', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.mandt', '100', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.flref', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.mbr', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.branchenbezeichnung', 'befestigungsindustri', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.bbr', 'http://rdata2graph.sap.com/hilti_erp/property/t179.id', 'http://rdata2graph.sap.com/hilti_erp/property/t179.description', 'http://rdata2graph.sap.com/hilti_erp/property/t179.id', 'http://rdata2graph.sap.com/hilti_erp/property/t179.levelno']
# ------------
# Intersect for src_4:
# ['http://rdata2graph.sap.com/hilti_erp/property/mara_fert.maktx', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.flref', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.mbr', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.branchenbezeichnung', 'befestigungsindustri', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.bbr', 'http://rdata2graph.sap.com/hilti_erp/property/t179.id', 'http://rdata2graph.sap.com/hilti_erp/property/t179.levelno', 'http://rdata2graph.sap.com/hilti_erp/property/t179.id', 'http://rdata2graph.sap.com/hilti_erp/property/t179.description', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.begru', '0001', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.zz_ekgrp', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.mandt', '100', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.wgbez', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.zz_inactive', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.ekwsl', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.gewei', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.wgbez60']
#
# ------------
# Intersect for src_5:
# ['http://rdata2graph.sap.com/hilti_erp/property/mara_fert.maktx', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.mandt', '100', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.wgbez', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.begru', '0001', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.wgbez60', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.ekwsl', 'z001', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.zz_inactive', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.gewei', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.zz_ekgrp', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.flref', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.mbr', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.branchenbezeichnung', 'befestigungsindustri', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.bbr', 'http://rdata2graph.sap.com/hilti_erp/property/t179.id', 'http://rdata2graph.sap.com/hilti_erp/property/t179.description', 'http://rdata2graph.sap.com/hilti_erp/property/t179.id', 'http://rdata2graph.sap.com/hilti_erp/property/t179.levelno']
#
# ------------
# Intersect for src_6:
# ['http://rdata2graph.sap.com/hilti_erp/property/mara_fert.maktx', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.gewei', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.zz_inactive', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.begru', '0001', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.wgbez60', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.wgbez', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.ekwsl', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.mandt', '100', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.zz_ekgrp', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.flref', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.mbr', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.branchenbezeichnung', 'befestigungsindustri', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.bbr', 'http://rdata2graph.sap.com/hilti_erp/property/t179.id', 'http://rdata2graph.sap.com/hilti_erp/property/t179.description', 'http://rdata2graph.sap.com/hilti_erp/property/t179.id', 'http://rdata2graph.sap.com/hilti_erp/property/t179.levelno']
#
# ------------
# Intersect for src_7:
# ['http://rdata2graph.sap.com/hilti_erp/property/mara_fert.maktx', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/property/v137.flref', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/property/v137.mbr', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/property/v137.branchenbezeichnung', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/property/v137.bbr', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.zz_ekgrp', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.begru', '0001', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.zz_inactive', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.wgbez60', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.mandt', '100', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.gewei', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.ekwsl', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.wgbez', 'http://rdata2graph.sap.com/hilti_erp/property/t179.id', 'http://rdata2graph.sap.com/hilti_erp/property/t179.levelno', 'http://rdata2graph.sap.com/hilti_erp/property/t179.id', 'http://rdata2graph.sap.com/hilti_erp/property/t179.description']
#
# ------------
# Intersect for src_8:
# ['http://rdata2graph.sap.com/hilti_erp/property/mara_fert.maktx', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/property/v137.flref', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/property/v137.mbr', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/property/v137.branchenbezeichnung', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/property/v137.bbr', 'http://rdata2graph.sap.com/hilti_erp/property/t179.id', 'http://rdata2graph.sap.com/hilti_erp/property/t179.description', 'http://rdata2graph.sap.com/hilti_erp/property/t179.id', 'http://rdata2graph.sap.com/hilti_erp/property/t179.levelno', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.begru', '0001', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.gewei', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.zz_inactive', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.wgbez60', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.wgbez', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.ekwsl', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.zz_ekgrp', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.mandt', '100']
# ------------
# Intersect for src_9:
# ['http://rdata2graph.sap.com/hilti_erp/property/mara_fert.maktx', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/property/v137.flref', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/property/v137.mbr', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/property/v137.branchenbezeichnung', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/property/v137.bbr', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.begru', '0001', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.gewei', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.zz_inactive', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.wgbez60', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.wgbez', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.ekwsl', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.zz_ekgrp', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.mandt', '100', 'http://rdata2graph.sap.com/hilti_erp/property/t179.id', 'http://rdata2graph.sap.com/hilti_erp/property/t179.levelno', 'http://rdata2graph.sap.com/hilti_erp/property/t179.id', 'http://rdata2graph.sap.com/hilti_erp/property/t179.description']
#
# ------------
# Intersect for src_10:
# ['http://rdata2graph.sap.com/hilti_erp/property/mara_fert.maktx', 'http://rdata2graph.sap.com/hilti_erp/property/t179.id', 'http://rdata2graph.sap.com/hilti_erp/property/t179.description', 'http://rdata2graph.sap.com/hilti_erp/property/t179.id', 'http://rdata2graph.sap.com/hilti_erp/property/t179.levelno', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.flref', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.mbr', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.branchenbezeichnung', 'befestigungsindustri', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.bbr', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.gewei', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.wgbez60', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.ekwsl', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.zz_ekgrp', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.wgbez', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.mandt', '100', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.zz_inactive', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.begru', '0001']
#
# ------------
# Intersect for src_11:
# ['http://rdata2graph.sap.com/hilti_erp/property/mara_fert.maktx', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.flref', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.mbr', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.branchenbezeichnung', 'befestigungsindustri', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.bbr', 'http://rdata2graph.sap.com/hilti_erp/property/t179.id', 'http://rdata2graph.sap.com/hilti_erp/property/t179.description', 'http://rdata2graph.sap.com/hilti_erp/property/t179.id', 'http://rdata2graph.sap.com/hilti_erp/property/t179.levelno', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.begru', '0001', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.gewei', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.zz_inactive', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.wgbez60', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.wgbez', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.ekwsl', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.zz_ekgrp', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.mandt', '100']
#
# ------------
# Intersect for src_12:
# ['http://rdata2graph.sap.com/hilti_erp/property/mara_fert.maktx', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.zz_ekgrp', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.begru', '0001', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.zz_inactive', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.wgbez60', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.mandt', '100', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.gewei', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.ekwsl', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.wgbez', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.flref', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.mbr', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.branchenbezeichnung', 'befestigungsindustri', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.bbr', 'http://rdata2graph.sap.com/hilti_erp/property/t179.id', 'http://rdata2graph.sap.com/hilti_erp/property/t179.description', 'http://rdata2graph.sap.com/hilti_erp/property/t179.id', 'http://rdata2graph.sap.com/hilti_erp/property/t179.levelno']
#
# ------------
# Intersect for src_13:
# ['http://rdata2graph.sap.com/hilti_erp/property/mara_fert.maktx', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.flref', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.mbr', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.branchenbezeichnung', 'befestigungsindustri', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.bbr', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.gewei', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.zz_inactive', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.begru', '0001', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.wgbez60', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.wgbez', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.ekwsl', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.mandt', '100', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.zz_ekgrp', 'http://rdata2graph.sap.com/hilti_erp/property/t179.id', 'http://rdata2graph.sap.com/hilti_erp/property/t179.description', 'http://rdata2graph.sap.com/hilti_erp/property/t179.id', 'http://rdata2graph.sap.com/hilti_erp/property/t179.levelno']
# ------------
# Intersect for src_14:
# ['http://rdata2graph.sap.com/hilti_erp/property/mara_fert.maktx', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/property/v137.flref', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/property/v137.mbr', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/property/v137.branchenbezeichnung', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/property/v137.bbr', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.begru', '0001', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.gewei', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.zz_inactive', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.wgbez60', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.wgbez', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.ekwsl', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.zz_ekgrp', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.mandt', '100', 'http://rdata2graph.sap.com/hilti_erp/property/t179.id', 'http://rdata2graph.sap.com/hilti_erp/property/t179.levelno', 'http://rdata2graph.sap.com/hilti_erp/property/t179.id', 'http://rdata2graph.sap.com/hilti_erp/property/t179.description']
#
# ------------
# Intersect for src_15:
# ['http://rdata2graph.sap.com/hilti_erp/property/mara_fert.maktx', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.begru', '0001', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.gewei', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.zz_inactive', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.wgbez60', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.wgbez', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.ekwsl', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.zz_ekgrp', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.mandt', '100', 'http://rdata2graph.sap.com/hilti_erp/property/t179.id', 'http://rdata2graph.sap.com/hilti_erp/property/t179.description', 'http://rdata2graph.sap.com/hilti_erp/property/t179.id', 'http://rdata2graph.sap.com/hilti_erp/property/t179.levelno', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.flref', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.mbr', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.branchenbezeichnung', 'befestigungsindustri', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.bbr']
#
# ------------
# Intersect for src_16:
# ['http://rdata2graph.sap.com/hilti_erp/property/mara_fert.maktx', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.mandt', '100', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.wgbez', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.begru', '0001', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.wgbez60', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.ekwsl', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.zz_inactive', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.gewei', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.zz_ekgrp', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.flref', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.mbr', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.branchenbezeichnung', 'befestigungsindustri', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.bbr', 'http://rdata2graph.sap.com/hilti_erp/property/t179.id', 'http://rdata2graph.sap.com/hilti_erp/property/t179.description', 'http://rdata2graph.sap.com/hilti_erp/property/t179.id', 'http://rdata2graph.sap.com/hilti_erp/property/t179.levelno']
#
# ------------
# Intersect for src_17:
# ['http://rdata2graph.sap.com/hilti_erp/property/mara_fert.maktx', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.begru', '0001', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.ekwsl', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.mandt', '100', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.zz_inactive', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.wgbez60', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.wgbez', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.gewei', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.zz_ekgrp', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.flref', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.mbr', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.branchenbezeichnung', 'befestigungsindustri', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.bbr', 'http://rdata2graph.sap.com/hilti_erp/property/t179.id', 'http://rdata2graph.sap.com/hilti_erp/property/t179.description', 'http://rdata2graph.sap.com/hilti_erp/property/t179.id', 'http://rdata2graph.sap.com/hilti_erp/property/t179.levelno']
#
# ------------
# Intersect for src_18:
# ['http://rdata2graph.sap.com/hilti_erp/property/mara_fert.maktx', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.begru', '0001', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.gewei', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.zz_inactive', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.wgbez60', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.wgbez', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.ekwsl', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.zz_ekgrp', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.mandt', '100', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.flref', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.mbr', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.branchenbezeichnung', 'befestigungsindustri', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.bbr', 'http://rdata2graph.sap.com/hilti_erp/property/t179.id', 'http://rdata2graph.sap.com/hilti_erp/property/t179.description', 'http://rdata2graph.sap.com/hilti_erp/property/t179.id', 'http://rdata2graph.sap.com/hilti_erp/property/t179.levelno']
# ------------
# Intersect for src_19:
# ['http://rdata2graph.sap.com/hilti_erp/property/mara_fert.maktx', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.mandt', '100', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.wgbez', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.begru', '0001', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.wgbez60', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.ekwsl', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.zz_inactive', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.gewei', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.zz_ekgrp', 'http://rdata2graph.sap.com/hilti_erp/property/t179.id', 'http://rdata2graph.sap.com/hilti_erp/property/t179.description', 'http://rdata2graph.sap.com/hilti_erp/property/t179.id', 'http://rdata2graph.sap.com/hilti_erp/property/t179.levelno', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.flref', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.mbr', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.branchenbezeichnung', 'befestigungsindustri', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.bbr']
#
# ------------
# Intersect for tgt_0:
# ['http://rdata2graph.sap.com/hilti_erp/property/mara_fert.maktx', 'http://rdata2graph.sap.com/hilti_erp/property/t179.id', 'http://rdata2graph.sap.com/hilti_erp/property/t179.description', 'http://rdata2graph.sap.com/hilti_erp/property/t179.id', 'http://rdata2graph.sap.com/hilti_erp/property/t179.levelno', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.flref', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.mbr', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.branchenbezeichnung', 'befestigungsindustri', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.bbr', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.begru', '0001', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.gewei', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.zz_inactive', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.wgbez60', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.wgbez', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.ekwsl', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.zz_ekgrp', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.mandt', '100']
#
# ------------
# Intersect for tgt_1:
# ['http://rdata2graph.sap.com/hilti_erp/property/mara_fert.maktx', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.begru', '0001', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.gewei', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.zz_inactive', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.wgbez60', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.wgbez', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.ekwsl', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.zz_ekgrp', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.mandt', '100', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.flref', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.mbr', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.branchenbezeichnung', 'befestigungsindustri', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.bbr', 'http://rdata2graph.sap.com/hilti_erp/property/t179.id', 'http://rdata2graph.sap.com/hilti_erp/property/t179.description', 'http://rdata2graph.sap.com/hilti_erp/property/t179.id', 'http://rdata2graph.sap.com/hilti_erp/property/t179.levelno']
#
# ------------
# Intersect for tgt_2:
# ['http://rdata2graph.sap.com/hilti_erp/property/mara_fert.maktx', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.flref', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.mbr', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.branchenbezeichnung', 'befestigungsindustri', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.bbr', 'http://rdata2graph.sap.com/hilti_erp/property/t179.id', 'http://rdata2graph.sap.com/hilti_erp/property/t179.description', 'http://rdata2graph.sap.com/hilti_erp/property/t179.id', 'http://rdata2graph.sap.com/hilti_erp/property/t179.levelno', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.begru', '0001', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.ekwsl', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.mandt', '100', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.zz_inactive', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.wgbez60', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.wgbez', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.gewei', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.zz_ekgrp']
# ------------
# Intersect for tgt_3:
# ...
#
# ------------
# Intersect for tgt_4:
# ['http://rdata2graph.sap.com/hilti_erp/property/mara_fert.maktx', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.flref', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.mbr', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.branchenbezeichnung', 'befestigungsindustri', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.bbr', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.ekwsl', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.mandt', '100', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.begru', '0001', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.gewei', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.wgbez60', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.zz_inactive', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.wgbez', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.zz_ekgrp', 'http://rdata2graph.sap.com/hilti_erp/property/t179.id', 'http://rdata2graph.sap.com/hilti_erp/property/t179.description', 'http://rdata2graph.sap.com/hilti_erp/property/t179.id', 'http://rdata2graph.sap.com/hilti_erp/property/t179.levelno']
#
# ------------
# Intersect for tgt_5:
# ['http://rdata2graph.sap.com/hilti_erp/property/mara_fert.maktx', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.flref', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.mbr', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.branchenbezeichnung', 'befestigungsindustri', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.bbr', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.ekwsl', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.gewei', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.begru', '0001', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.zz_inactive', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.wgbez60', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.mandt', '100', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.zz_ekgrp', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.wgbez', 'http://rdata2graph.sap.com/hilti_erp/property/t179.id', 'http://rdata2graph.sap.com/hilti_erp/property/t179.levelno', 'http://rdata2graph.sap.com/hilti_erp/property/t179.id', 'http://rdata2graph.sap.com/hilti_erp/property/t179.description']
#
# ------------
# Intersect for tgt_6:
# ['http://rdata2graph.sap.com/hilti_erp/property/mara_fert.maktx', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.flref', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.mbr', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.branchenbezeichnung', 'befestigungsindustri', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.bbr', 'http://rdata2graph.sap.com/hilti_erp/property/t179.id', 'http://rdata2graph.sap.com/hilti_erp/property/t179.levelno', 'http://rdata2graph.sap.com/hilti_erp/property/t179.id', 'http://rdata2graph.sap.com/hilti_erp/property/t179.description', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.zz_ekgrp', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.begru', '0001', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.zz_inactive', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.wgbez60', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.mandt', '100', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.gewei', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.ekwsl', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.wgbez']
# ------------
# Intersect for tgt_7:
# ['http://rdata2graph.sap.com/hilti_erp/property/mara_fert.maktx', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.flref', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.mbr', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.branchenbezeichnung', 'befestigungsindustri', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.bbr', 'http://rdata2graph.sap.com/hilti_erp/property/t179.id', 'http://rdata2graph.sap.com/hilti_erp/property/t179.levelno', 'http://rdata2graph.sap.com/hilti_erp/property/t179.id', 'http://rdata2graph.sap.com/hilti_erp/property/t179.description', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.zz_inactive', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.wgbez60', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.gewei', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.begru', '0001', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.zz_ekgrp', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.mandt', '100', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.ekwsl', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.wgbez']
#
# ------------
# Intersect for tgt_8:
# ['http://rdata2graph.sap.com/hilti_erp/property/mara_fert.maktx', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.flref', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.mbr', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.branchenbezeichnung', 'befestigungsindustri', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.bbr', 'http://rdata2graph.sap.com/hilti_erp/property/t179.id', 'http://rdata2graph.sap.com/hilti_erp/property/t179.levelno', 'http://rdata2graph.sap.com/hilti_erp/property/t179.id', 'http://rdata2graph.sap.com/hilti_erp/property/t179.description', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.begru', '0001', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.gewei', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.zz_inactive', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.wgbez60', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.wgbez', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.ekwsl', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.zz_ekgrp', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.mandt', '100']
#
# ------------
# Intersect for tgt_9:
# ['http://rdata2graph.sap.com/hilti_erp/property/mara_fert.maktx', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.gewei', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.zz_inactive', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.begru', '0001', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.wgbez60', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.wgbez', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.ekwsl', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.mandt', '100', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.zz_ekgrp', 'http://rdata2graph.sap.com/hilti_erp/property/t179.id', 'http://rdata2graph.sap.com/hilti_erp/property/t179.description', 'http://rdata2graph.sap.com/hilti_erp/property/t179.id', 'http://rdata2graph.sap.com/hilti_erp/property/t179.levelno', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.flref', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.mbr', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.branchenbezeichnung', 'befestigungsindustri', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.bbr']
#
# ------------
# Intersect for tgt_10:
# ['http://rdata2graph.sap.com/hilti_erp/property/mara_fert.maktx', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.ekwsl', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.begru', '0001', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.mandt', '100', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.gewei', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.wgbez60', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.zz_inactive', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.zz_ekgrp', 'http://rdata2graph.sap.com/hilti_erp/property/t023.id', 'http://rdata2graph.sap.com/hilti_erp/property/t023.wgbez', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.flref', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.mbr', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.branchenbezeichnung', 'befestigungsindustri', 'http://rdata2graph.sap.com/hilti_erp/property/v137.id', 'http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56', 'http://rdata2graph.sap.com/hilti_erp/property/v137.bbr', 'http://rdata2graph.sap.com/hilti_erp/property/t179.id', 'http://rdata2graph.sap.com/hilti_erp/property/t179.levelno', 'http://rdata2graph.sap.com/hilti_erp/property/t179.id', 'http://rdata2graph.sap.com/hilti_erp/property/t179.description']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-29-9ddac5d14e2d> in <module>
#       2 for header in ['src_'+str(i) for i in range(round((len(df.columns)-12)/2))] + ['tgt_'+str(i) for i in range(round((len(df.columns)-12)/2))]:
#       3     tmp = df.sort_values(by=[header])
# ----> 4     o = compute_intersect(tmp[:10]['src_id'].tolist() + tmp[-10:]['src_id'].to_list() + tmp[round(len(tmp)/2)-5:round(len(tmp)/2)+5]['src_id'].to_list(), header)
#       5     out.append(o)
#
# <ipython-input-15-c0b14c3a650e> in compute_intersect(id_list, headername)
#      24     x3 = list()
#      25     for i in range(0,len(x2)):
# ---> 26         x3.append([value for value in x2[i]])
#      27     intersect = x3[0]
#      28     for i in range(1,len(x3)):
#
# <ipython-input-15-c0b14c3a650e> in <listcomp>(.0)
#      24     x3 = list()
#      25     for i in range(0,len(x2)):
# ---> 26         x3.append([value for value in x2[i]])
#      27     intersect = x3[0]
#      28     for i in range(1,len(x3)):
#
# KeyboardInterrupt:

# %%
diff = set()
for an_intersect in out:
    diff = diff.difference(an_intersect)
    print(diff)
# Out:
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()

# %%
from operator import itemgetter
def getmax(listoftuples, no):
    return sorted(listoftuples,key=lambda x: x[1], reverse=True)[:no]

def compute_diff(id_list_x, id_list_y, headername):
    
    def sim(l1, l2):
        for value in l1:
            if value in l2:
                yield value
    
    def search(word):
        val = list()
        for x in training_material:
            if word in x:
                yield x   

    def flatten(x):
        for y in x:
            for z in y:
                yield z

    x=[search(word) for word in id_list_x]
    y=[search(word) for word in id_list_y]
    
    
    x2 = list()
    for value in x:
        x2.append(flatten(value))
    y2 = list()
    for value in y:
        y2.append(flatten(value))
    

    
    
    x4 = None
    for value in x2:
        if x4 is None:
            value = list(value)
            x4 = value
            x4 = list(sim(value, x4))
        else:
            value = list(value)
            x4 = list(sim(value, x4))
        
    
    y4 = None
    for value in y2:
        if y4 is None:
            value = list(value)
            y4 = value
            y4 = list(sim(value, y4))
        else:
            value = list(value)
            y4 = list(sim(value, y4))
        
    y4=[y4]
    x4=[x4]

    def diff(l1, l2):
        for value in l1:
            found=False
            for value2 in l2:
                if value==value2:
                    found=True
            if not found:
                yield value
                
    def concat_gen(g):
        for i in range(0,len(g)):
            for value in g[i]:
                yield value

    x3 = concat_gen(x4)
    y3 = concat_gen(y4)
    
    print('Difference for ' + headername+':')
    y3 = list(y3)
    x3 = list(x3)
    d = list(diff(x3, y3))
    out=list()
    out2=list()
    for val in d:
        ctr=0
        for tmp in training_material:
            if val in tmp:
                ctr = ctr + 1
        if not str(val)+" -> " + str(ctr) in out: 
            out.append(str(val)+" -> " + str(ctr))
            out2.append((str(val), int(ctr)))
    output1= getmax(out2,100)
    #output1 = output1[:10]
    d = list(diff(y3, x3))
    out=list()
    out2=list()
    for val in d:
        ctr=0
        for tmp in training_material:
            if val in tmp:
                ctr = ctr + 1
        if not str(val)+" -> " + str(ctr) in out: 
            out.append(str(val)+" -> " + str(ctr))
            out2.append((str(val), int(ctr)))
    output2 = getmax(out2,100)
    #output2 = output2[:10]
    return output1,output2
out = list()
for header in ['src_'+str(i) for i in range(round((len(df.columns)-12)/2))] + ['tgt_'+str(i) for i in range(round((len(df.columns)-12)/2))]:
    tmp = df.sort_values(by=[header])
    if 'src_' in header:
        hid = 'src_id'
    else:
        hid = 'tgt_id'
    o1, o2 = compute_diff(tmp[:10][hid].tolist(), tmp[-10:][hid].to_list(), header)
    for x in o1:
        print(x[0] + " (" + str(x[1]) + ")")
    print("---")
    for x in o2:
        print(x[0] + " (" + str(x[1]) + ")")
    print("\n")
    print("------------------")
# Out:
# Difference for src_0:
# ---
# http://rdata2graph.sap.com/hilti_erp/#3a799970-cea9-42d4-bdfc-fd134949cb0a (9984)
# not (3066)
# yet (2496)
# defin (2496)
# tool (2026)
# saw (1761)
# cordless (844)
# es (325)
# g01 (211)
# bulk (32)
# cutout (23)
# http://rdata2graph.sap.com/hilti_erp/cordless_cut_out_tool_sco_a22_bulk#1458df9d-b5c1-4996-9e09-96ac87688541 (15)
# http://rdata2graph.sap.com/hilti_erp/#3ce009af-6e85-4a82-a8b1-4055b9792951 (4)
# scoa22 (3)
#
#
# ------------------
# Difference for src_1:
# and (4055)
# part (2171)
# z001 (2078)
# accessori (1764)
# wall (1006)
# http://rdata2graph.sap.com/hilti_erp/#56c17318-d28c-4d22-8751-5116acbb7fa4 (736)
# spare (712)
# incl (349)
# posit (188)
# mm (167)
# 184 (92)
# mount (55)
# pra (54)
# adaptor (39)
# 72 (16)
# http://rdata2graph.sap.com/hilti_erp/wall_mount_pra_72#b81df8c6-4493-48bd-9eeb-212a1f62ab4f (15)
# http://rdata2graph.sap.com/hilti_erp/#a74f31da-9ef1-4c3d-a45a-971a53a08a34 (12)
# ---
#
#
# ------------------
# Difference for src_2:
# ---
#
#
# ------------------
# Difference for src_3:
# ---
#
#
# ------------------
# Difference for src_4:
# ---
# part (2171)
# z001 (2078)
#
#
# ------------------
# Difference for src_5:
# ---
#
#
# ------------------
# Difference for src_6:
# ---
#
#
# ------------------
# Difference for src_7:
# z001 (2078)
# saw (1761)
# 034 (141)
# ---
# http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56 (10060)
# http://rdata2graph.sap.com/hilti_erp/#3a799970-cea9-42d4-bdfc-fd134949cb0a (9984)
# not (3066)
# befestigungsindustri (2515)
# yet (2496)
# defin (2496)
#
#
# ------------------
# Difference for src_8:
# http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56 (10060)
# befestigungsindustri (2515)
# z001 (2078)
# ---
#
#
# ------------------
# Difference for src_9:
# ---
# http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56 (10060)
# befestigungsindustri (2515)
#
#
# ------------------
# Difference for src_10:
# z001 (2078)
# ---
#
#
# ------------------
# Difference for src_11:
# ---
# z001 (2078)
#
#
# ------------------
# Difference for src_12:
# ---
# http://rdata2graph.sap.com/hilti_erp/#3a799970-cea9-42d4-bdfc-fd134949cb0a (9984)
# not (3066)
# yet (2496)
# defin (2496)
# nail (460)
# xg (255)
# pack (186)
# magazin (77)
# g2 (18)
# x120 (18)
# http://rdata2graph.sap.com/hilti_erp/nail_magazine_x_m30s_g2_packed#0422eed0-83a8-4fd2-85eb-eb1777f1e0d7 (15)
# gm (10)
# http://rdata2graph.sap.com/hilti_erp/#9aa12970-5b12-4a5a-b411-f456b110795d (6)
# xm30 (1)
#
#
# ------------------
# Difference for src_13:
# and (4055)
# part (2171)
# z001 (2078)
# accessori (1764)
# screw (933)
# spare (712)
# dx (427)
# incl (349)
# si (214)
# 2 (133)
# magazin (77)
# 485 (56)
# http://rdata2graph.sap.com/hilti_erp/#a235b85c-2064-41ee-b212-b3b43d5d3080 (48)
# http://rdata2graph.sap.com/hilti_erp/screw_magazine_sd_m_2#c185d145-7cb3-4935-a625-d7bbe0977dd1 (15)
# sdm (10)
# http://rdata2graph.sap.com/hilti_erp/#db2a726e-464b-4352-844d-a58057b48b0f (4)
# ---
#
#
# ------------------
# Difference for src_14:
# z001 (2078)
# ---
# http://rdata2graph.sap.com/hilti_erp/#0e08a169-a93c-4c44-a608-820a1543aa56 (10060)
# http://rdata2graph.sap.com/hilti_erp/#3a799970-cea9-42d4-bdfc-fd134949cb0a (9984)
# not (3066)
# befestigungsindustri (2515)
# yet (2496)
# defin (2496)
# box (169)
# cordl (95)
#
#
# ------------------
# Difference for src_15:
# ---
#
#
# ------------------
# Difference for src_16:
# z001 (2078)
# ---
#
#
# ------------------
# Difference for src_17:
# ---
# z001 (2078)
#
#
# ------------------
# Difference for src_18:
# ---
#
#
# ------------------
# Difference for src_19:
# other (1810)
# ---
#
#
# ------------------
# Difference for tgt_0:
# for (4274)
# ---
# me (2003)
# show (1988)
# cordless (844)
#
#
# ------------------
# Difference for tgt_1:
# ---
# saw (1761)
# concret (1604)
# demolit (1276)
# design (1251)
# wall (1006)
# diamond (857)
# servic (384)
# set (379)
# heavyduti (340)
# wire (323)
# hilti (235)
# http://rdata2graph.sap.com/hilti_web/diamond_wire___wall_saws#2f0b0940-db42-4b84-9be9-ca95dce9de3f (148)
# structur (133)
# wheel (120)
# alter (79)
# drive (56)
# pr (54)
# replac (43)
# pulley (36)
# dsww (24)
# 360 (6)
# http://rdata2graph.sap.com/hilti_web/drive_wheel_dsw_w_360_pr_servicing_set#676e3876-a8b5-4c18-82e8-4702ccfa953d (5)
# 20946630 (1)
#
#
# ------------------
# Difference for tgt_2:
# saw (1761)
# in (1308)
# design (1251)
# cut (924)
# metal (874)
# cordless (844)
# with (726)
# wood (480)
# a (378)
# perform (144)
# when (126)
# 22v (112)
# power (106)
# jig (97)
# control (52)
# comfort (36)
# superior (18)
# grip (15)
# 6a22 (7)
# top (6)
# http://rdata2graph.sap.com/hilti_web/cordless_jig_saws#f664366c-fe14-46f3-851c-cd8f6858da27 (6)
# http://rdata2graph.sap.com/hilti_web/sjd_6_a22#1941a150-6922-43ef-b670-b071eef4dc1f (5)
# user (5)
# sjd (3)
# dhandl (3)
# 21336720 (1)
# ---
# fasten (1081)
# stud (358)
#
#
# ------------------
# Difference for tgt_3:
# accessori (1764)
# design (1251)
# cut (924)
# metal (874)
# with (726)
# grind (365)
# disc (324)
# grinder (289)
# angl (266)
# as (171)
# wrench (101)
# diamet (85)
# switch (67)
# well (58)
# http://rdata2graph.sap.com/hilti_web/grinders___sanders#2ae4c91b-6e60-4da4-9e6a-1209b8c09155 (54)
# sander (45)
# variou (39)
# ---
# hammer (1386)
# breaker (1350)
# in (1308)
# demolit (1276)
# http://rdata2graph.sap.com/hilti_web/demolition_hammers___breakers#8480278b-fdd4-4cf2-8bb0-fd976ad0bdf0 (1128)
# wall (1006)
# cord (970)
# masonri (925)
# floor (738)
# none (648)
#
#
# ------------------
# Difference for tgt_4:
# ---
# concret (1604)
# hammer (1386)
# breaker (1350)
# in (1308)
# demolit (1276)
# http://rdata2graph.sap.com/hilti_web/demolition_hammers___breakers#8480278b-fdd4-4cf2-8bb0-fd976ad0bdf0 (1128)
# wall (1006)
# cord (970)
# masonri (925)
# floor (738)
# none (648)
#
#
# ------------------
# Difference for tgt_5:
# metal (874)
# wood (480)
# ---
#
#
# ------------------
# Difference for tgt_6:
# for (4274)
# and (4055)
# accessori (1764)
# ---
# me (2003)
# show (1988)
#
#
# ------------------
# Difference for tgt_7:
# ---
#
#
# ------------------
# Difference for tgt_8:
# other (1810)
# in (1308)
# drill (1052)
# masonri (925)
# metal (874)
# cordless (844)
# with (726)
# materi (527)
# wood (480)
# applic (349)
# driver (278)
# gear (205)
# perform (144)
# 22v (112)
# sf (100)
# ultim (79)
# control (52)
# 12v (46)
# high (44)
# class (34)
# torqu (34)
# activ (14)
# http://rdata2graph.sap.com/hilti_web/cordless_drill_drivers#f676a6d1-6081-48de-b21f-d63bd2a9f3b6 (12)
# atc (11)
# http://rdata2graph.sap.com/hilti_web/sf_10w_a_atc#43d70524-d995-4007-a7ec-12263882fea0 (5)
# demand (2)
# fourspe (1)
# 10wa (1)
# 21098290 (1)
# ---
# tool (2026)
# accessori (1764)
# to (893)
# none (648)
# measur (356)
# rod (353)
# http://rdata2graph.sap.com/hilti_web/accessories_for_measuring_tools_and_scanners#8d5328e7-96ab-42c5-bb5d-f3a56d6dfd3e (274)
# level (195)
# tripod (175)
# scanner (166)
# staff (158)
# keep (156)
# accur (145)
# steadi (137)
# read (137)
# adapt (111)
# 50 (47)
# reflector (39)
# poaw (7)
# http://rdata2graph.sap.com/hilti_web/reflector_rod_poaw_50_adapter#657f08be-4833-4389-9b1c-af4de6307050 (5)
# 21262370 (1)
#
#
# ------------------
# Difference for tgt_9:
# ---
#
#
# ------------------
# Difference for tgt_10:
# ---
# me (2003)
# show (1988)
# concret (1604)
# hammer (1386)
# breaker (1350)
# in (1308)
# demolit (1276)
# http://rdata2graph.sap.com/hilti_web/demolition_hammers___breakers#8480278b-fdd4-4cf2-8bb0-fd976ad0bdf0 (1128)
# wall (1006)
# cord (970)
# masonri (925)
# floor (738)
# none (648)
# assi (273)
# pack (186)
# drive (56)
# cylind (7)
#
#
# ------------------
# Difference for tgt_11:
# accessori (1764)
# use (876)
# with (726)
# more (597)
# firestop (509)
# all (279)
# hilti (235)
# solut (205)
# fire (161)
# protect (148)
# foam (134)
# sealant (134)
# see (87)
# http://rdata2graph.sap.com/hilti_web/accessories_for_firestop___fire_protection#0763ca39-003f-4130-8e66-c1c146bc5b4e (74)
# gun (52)
# like (50)
# dispenserscaulk (37)
# ---
# part (2171)
# tool (2026)
# me (2003)
# show (1988)
# saw (1761)
# design (1251)
# cord (970)
# cut (924)
# metal (874)
# cordless (844)
# spare (712)
# wood (480)
# http://rdata2graph.sap.com/hilti_web/saws#1ccce829-55db-4be8-acb6-f73f16febd03 (450)
# circular (385)
# grind (365)
# both (241)
# cuttingsaw (215)
#
#
# ------------------
# Difference for tgt_12:
# concret (1604)
# hammer (1386)
# design (1251)
# drill (1052)
# cord (970)
# rotari (531)
# chisel (444)
# sd (275)
# light (189)
# plu (143)
# tec (140)
# power (106)
# compact (69)
# chuck (59)
# http://rdata2graph.sap.com/hilti_web/rotary_hammers_sds_plus#5a9f051a-5b79-422c-8d6e-2a727bee0dd1 (36)
# sdsplu (26)
# ---
# other (1810)
# fasten (1081)
# screw (933)
# to (893)
# metal (874)
# materi (527)
# wood (480)
# stud (358)
# or (240)
# singl (235)
# drywal (214)
# collat (137)
# magazin (77)
# board (58)
# substructur (34)
# http://rdata2graph.sap.com/hilti_web/drywall_screws#4f1166f5-e6c7-48c5-b9e4-54946d3064b9 (26)
#
#
# ------------------
# Difference for tgt_13:
# for (4274)
# tool (2026)
# me (2003)
# show (1988)
# accessori (1764)
# design (1251)
# to (893)
# none (648)
# measur (356)
# http://rdata2graph.sap.com/hilti_web/accessories_for_measuring_tools_and_scanners#8d5328e7-96ab-42c5-bb5d-f3a56d6dfd3e (274)
# level (195)
# tripod (175)
# scanner (166)
# staff (158)
# keep (156)
# accur (145)
# steadi (137)
# read (137)
# imp (18)
# pa (18)
# http://rdata2graph.sap.com/hilti_web/leveling_staff___imp_ft_tenths_pa_962#884fb596-66d0-42ea-b1b8-3724dbc6f03d (5)
# 962 (2)
# fttenth (1)
# 3396710 (1)
# ---
#
#
# ------------------
# Difference for tgt_14:
# saw (1761)
# design (1251)
# diamond (857)
# blade (535)
# heavyduti (340)
# wire (323)
# hilti (235)
# http://rdata2graph.sap.com/hilti_web/diamond_wire___wall_saws#2f0b0940-db42-4b84-9be9-ca95dce9de3f (148)
# structur (133)
# guard (86)
# alter (79)
# center (30)
# section (28)
# ---
# hammer (1386)
# breaker (1350)
# in (1308)
# http://rdata2graph.sap.com/hilti_web/demolition_hammers___breakers#8480278b-fdd4-4cf2-8bb0-fd976ad0bdf0 (1128)
# cord (970)
# masonri (925)
# floor (738)
# none (648)
# torxsoc (66)
#
#
# ------------------
# Difference for tgt_15:
# saw (1761)
# demolit (1276)
# wall (1006)
# cut (924)
# diamond (857)
# ds (395)
# the (352)
# heavyduti (340)
# wire (323)
# http://rdata2graph.sap.com/hilti_web/diamond_wire___wall_saws#2f0b0940-db42-4b84-9be9-ca95dce9de3f (148)
# structur (133)
# alter (79)
# flush (78)
# ts20e (23)
# flang (18)
# dst (18)
# flushcut (10)
# 10ca (8)
# http://rdata2graph.sap.com/hilti_web/flush_cutting_flange_ds_fca_110ff#92dce39d-12f9-4b5b-b618-27c9ee6b2e82 (5)
# ts32lp32 (4)
# dsfca110ff (2)
# 4161890 (1)
# ---
# tool (2026)
# hammer (1386)
# drill (1052)
# cord (970)
# te (766)
# rotari (531)
# chisel (444)
# sd (275)
# combihamm (219)
# case (191)
# light (189)
# plu (143)
# 037 (140)
# tec (140)
# power (106)
# compact (69)
# http://rdata2graph.sap.com/hilti_web/rotary_hammers_sds_plus#5a9f051a-5b79-422c-8d6e-2a727bee0dd1 (36)
# 40 (34)
# sdsplu (26)
# typ (17)
# http://rdata2graph.sap.com/hilti_web/case_te_40___typ_037#7dddad27-d408-47e9-997d-1d68d4802489 (5)
# 20846930 (1)
#
#
# ------------------
# Difference for tgt_16:
# ---
# tool (2026)
# me (2003)
# show (1988)
# accessori (1764)
# fasten (1081)
# direct (283)
# http://rdata2graph.sap.com/hilti_web/accessories_for_direct_fastening#c4036c64-8631-4f28-b59b-bf473b394fc3 (204)
# piston (175)
# brake (104)
# buffer (102)
#
#
# ------------------
# Difference for tgt_17:
# and (4055)
# me (2003)
# show (1988)
# concret (1604)
# in (1308)
# masonri (925)
# ---
# tool (2026)
#
#
# ------------------
# Difference for tgt_18:
# ---
# me (2003)
# show (1988)
#
#
# ------------------
# Difference for tgt_19:
# floor (738)
# ---
# and (4055)
# me (2003)
# show (1988)
# hammer (1386)
# design (1251)
# drill (1052)
# cord (970)
# rotari (531)
# chisel (444)
# sd (275)
# light (189)
# pack (186)
# plu (143)
# tec (140)
# power (106)
# compact (69)
# chuck (59)
# http://rdata2graph.sap.com/hilti_web/rotary_hammers_sds_plus#5a9f051a-5b79-422c-8d6e-2a727bee0dd1 (36)
# sdsplu (26)
# quickreleas (6)
# http://rdata2graph.sap.com/hilti_web/quick_release_chuck_packed#c7ce6753-05ba-43b9-82b7-4b5675e2fffc (5)
# 21231660 (1)
#
#
# ------------------

# %%
out = list()

for header in ['src_'+str(i) for i in range(round((len(df.columns)-12)/2))] + ['tgt_'+str(i) for i in range(round((len(df.columns)-12)/2))]:
    tmp = df.sort_values(by=[header])
    o = compute_max_occurence(tmp[:10]['src_id'].tolist() + tmp[-10:]['src_id'].to_list() + tmp[round(len(tmp)/2)-5:round(len(tmp)/2)+5]['src_id'].to_list(), header)
    out.append(o)
# Out:
# ------------
# Max occurence for src_0:
# 0001: 30
# defin: 26
# not: 28
# 100: 30
# befestigungsindustri: 30
# yet: 26
#
# ------------
# Max occurence for src_1:
# z001: 25
# 0001: 30
# 100: 30
# befestigungsindustri: 30
# part: 27
#
# ------------
# Max occurence for src_2:
# part: 24
# z001: 25
# 0001: 30
# 100: 30
# befestigungsindustri: 30
#
# ------------
# Max occurence for src_3:
# defin: 32
# 0001: 30
# 100: 32
# yet: 32
# befestigungsindustri: 30
# not: 32
#
# ------------
# Max occurence for src_4:
# 100: 31
# 0001: 30
# z001: 24
# befestigungsindustri: 30
# magazin: 27
#
# ------------
# Max occurence for src_5:
# 0001: 30
# z001: 30
# 100: 30
# befestigungsindustri: 30
#
# ------------
# Max occurence for src_6:
# 100: 30
# 0001: 30
# z001: 24
# befestigungsindustri: 30
#
# ------------
# Max occurence for src_7:
# 0001: 30
# befestigungsindustri: 29
# saw: 31
# 100: 30
# not: 24
# part: 25
#
# ------------
# Max occurence for src_8:
# yet: 22
# 100: 33
# 0001: 30
# defin: 22
# befestigungsindustri: 29
# not: 23
#
# ------------
# Max occurence for src_9:
# 100: 33
# befestigungsindustri: 29
# 0001: 30
#
# ------------
# Max occurence for src_10:
# 0001: 30
# 100: 30
# befestigungsindustri: 30
# z001: 22
#
# ------------
# Max occurence for src_11:
# 0001: 30
# 100: 30
# befestigungsindustri: 30
# z001: 23
#
# ------------
# Max occurence for src_12:
# 0001: 30
# defin: 34
# yet: 34
# 100: 30
# befestigungsindustri: 30
# not: 34
#
# ------------
# Max occurence for src_13:
# part: 29
# 0001: 30
# screw: 26
# z001: 27
# 100: 30
# befestigungsindustri: 30
# magazin: 40
#
# ------------
# Max occurence for src_14:
# 0001: 30
# yet: 24
# befestigungsindustri: 29
# defin: 24
# 100: 30
# not: 24
#
# ------------
# Max occurence for src_15:
# defin: 46
# 0001: 30
# 100: 30
# befestigungsindustri: 30
# yet: 46
# not: 47
#
# ------------
# Max occurence for src_16:
# 0001: 30
# z001: 26
# 100: 30
# befestigungsindustri: 30
#
# ------------
# Max occurence for src_17:
# z001: 21
# 0001: 30
# 100: 30
# befestigungsindustri: 30
#
# ------------
# Max occurence for src_18:
# not: 38
# accessori: 23
# 0001: 30
# 100: 30
# befestigungsindustri: 30
# defin: 38
# yet: 38
#
# ------------
# Max occurence for src_19:
# 0001: 30
# yet: 24
# defin: 24
# 100: 30
# befestigungsindustri: 30
# not: 24
#
# ------------
# Max occurence for tgt_0:
# 0001: 30
# defin: 26
# accessori: 28
# 100: 30
# befestigungsindustri: 30
# not: 26
# yet: 26
#
# ------------
# Max occurence for tgt_1:
# part: 21
# z001: 25
# 0001: 30
# accessori: 38
# saw: 31
# 100: 30
# befestigungsindustri: 30
# wire: 27
#
# ------------
# Max occurence for tgt_2:
# part: 21
# defin: 28
# yet: 28
# 0001: 30
# not: 28
# 100: 30
# befestigungsindustri: 30
#
# ------------
# Max occurence for tgt_3:
# 100: 31
# yet: 22
# 0001: 30
# defin: 22
# not: 22
# part: 31
# befestigungsindustri: 30
#
# ------------
# Max occurence for tgt_4:
# z001: 25
# 0001: 30
# part: 30
# 100: 30
# befestigungsindustri: 30
#
# ------------
# Max occurence for tgt_5:
# accessori: 34
# 0001: 30
# saw: 27
# 100: 30
# z001: 24
# befestigungsindustri: 30
# wire: 27
#
# ------------
# Max occurence for tgt_6:
# 0001: 30
# z001: 26
# 100: 30
# befestigungsindustri: 30
# part: 25
#
# ------------
# Max occurence for tgt_7:
# z001: 22
# 0001: 30
# 100: 30
# befestigungsindustri: 30
# part: 32
#
# ------------
# Max occurence for tgt_8:
# yet: 36
# defin: 36
# 0001: 30
# not: 36
# 100: 30
# befestigungsindustri: 30
# accessori: 24
#
# ------------
# Max occurence for tgt_9:
# 0001: 30
# z001: 28
# accessori: 27
# 100: 30
# befestigungsindustri: 30
# part: 36
#
# ------------
# Max occurence for tgt_10:
# part: 21
# yet: 22
# 0001: 30
# defin: 22
# not: 22
# 100: 30
# befestigungsindustri: 30
#
# ------------
# Max occurence for tgt_11:
# z001: 22
# 0001: 30
# 100: 30
# befestigungsindustri: 30
# part: 28
#
# ------------
# Max occurence for tgt_12:
# z001: 22
# magazin: 25
# 0001: 30
# 100: 30
# befestigungsindustri: 30
# part: 28
#
# ------------
# Max occurence for tgt_13:
# 0001: 30
# part: 31
# 100: 30
# befestigungsindustri: 30
# z001: 24
#
# ------------
# Max occurence for tgt_14:
# 0001: 30
# z001: 29
# 100: 30
# befestigungsindustri: 30
# part: 27
#
# ------------
# Max occurence for tgt_15:
# 100: 31
# 0001: 30
# z001: 24
# befestigungsindustri: 30
#
# ------------
# Max occurence for tgt_16:
# 0001: 30
# yet: 24
# accessori: 27
# defin: 24
# 100: 30
# befestigungsindustri: 30
# part: 22
# not: 24
#
# ------------
# Max occurence for tgt_17:
# 0001: 30
# part: 34
# 100: 30
# z001: 24
# befestigungsindustri: 30
#
# ------------
# Max occurence for tgt_18:
# z001: 22
# 0001: 30
# 100: 30
# befestigungsindustri: 30
# part: 28
#
# ------------
# Max occurence for tgt_19:
# 0001: 30
# 100: 30
# befestigungsindustri: 30
# z001: 23
# part: 27

# %%
out = list()
for header in ['src_'+str(i) for i in range(round((len(df.columns)-12)/2))] + ['tgt_'+str(i) for i in range(round((len(df.columns)-12)/2))]:
    dimlist_x = list()
    dimlist_y = list()
    for header2 in ['src_'+str(i) for i in range(round((len(df.columns)-12)/2))] + ['tgt_'+str(i) for i in range(round((len(df.columns)-12)/2))]:
        if not header2 == header:
            tmp = df.sort_values(by=[header], ascending=False)
            dimlist_y.append(tmp[:10]['src_id'].tolist() + tmp[-10:]['src_id'].to_list() + tmp[round(len(tmp)/2)-5:round(len(tmp)/2)+5]['src_id'].to_list())
        else:
            tmp = df.sort_values(by=[header])
            dimlist_x.append(tmp[:10]['src_id'].tolist() + tmp[-10:]['src_id'].to_list() + tmp[round(len(tmp)/2)-5:round(len(tmp)/2)+5]['src_id'].to_list())
    o = compute_diff(dimlist_x, dimlist_y, header)
    out.append(o)
# Out:
# ------------
# Difference for src_0:
#
# ------------
# Difference for src_1:
#
# ------------
# Difference for src_2:
#
# ------------
# Difference for src_3:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-75-79701ee4c7df> in <module>
#      10             tmp = df.sort_values(by=[header])
#      11             dimlist_x.append(tmp[:10]['src_id'].tolist() + tmp[-10:]['src_id'].to_list() + tmp[round(len(tmp)/2)-5:round(len(tmp)/2)+5]['src_id'].to_list())
# ---> 12     o = compute_diff(dimlist_x, dimlist_y, header)
#      13     out.append(o)
#
# <ipython-input-36-1c8f998415c6> in compute_diff(id_list_x, id_list_y, headername)
#      32     y3 = list()
#      33     for i in range(0,len(y2)):
# ---> 34         y3 = y3 + ([value for value in y2[i]])
#      35
#      36     print("\n------------")
#
# <ipython-input-36-1c8f998415c6> in <listcomp>(.0)
#      32     y3 = list()
#      33     for i in range(0,len(y2)):
# ---> 34         y3 = y3 + ([value for value in y2[i]])
#      35
#      36     print("\n------------")
#
# <ipython-input-36-1c8f998415c6> in flatten(x)
#       8
#       9     def flatten(x):
# ---> 10         for y in x:
#      11             for z in y:
#      12                 yield z
#
# KeyboardInterrupt:

# %%
diff = set()
for an_intersect in out:
    diff = diff.difference(an_intersect)
    print(diff)
# Out:
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()

# %%
# Out:
# set()

# %%
def compute_intersect(id_list, headername):

    def search(word):
        val = list()
        for x in training_material:
            if word in x:
                yield x   

    def flatten(x):
        for y in x:
            for z in y:
                yield z

    x=[search(word) for word in id_list]

    x2 = list()
    for value in x:
        x2.append(flatten(value))


    def intersection(l1, l2): 
        return [value for value in l1 if value in l2]

    x3 = list()
    for i in range(0,len(x2)):
        x3.append([value for value in x2[i]])
    intersect = x3[0]
    for i in range(1,len(x3)):
        intersect = intersection(x3[i], intersect)
    print("\n------------")
    print('Intersect for ' + headername+':')
    print(intersect)
    return intersect

# %%
def compute_max_occurence(id_list, headername):
    
    def search(word):
        val = list()
        for x in training_material:
            if word in x:
                yield x   

    def flatten(x):
        for y in x:
            for z in y:
                yield z

    x=[search(word) for word in id_list]
    
    x2 = list()
    for value in x:
        x2.append(flatten(value))
    x3=list()
    for value in x2:
        for value2 in value:
            x3.append(value2)
    training = pd.DataFrame(x3)
    training = training.set_index(training[0])
    training.columns = ['values']
    t = [val for val in training['values'].values.tolist() if not 'http' in val]
    tpd = pd.DataFrame(t)
    tpd = tpd.set_index(tpd[0])
    print("\n------------")
    print('Max occurence for ' + headername+':')
    r = [w + ': ' + str(pd.DataFrame([countit(tpd, w)])[0].to_list()[0]) for w in t if pd.DataFrame([countit(tpd, w)])[0].to_list()[0] > 20]
    print("\n".join(list(set(r))))
    return

# %%
def compute_diff(id_list_x, id_list_y, headername):

    def search(word):
        val = list()
        for x in training_material:
            if word in x:
                yield x   

    def flatten(x):
        for y in x:
            for z in y:
                yield z

    x=[search(word) for word in id_list_x]
    y=[search(word) for word in id_list_y]
    
    
    x2 = list()
    for value in x:
        x2.append(flatten(value))
    y2 = list()
    for value in y:
        y2.append(flatten(value))


    def diff(l1, l2): 
        return [value for value in l1 if not value in l2]

    x3 = list()
    for i in range(0,len(x2)):
        x3 = x3 + ([value for value in x2[i]])
    y3 = list()
    for i in range(0,len(y2)):
        y3 = y3 + ([value for value in y2[i]])
    
    print(x3)
    print("\n------------")
    print('Difference for ' + headername+':')
    d = diff(x3, y3)
    for val in d:
        ctr=0
        for tmp in training_material:
            if val in tmp:
                ctr = ctr + 1
        #print(str(val)+" -> " + str(ctr))
    return d

# %%
out = list()
for header in ['src_'+str(i) for i in range(round((len(df.columns)-12)/2))] + ['tgt_'+str(i) for i in range(round((len(df.columns)-12)/2))]:
    dimlist_x = list()
    dimlist_y = list()
    for header2 in ['src_'+str(i) for i in range(round((len(df.columns)-12)/2))] + ['tgt_'+str(i) for i in range(round((len(df.columns)-12)/2))]:
        if not header2 == header:
            tmp = df.sort_values(by=[header2], ascending=False)
            dimlist_y = dimlist_y + (tmp[:10]['src_id'].tolist() + tmp[-10:]['src_id'].to_list() + tmp[round(len(tmp)/2)-5:round(len(tmp)/2)+5]['src_id'].to_list())
        else:
            tmp = df.sort_values(by=[header2], ascending=False)
            dimlist_x = dimlist_x + (tmp[:10]['src_id'].tolist() + tmp[-10:]['src_id'].to_list() + tmp[round(len(tmp)/2)-5:round(len(tmp)/2)+5]['src_id'].to_list())
    
    #o = compute_diff(dimlist_x, dimlist_y, header)
    #out.append(o)
    z = set(dimlist_x) - set(dimlist_y)
    out = list()
    print("------------")
    print("Difference for " + header)
    for val in z:
        if dimlist_x.count(val)>0:
            out.append(val)
    print(out)
# Out:
# ------------
# Difference for src_0
# ['http://rdata2graph.sap.com/hilti_erp/centering_bushing#4b60d26d-2990-43c4-b2ae-179d2dc30ba0', 'http://rdata2graph.sap.com/hilti_erp/gear_housing_assy#64a13cbf-b805-44b4-90c8-d9019ba4dc54', 'http://rdata2graph.sap.com/hilti_erp/insulating_washer#9b39e49b-7f4c-4840-808e-44497c74c56b', 'http://rdata2graph.sap.com/hilti_erp/toothed_gear_z_29#721a42e8-b48f-4e78-9665-a9d028478ff8']
# ------------
# Difference for src_1
# ['http://rdata2graph.sap.com/hilti_erp/wire_size_bit__47_12_bx_[vc12_3d_x_207sp#637328f9-ef5a-4a76-b770-94dabcb51fee', 'http://rdata2graph.sap.com/hilti_erp/kit_wsr_900_pe___w_csr_cas#09bc6107-0f42-494f-ac82-a67d37869ef0', 'http://rdata2graph.sap.com/hilti_erp/fastening_set_hvu_m20___has_e_r#f63b0be0-c74e-4553-888c-b3c9fd2410e7']
# ------------
# Difference for src_2
# ['http://rdata2graph.sap.com/hilti_erp/side_handle_270_assy#b3d19247-84ba-489d-9cbe-dd7b48bd9b08', 'http://rdata2graph.sap.com/hilti_erp/rating_plate_te_16_m_120v_usa#29621c8a-243f-4fdf-9a20-5697d60d49a7', 'http://rdata2graph.sap.com/hilti_erp/socket_wrench_insert_mft_bit_sq#f0d152ea-7c4e-4cc9-9f7f-c95dbd688d6a', 'http://rdata2graph.sap.com/hilti_erp/lid_220_240v_assy#cae210a7-3130-4123-8961-1b8c708685a4', 'http://rdata2graph.sap.com/hilti_erp/electric_plug_250v_16a_te_kpl_grip#b227f888-2123-4b91-a5f5-c845fdf2531a', 'http://rdata2graph.sap.com/hilti_erp/grip_unit_wsr_assy#3bc063f7-4896-4c6a-958c-5c44d4f25413', 'http://rdata2graph.sap.com/hilti_erp/truss_head_bolt_m10_x_20__grade_8_8u_hdg#cc56c94c-16f2-4483-a81a-f22e6a845c61', 'http://rdata2graph.sap.com/hilti_erp/identification_plate_qr_us#45e0c6e1-b850-4aa4-89cc-a75cfcefaed2']
# ------------
# Difference for src_3
# ['http://rdata2graph.sap.com/hilti_erp/bevel_pinion_te_60_03_packed#ed5f8029-72d5-4723-abd8-341a990d1704', 'http://rdata2graph.sap.com/hilti_erp/kit_te_70_atc_te_yx_22_te_yp_sm_fm_foot#37a3d384-0251-4500-9d6a-62879b897754', 'http://rdata2graph.sap.com/hilti_erp/s_pack_metal_cutting_disc_100_7#b0e2fc41-0715-4f49-b956-baf55fe16b70', 'http://rdata2graph.sap.com/hilti_erp/extension_tube_sme_assy#d4e4efcb-b7d2-48b1-a49f-f9f0bb4e6a74', 'http://rdata2graph.sap.com/hilti_erp/extension_tube_200_assy#5b41f3e0-d341-44f9-abba-f74d5d97e850', 'http://rdata2graph.sap.com/hilti_erp/cutting_disc_ac_d_115_stnls_#aa68c4ce-7bf6-4d53-a728-6b52ef93c87e']
# ------------
# Difference for src_4
# ['http://rdata2graph.sap.com/hilti_erp/narrow_flat_chisel_tp_22_fm_50_assy#1abdbb66-8a1d-4f44-8b10-a9e62e2c0500', 'http://rdata2graph.sap.com/hilti_erp/kit_dd_bs_300_1500_hx4s#cf38b13d-23c1-436f-a70f-47b34db11b15', 'http://rdata2graph.sap.com/hilti_erp/metal_anchor_hb_m8#ece9f5f5-0661-42c8-a1c8-337f7f56750e', 'http://rdata2graph.sap.com/hilti_erp/coupler_magnet_assy#40a3bfe4-acdb-4292-80a0-23228fff4ffa', 'http://rdata2graph.sap.com/hilti_erp/bevel_gear_z_27#c28bf21a-311f-440c-96aa-0681039ee199', 'http://rdata2graph.sap.com/hilti_erp/o_ring_9_19x2_62#181b008c-9803-4320-a0fc-d93c08d12cf0', 'http://rdata2graph.sap.com/hilti_erp/kit_dd_150_bidon_sac_f_t_x_ring_112_320#b5b25b42-15ac-4101-9677-faa75737de8c', 'http://rdata2graph.sap.com/hilti_erp/kit_dd_150_u___s_sd_sl1_2_x_7_0#4652d0fc-098c-42c6-8ba8-ba12a233a8ff', 'http://rdata2graph.sap.com/hilti_erp/dag_100_grinding_disc_package_100_7#119dcf01-ddf8-4769-ba21-c5bf82dcfa0a', 'http://rdata2graph.sap.com/hilti_erp/crimping_pliers_ds_wsthy#63fbe04e-6903-43b7-bfe6-cb1c7b6fd8d6', 'http://rdata2graph.sap.com/hilti_erp/extension_tube_x_pt_ct_351_3ft#9f6672fc-f37e-4436-b926-8f2e8505b2c5']
# ------------
# Difference for src_5
# ['http://rdata2graph.sap.com/hilti_erp/ceiling_hanger_x_cc_mx_4_12ga#c3a29976-6543-41ce-b415-8923158ef1b5', 'http://rdata2graph.sap.com/hilti_erp/locking_snap_in_clip_mp_pl_20#4536af19-aca4-4d9c-ba80-93cc384bd919', 'http://rdata2graph.sap.com/hilti_erp/gearing_te_80_atc_avr_assy#ddbfe019-e430-4e3f-97f9-a97afe31806b', 'http://rdata2graph.sap.com/hilti_erp/drywall_screw_6_x_1_5_8_pbh_sd_zinc#7d176a7e-dd2b-4691-9a91-fcbdbd486c31', 'http://rdata2graph.sap.com/hilti_erp/case_dx_36_typ_7#d91fe1a1-0d25-41d9-8535-3a0817d46ac3', 'http://rdata2graph.sap.com/hilti_erp/water_collector_holder_dd_st_150_160_wch#59e168e2-30f7-44d6-9464-5a17423006df', 'http://rdata2graph.sap.com/hilti_erp/pole_tool_x_pt_351_7ft_assy#5f6cdb5d-1650-4bd8-b3a5-3fc9458c62e4', 'http://rdata2graph.sap.com/hilti_erp/pole_tool_x_pt_35_7ft_assy#1b383f5e-723d-4f88-b93e-ed03794ed95e', 'http://rdata2graph.sap.com/hilti_erp/water_collector_holder_dd_wcs_hh_150#1c4ed5b7-41a5-4d31-b14c-240d6274cdee', 'http://rdata2graph.sap.com/hilti_erp/water_collector_holder_dd_hd30_wch#b7c894e1-7333-43b6-b24d-44813b238870']
# ------------
# Difference for src_6
# ['http://rdata2graph.sap.com/hilti_erp/connection_end_dd_bs#3849e74f-33a3-45d3-bbed-fe7e2a21e795', 'http://rdata2graph.sap.com/hilti_erp/wsr_22_a_case_set_3_3ah__2_#b5ec8a3a-8e24-4a03-a097-d7c25bac738d', 'http://rdata2graph.sap.com/hilti_erp/wall_saw_blade_ds_b_750_rc_retipped#b26d311e-ab57-4623-a924-3d8328f502a7', 'http://rdata2graph.sap.com/hilti_erp/wall_saw_blade_ds_b_1000_24_cl_nbm#692ee1f4-9bcb-4992-82cb-07ceaef8bb51', 'http://rdata2graph.sap.com/hilti_erp/slotted_wood_screw_4x30#daf507f4-41f8-4ffe-b5c4-f40490184b9a', 'http://rdata2graph.sap.com/hilti_erp/vacuum_cleaner_dc_pp_25___1400spe#00bdab45-6f9c-4b83-a729-da63ac2e32d8', 'http://rdata2graph.sap.com/hilti_erp/connector_housing_ul_assy_packed#e73f69e3-9a09-4e26-b3f6-0b6c791d502c', 'http://rdata2graph.sap.com/hilti_erp/piston_guide_dx36m_packed#dfeb23fe-102a-46e9-b0b6-ce2f786b4314', 'http://rdata2graph.sap.com/hilti_erp/rating_plate_te_76_atc_110v_tw#1cd99e84-6c4e-46b7-94c4-8c67e84767c9', 'http://rdata2graph.sap.com/hilti_erp/backplate_gx_120_packed#13256ed7-a7c9-41c2-beee-8f92273a655e']
# ------------
# Difference for src_7
# ['http://rdata2graph.sap.com/hilti_erp/cylindrical_roller_5x5#9eb6622c-1bbb-4437-b0dd-7b763933842b', 'http://rdata2graph.sap.com/hilti_erp/operating_instructions_tdr_p3#eaaa1a69-e7b4-4d55-9eee-638989e61d72', 'http://rdata2graph.sap.com/hilti_erp/install__channel_mq_41_f_2_2_m#c1bc6a00-bc1c-494a-8f7c-a957c764d527', 'http://rdata2graph.sap.com/hilti_erp/me_and_plumbring_pack_7__cf126_#21eeb807-1277-4bd2-9205-908082484280', 'http://rdata2graph.sap.com/hilti_erp/toothed_gear_z_24#9d820b5e-8b48-4cfc-a037-3cdc13e93587']
# ------------
# Difference for src_8
# ['http://rdata2graph.sap.com/hilti_erp/kit_te_1___dag_125_s#b1182a79-be2e-4c58-ae67-b3afae5c9008', 'http://rdata2graph.sap.com/hilti_erp/torx_soc_re_scr_4x20_black#985bbf19-a403-4aca-9409-63bbf6f3a64d', 'http://rdata2graph.sap.com/hilti_erp/cartridge_holder_hit_cb_500#cab2a3f1-ff3f-423f-b8bd-560d7adad794', 'http://rdata2graph.sap.com/hilti_erp/fastener_guide_x_351_f8ct#a95f6108-2c39-4608-a674-c3878eeec347', 'http://rdata2graph.sap.com/hilti_erp/fm48_p_dag_125_se_230v_quick_lock#c9715e55-ba2a-4761-bec3-64743ca0e8b7', 'http://rdata2graph.sap.com/hilti_erp/insulating_connector#1f0f8cf6-75f9-491b-98ac-8ec72814291d', 'http://rdata2graph.sap.com/hilti_erp/amoladora_dag_125_s___kit_de_trabajo_seg#3d5c5397-9de0-4b32-bae2-f16ccb83f0c2', 'http://rdata2graph.sap.com/hilti_erp/sl_cheese_head_screw_m5x75_zn#f53ed383-bbdb-48b2-bc2c-b15fc643ac39', 'http://rdata2graph.sap.com/hilti_erp/tripod_bag_pua_44#6972deb8-d4c3-43f2-aada-67546bb0262c']
# ------------
# Difference for src_9
# ['http://rdata2graph.sap.com/hilti_erp/hexagon_nut_m12_zinced#6ebcbae2-1b45-43ea-b0a6-b44b172dd2e4', 'http://rdata2graph.sap.com/hilti_erp/hardmetal_tip_18__x_form#98cb9cba-3ea9-49f1-8a3d-637cf0cafddc', 'http://rdata2graph.sap.com/hilti_erp/anchor_rod_hit_c_nut_m24_sus_316_#e4108e5f-18f2-47bc-bc61-4200b7a6a0b6', 'http://rdata2graph.sap.com/hilti_erp/washer_holder_x_120_wh#51b4b008-38eb-41a5-98be-c8515fb33cef', 'http://rdata2graph.sap.com/hilti_erp/torx_soc_tapt_scr_m10x30__sn140_black#ff37b0e9-6411-4559-bdf3-d3f0f8da278d', 'http://rdata2graph.sap.com/hilti_erp/remote_control_ds_rc_ts20#9a940a8f-92a1-46b3-afd5-ab9a9dbcdec0', 'http://rdata2graph.sap.com/hilti_erp/hex_skt_hd_cap_screw_m8x45_a4_70#e88f5da1-6372-49f8-aae9-4cd0a7d0aa24', 'http://rdata2graph.sap.com/hilti_erp/bevel_pinion_packed#dc807012-59ba-4e04-85b3-626c7abbeeea', 'http://rdata2graph.sap.com/hilti_erp/hexagon_nut_m12__din_980__kl10_verzinkt_#5fd7b52f-abcf-4827-bcfd-5b9a986dff70', 'http://rdata2graph.sap.com/hilti_erp/firestop_plug_cfs_pl_158#dd355de5-406c-4eaa-9fb8-29cbbc220422', 'http://rdata2graph.sap.com/hilti_erp/remote_control_dst_wrc_ca_ul_assy#6d91b6ba-4ded-4476-accf-4e3e26aa6ba8', 'http://rdata2graph.sap.com/hilti_erp/hexagon_nut_m16x1_5#ae6b5d83-2057-4eac-829c-211a63b3d35e', 'http://rdata2graph.sap.com/hilti_erp/sticker_30_cm_hilti#0a9e9fe7-581e-4c6c-a5c8-7ae9ad040b0a']
# ------------
# Difference for src_10
# ['http://rdata2graph.sap.com/hilti_erp/cable_holder_x_jh_c_s_dni27#734cf3f6-6238-4c4b-aeec-e03ea695bfa6', 'http://rdata2graph.sap.com/hilti_erp/bracket_mft_foi_240_l_6_5#644870eb-4a36-4f54-bff4-5b790505b687', 'http://rdata2graph.sap.com/hilti_erp/dx_cartridge_6_8_11_m_bulk_green#17992c23-154a-4532-9c69-7748afa05a97', 'http://rdata2graph.sap.com/hilti_erp/toothed_gear_z_26__te6_a36avr_03_set#41dc3b1f-18b5-417f-b73b-9e08e236d0fd', 'http://rdata2graph.sap.com/hilti_erp/bevel_pinion_te6_a36avr_03_assy_set#6c8d6ebb-b138-4e55-bf8a-1b2f6a829c57', 'http://rdata2graph.sap.com/hilti_erp/set_pr_30_hsv___pra90___pua_53_slovenia#7bc28381-41cd-4c5c-b1fb-205f1111ef0a']
# ------------
# Difference for src_11
# ['http://rdata2graph.sap.com/hilti_erp/stabilizer_plate#d87e3226-f82b-4f90-8abe-698f6c24fe84', 'http://rdata2graph.sap.com/hilti_erp/measuring_rod_pua_56__in_cm_#499e7feb-dce1-49b9-b91a-71eb88773097', 'http://rdata2graph.sap.com/hilti_erp/bracket_mk_21d_300_r#0ff9ae8b-d111-412f-825f-655cd61700fc', 'http://rdata2graph.sap.com/hilti_erp/spring_nut_mn_s_m6#e481d06b-a7d1-4f05-8558-c81a712f4166', 'http://rdata2graph.sap.com/hilti_erp/protective_sleeve_10_2#01c99df5-615a-4657-8ad6-0039e811dde7', 'http://rdata2graph.sap.com/hilti_erp/label_firestop_bandage_cfs_b#2adb84ec-8a09-4d72-9a52-e3cbc51008df', 'http://rdata2graph.sap.com/hilti_erp/rating_plate_te_6_s_230v_gb#100efd62-5065-4fc4-b554-6ae29f75df38', 'http://rdata2graph.sap.com/hilti_erp/ceiling_hanger_x_hs_w_u16_p8_2m_7ft#a804da52-d812-4eb1-8c68-71f368748ac9', 'http://rdata2graph.sap.com/hilti_erp/bracket_mft_fox_h_275_m_5_assy#0225bd02-62f1-4ac7-9591-3a14fdc23214', 'http://rdata2graph.sap.com/hilti_erp/toothed_gear_z_32__sint_#14941336-a7ef-490e-b189-2aeaab3bc1d7']
# ------------
# Difference for src_12
# ['http://rdata2graph.sap.com/hilti_erp/dust_removal_system_te_drs_6_a_box#c3bf0812-c664-4dcf-9e8a-bf3f52e035a8', 'http://rdata2graph.sap.com/hilti_erp/cordless_rotary_hammer_te_10_a_220v_used#ec61c533-f78d-40a9-b2fa-e060791d973e']
# ------------
# Difference for src_13
# ['http://rdata2graph.sap.com/hilti_erp/anchor_hit_cr_316__washer_m30#5787f90d-e853-4edb-992d-a85919b4444b', 'http://rdata2graph.sap.com/hilti_erp/screw_m6x22_t27_black#6bb84e6f-79aa-41e4-a8c2-357e9a98e44f', 'http://rdata2graph.sap.com/hilti_erp/water_collector_holder_dd_hsm_s#86df033a-16a7-47b2-902b-54b997f8b44c']
# ------------
# Difference for src_14
# ['http://rdata2graph.sap.com/hilti_erp/data_cable_psa_92_usb_b#083ae2b7-e68e-4bda-92e8-5a50576fbf92', 'http://rdata2graph.sap.com/hilti_erp/measuring_extension_pda_72#e0f2835c-168f-45f0-91fc-2d253d2a8e85', 'http://rdata2graph.sap.com/hilti_erp/center_section_ds_bgf_80#74ba0074-ed2d-4bd2-9eec-83ecb82f736a', 'http://rdata2graph.sap.com/hilti_erp/center_section_ds_bgf_120#e308f681-3a57-4fee-b2e5-7887a1741bad', 'http://rdata2graph.sap.com/hilti_erp/batter_board_adapter_pra_750#a283c267-66dd-43fe-8ca6-1b300cdb936a']
# ------------
# Difference for src_15
# ['http://rdata2graph.sap.com/hilti_erp/case_te_drs_y__dust#af7cbe1f-c7e4-4747-9286-af4afcdbe801', 'http://rdata2graph.sap.com/hilti_erp/power_conditioner_dpc_20_110v_wh#e198fc3d-0517-4355-9f9c-17625f8f5de6', 'http://rdata2graph.sap.com/hilti_erp/cordless_combihammer_te_30_a36_cas#be867c7a-219d-4663-99d1-de16d8042394', 'http://rdata2graph.sap.com/hilti_erp/spring_washer_ss_m16__20_#3dd446fd-cf75-492a-a875-cc22125cd66e', 'http://rdata2graph.sap.com/hilti_erp/stator_120v_assy#8f54106a-962f-4707-8e87-8e9b4eb22bcd', 'http://rdata2graph.sap.com/hilti_erp/stator_230_240v_assy#a23137b3-a8ed-4007-8a60-d8eaadea24f3', 'http://rdata2graph.sap.com/hilti_erp/kit_te_cx__12__l1___hss_1_10__s_m__box#07565e04-3097-483c-8f9f-b69f61290ece']
# ------------
# Difference for src_16
# ['http://rdata2graph.sap.com/hilti_erp/bracket_mft_efi_600_u_11#a0f626c9-2be5-461f-bddd-cf6230362fe4', 'http://rdata2graph.sap.com/hilti_erp/tripod_adapter_pmw_30#42bbd691-0a8d-4c56-ab8b-26507057a9da', 'http://rdata2graph.sap.com/hilti_erp/dx_fastening_design_c2f#553996ea-d77e-401c-8d8e-2ecbcb7f2f9c', 'http://rdata2graph.sap.com/hilti_erp/bracket_mft_mf_060_m_6_5_s#fb8abcde-424c-4ff5-bed9-7211026c604c', 'http://rdata2graph.sap.com/hilti_erp/universal_nail_x_dni_72#6fb05590-3c4c-42d0-8edf-17e152120c0c', 'http://rdata2graph.sap.com/hilti_erp/accessory_kit_hit_profi_anchor_box#9e4fca75-4793-4126-9dea-368840ac4ef2', 'http://rdata2graph.sap.com/hilti_erp/dx460_f8_sill_plate_x_cp_booster_pkg_500#8e57e682-d656-4aba-9d87-5a11340ad72e', 'http://rdata2graph.sap.com/hilti_erp/torx_soc_ov_screw_m6x25_t30_black#d225e23f-ad92-4166-a580-6cd39ba511b0']
# ------------
# Difference for src_17
# ['http://rdata2graph.sap.com/hilti_erp/mains_adapter_pua_81#a001a5ed-fd21-4115-a200-f5b54894d2aa', 'http://rdata2graph.sap.com/hilti_erp/cutting_disc_ac_d_230f_s1#1939d41b-1f5d-4223-8ad6-4898ff3f2eae', 'http://rdata2graph.sap.com/hilti_erp/kit_te_80_atc___yp_sm___te_yx_28_52_cas#23d3dca0-8075-48bc-bdc3-0b4ffe8569ba', 'http://rdata2graph.sap.com/hilti_erp/torx_soc_re_scr_sn65_4x35_black#30717fe7-a4d4-4521-a54a-681c6a4b69c2', 'http://rdata2graph.sap.com/hilti_erp/air_duct_bracket_mva_l#86032528-00be-46f7-8fcb-8f723ebb5308', 'http://rdata2graph.sap.com/hilti_erp/kit_te_50_avr___te_yp_fm___te_yx_15_55#80588148-3830-47c8-a64d-373a39a506e5', 'http://rdata2graph.sap.com/hilti_erp/rf_screw_5x20_black#e542ab59-a033-4696-9f0e-4d798bbd6de2', 'http://rdata2graph.sap.com/hilti_erp/connecting_cable_psa_51#e9dc44b8-9649-44ff-ac5b-c3ef4ac9770c']
# ------------
# Difference for src_18
# ['http://rdata2graph.sap.com/hilti_erp/combo_200x_re_500_330___hdm500_dispenser#bd51b2fe-6f57-4049-bfb1-696b64573d51', 'http://rdata2graph.sap.com/hilti_erp/bearing_plate_assy#80f794c7-82db-48fb-865e-26b2071b35a3', 'http://rdata2graph.sap.com/hilti_erp/slotted_set_screw_m10x12#43efe5cb-2000-446f-b0ce-2b027e312cac']
# ------------
# Difference for src_19
# ['http://rdata2graph.sap.com/hilti_erp/light_duty_pipe_ring_mp_ad_m6_22#39e92c3c-df2e-4ae4-adcd-3bfda54a6f6c', 'http://rdata2graph.sap.com/hilti_erp/regulating_wheel#24e5f299-a753-463c-ad35-f6a41bb8067e', 'http://rdata2graph.sap.com/hilti_erp/kit_te_2_a___b_24_2_0_nicd__2__assy#761415e2-5549-41c5-a7f2-abdad893f2e3', 'http://rdata2graph.sap.com/hilti_erp/hexagon_nut_m33_a4_50#e99499ad-591c-439c-97db-528f385671b8']
# ------------
# Difference for tgt_0
# []
# ------------
# Difference for tgt_1
# ['http://rdata2graph.sap.com/hilti_erp/wall_mount_with_magnetic_bracket_pma_82#6e924c02-c189-4473-88b7-603c1d24e407', 'http://rdata2graph.sap.com/hilti_erp/return_pulley_dsw_w_280_pr_servicing_set#619d9d94-0dcf-4098-8e44-fd154f46fc41', 'http://rdata2graph.sap.com/hilti_erp/target_plate_poa_27_square#02346cc8-e38c-4919-9fc0-b711a3dc0066']
# ------------
# Difference for tgt_2
# ['http://rdata2graph.sap.com/hilti_erp/te_4_a22__body_5_____nov_od#63f09ec8-be84-449d-9ee9-9482ef86c99e', 'http://rdata2graph.sap.com/hilti_erp/self_tapping_screw_s_mp72s_6_3x63#2182202f-690c-404f-a772-12a9a989b635', 'http://rdata2graph.sap.com/hilti_erp/nail_magazine_x_120_gm20#6c5a52cd-8492-4410-b262-11932682344a', 'http://rdata2graph.sap.com/hilti_erp/recess_tapping_screw_4_8x38#56c12fde-56f6-4338-9428-b85dc2476a0c', 'http://rdata2graph.sap.com/hilti_erp/kit_te_4_a22___drs_4_a___b_22_3_3__2_#48d9d668-0d7f-4182-8705-8cbc0b371338', 'http://rdata2graph.sap.com/hilti_erp/recess_tapping_screw_3_9x19#c40783be-34bf-468e-99ca-165123167ccd', 'http://rdata2graph.sap.com/hilti_erp/kit_te_4_a22___sfh_22_a___b_22__2__cas#8c44c04c-6591-4778-a4f3-936a4f694225', 'http://rdata2graph.sap.com/hilti_erp/recess_tapping_screw_st3_9x16#7c525210-9935-42f9-a271-ecb05ccd01c3', 'http://rdata2graph.sap.com/hilti_erp/kit_te_4_a22___b_22_3_3_2____c_4_36_acs#aba055ce-7990-40a7-b87e-1d93526fa9b6', 'http://rdata2graph.sap.com/hilti_erp/flotte_p60m_te_4_a22___sf_22_a#b8989200-9902-4462-a642-6f5ba51181cf', 'http://rdata2graph.sap.com/hilti_erp/taptite_screw_m5x16_t20_mc#2c380656-aa65-4cc5-bef9-4015585ef7cf', 'http://rdata2graph.sap.com/hilti_erp/kit_te_4_a22___b22_3_3__2_#74dfefca-d867-427c-a837-781ebb8a8641', 'http://rdata2graph.sap.com/hilti_erp/kit_hit_re_500_500__25____te_2_a22#40b84fa6-8f7d-4aba-84c2-6157049e783b', 'http://rdata2graph.sap.com/hilti_erp/kit_te_4_a22___sf_8m_a22#d97a832d-aebf-457f-beb4-86aa3289e0ef']
# ------------
# Difference for tgt_3
# ['http://rdata2graph.sap.com/hilti_erp/flat_wrench_10mm_insert_tool#4f16f56c-c67b-4524-8394-f1bae5a2ccad', 'http://rdata2graph.sap.com/hilti_erp/pin_type_face_wrench_m14_5_8#c234184d-61c9-429d-8b51-419629ff5316', 'http://rdata2graph.sap.com/hilti_erp/rating_plate_te_75_100v_j#ad19105a-90e4-4b5e-a4ff-ef636cc16bd0', 'http://rdata2graph.sap.com/hilti_erp/side_handle__m_14__assy#f3e91522-3f74-4d82-8015-3ace09b26e60', 'http://rdata2graph.sap.com/hilti_erp/pin_type_face_wrench_b35#bbba90ba-25ef-48b4-a9ce-c2125f025022', 'http://rdata2graph.sap.com/hilti_erp/side_handle_dd_sh_30#7a87857f-25df-49d8-999c-dffbc32c920d', 'http://rdata2graph.sap.com/hilti_erp/side_handle_dd_sh_150#f0e9e174-f2b3-44c2-8292-6ee22b4ec4ac', 'http://rdata2graph.sap.com/hilti_erp/side_handle_xsag#fefead91-ab03-4b2f-9b74-ed9751cfad42', 'http://rdata2graph.sap.com/hilti_erp/impact_wrench_si_100_230v_assy#ea04c4b3-d34f-4137-a93c-34848d1c0a5c', 'http://rdata2graph.sap.com/hilti_erp/side_handle_assy#62b92546-ef15-43ef-8aaf-297d24f53ab0', 'http://rdata2graph.sap.com/hilti_erp/rating_plate_te_14_230v_ch#a74980a0-ed23-43fe-a323-ece76c36c51a', 'http://rdata2graph.sap.com/hilti_erp/rating_plate_te_700_avr_220_230v#53d13d71-543b-400e-9b54-c6e121fcf728', 'http://rdata2graph.sap.com/hilti_erp/installation_wrench_sw_24_10#e6aa49a7-7a02-421d-b9e7-66cbee489373', 'http://rdata2graph.sap.com/hilti_erp/side_handle__m10__assy#d414091f-7e68-4ce2-b4f2-69f406a1f77e', 'http://rdata2graph.sap.com/hilti_erp/angle_grinder_ws_180_220v_kl_box#c71feca8-df88-4556-8479-4d37bc7d5605', 'http://rdata2graph.sap.com/hilti_erp/angle_grinder_ws6350_110v#d0907754-a400-4bdd-b543-e1133cd1fefd', 'http://rdata2graph.sap.com/hilti_erp/side_handle_te_sh_std_2#bdc329e1-5c82-447b-9728-3ea9bb3d9d50']
# ------------
# Difference for tgt_4
# ['http://rdata2graph.sap.com/hilti_erp/hanger_clamping#cb383215-9365-4e13-a34a-a37181d1e3c3', 'http://rdata2graph.sap.com/hilti_erp/tension_lever_set#62b3f5c3-ff46-4714-a490-bf638f550be6', 'http://rdata2graph.sap.com/hilti_erp/hex_skt_hd_cap_screw_m4x12_mc#e7e467e2-9baa-4d3e-8d50-6058dec294fd']
# ------------
# Difference for tgt_5
# ['http://rdata2graph.sap.com/hilti_erp/plunging_wheel_dsw_pw_rotatable#eaae05d5-9f6c-479d-8eac-d63c562cc9e0', 'http://rdata2graph.sap.com/hilti_erp/case_wsr_1250_pe#5db0ba2e-396d-4f15-ab52-88b1c2cb8df8', 'http://rdata2graph.sap.com/hilti_erp/return_pulley_dsw_w_280_pr_assy#c3f5638b-54c0-4b44-8382-5403e412b879', 'http://rdata2graph.sap.com/hilti_erp/guide_wheel_dsw_w_280_pr_servicing_set#e97dd03d-195b-4370-aac7-92cf6d702efc', 'http://rdata2graph.sap.com/hilti_erp/guide_wheel_dsw_w_200_assy#c93d6181-ab78-481e-80c7-daf444fadf96']
# ------------
# Difference for tgt_6
# ['http://rdata2graph.sap.com/hilti_erp/torx_soc_cap_screw_m5x25#2356a0df-7977-452f-b4e9-b3340713666e', 'http://rdata2graph.sap.com/hilti_erp/torx_soc_ov_screw__sn44_5x16_mc#1d11cd62-d2e7-48de-a4d9-69b3a8c3b865', 'http://rdata2graph.sap.com/hilti_erp/filter_cartridge_inside#99c562ab-ac48-4e03-8320-b4f6afbdcde9', 'http://rdata2graph.sap.com/hilti_erp/frame_clamp_poa_73#8332f360-f3cf-478f-b439-bc7dca24b94d', 'http://rdata2graph.sap.com/hilti_erp/frame_clamp_poa_79#5c1c5baf-47ef-4da5-a40c-177f3e27cde2', 'http://rdata2graph.sap.com/hilti_erp/torx_soc_ov_screw__sn44_6x14_mc#d3911552-9a0f-4d57-9b10-addecf520dea', 'http://rdata2graph.sap.com/hilti_erp/wedge_puller_cfs_t_pul#3defae2f-9aaf-4693-8bc1-df1d93f6b2ad']
# ------------
# Difference for tgt_7
# ['http://rdata2graph.sap.com/hilti_erp/electrical_connection_eu_400v_63a#1ea8898d-7725-4b6a-963c-5717141b3488', 'http://rdata2graph.sap.com/hilti_erp/electrical_assembly_set_assy#7e7b58b8-e44d-4c07-9ae1-8c25d7c0e9df', 'http://rdata2graph.sap.com/hilti_erp/o_ring_13_94x2_62#a6c238ab-5a39-4c21-9490-d368cb9b7646', 'http://rdata2graph.sap.com/hilti_erp/crank_tripod_pua_32#2e523256-acda-438d-b3e4-809f384e2077']
# ------------
# Difference for tgt_8
# ['http://rdata2graph.sap.com/hilti_erp/gearing_ag_125_500_a_assy_packed#fefc2508-9338-47af-858d-8964ae9fd42e', 'http://rdata2graph.sap.com/hilti_erp/clamping_piece_ds_rf#1d935e1b-aa65-459f-8190-d8b31789e6da', 'http://rdata2graph.sap.com/hilti_erp/rod_adapter_te_y_rd_5_8#15ec1940-fe74-4ede-b83e-95e56f9480e5', 'http://rdata2graph.sap.com/hilti_erp/reflector_rod_poa_54_kit#c6cacf29-9280-45ea-ba1b-5731073194e2', 'http://rdata2graph.sap.com/hilti_erp/reflector_rod_poa_52#f74d1f4d-c3a7-49a1-bfed-b64b5b0adc79', 'http://rdata2graph.sap.com/hilti_erp/reflector_foil_poaw_4_set#6e8892c4-1d4e-427a-869b-712f5db2a86e', 'http://rdata2graph.sap.com/hilti_erp/sf_121_a_12_volt_3_0_nimh__3_pack_#c91319e9-954a-4bff-bf30-8b2ad1d72085', 'http://rdata2graph.sap.com/hilti_erp/kit_sf_4000_a___sf_4000#642e3959-5f6b-4dc8-9a84-e7b364f0d400', 'http://rdata2graph.sap.com/hilti_erp/kit_te_6_a___sf_144_a___b_36_3_0#4c439bed-1df2-4c43-915f-78a68ab9f69b', 'http://rdata2graph.sap.com/hilti_erp/siw_144_a___sf_144_a_p2#06a9f5b8-7661-48d6-83c9-2452940d95d1', 'http://rdata2graph.sap.com/hilti_erp/te_7_a___sf_18_a_cpc_kit#358c4b21-4ca8-40ef-bcd8-a1fc8c902714', 'http://rdata2graph.sap.com/hilti_erp/reflector_rod_poa_51#7e43e35c-ff82-4776-9413-bd98ceaf6b8d', 'http://rdata2graph.sap.com/hilti_erp/reflector_rod_poaw_50_adapter#1be2a53f-74e1-4aa5-b8f1-605d9a201bc8']
# ------------
# Difference for tgt_9
# ['http://rdata2graph.sap.com/hilti_erp/control_cable_ds_ts20_e_10m#92b608d2-d537-4f27-a5cc-3d0c11919cee']
# ------------
# Difference for tgt_10
# ['http://rdata2graph.sap.com/hilti_erp/carbon_brush_6_3x10x19_100v_120v_ao_ml#9ab8a9c3-2087-4035-b3b9-9df71ef85f05', 'http://rdata2graph.sap.com/hilti_erp/carbon_brush_100_120v#64a125bf-fbe7-4ac8-9069-11e391c904fe', 'http://rdata2graph.sap.com/hilti_erp/carbon_brush_7x12_5x26_100v_120v_ao#5b1baab4-f7e5-48dc-bf6f-11763da64ee0', 'http://rdata2graph.sap.com/hilti_erp/hex_skt_set_screw_m10x60#b675fdb3-43f4-49ca-b1ca-8e23f370bdc1', 'http://rdata2graph.sap.com/hilti_erp/hex_skt_hd_cap_screw_m8x16#374e9789-6ae2-41a3-97e2-05d966f77d67', 'http://rdata2graph.sap.com/hilti_erp/fastener_guide_x_460_f10#8fab7925-e18f-411a-906c-81bfe3c3b87b']
# ------------
# Difference for tgt_11
# ['http://rdata2graph.sap.com/hilti_erp/firestop_mortar_fs_635_40lb#be05d9e1-5dcf-4531-a831-a08ff0fc448a', 'http://rdata2graph.sap.com/hilti_erp/10_black_plastic_closure_strip[vi1_cl10#3f5a8056-2cc4-42d8-9fc9-d48bd54a64f7', 'http://rdata2graph.sap.com/hilti_erp/foamed_plastic_strip#8be8be83-0907-4cba-b42a-3823834873b1', 'http://rdata2graph.sap.com/hilti_erp/ejot_screw_3x18_t10_black#f88f9f1b-00a8-49c8-98e7-600157fbc356', 'http://rdata2graph.sap.com/hilti_erp/firestop_plaquette_de_conformit__be#8ca02836-d2a6-48dd-844e-09c14207c1f8', 'http://rdata2graph.sap.com/hilti_erp/firestop_cushion_cp_652_aud#a591f4a4-f48b-4310-8e15-94667fbe18ec', 'http://rdata2graph.sap.com/hilti_erp/firestop_sealant_cp_604_5_ga#92ba3995-a9d5-4ec6-b138-74263199c93d']
# ------------
# Difference for tgt_12
# ['http://rdata2graph.sap.com/hilti_erp/pan_head_screw_m6x16_mc#10c86e03-6a62-4a89-bb7f-437bb3cb2c94', 'http://rdata2graph.sap.com/hilti_erp/hex_skt_hd_cap_screw_m6x65#025bf54e-8998-4919-ab94-0b707fedc8d8', 'http://rdata2graph.sap.com/hilti_erp/hex_skt_hd_cap_screw_m6x25#4ca3bf61-7764-47a5-877a-282701941673']
# ------------
# Difference for tgt_13
# ['http://rdata2graph.sap.com/hilti_erp/telescopic_staff_pa_951__cm_#d5aa9ba3-737b-44b4-9f67-ee6f26b20279', 'http://rdata2graph.sap.com/hilti_erp/drilling_stand_dd_st_30#52d186ed-1fb1-4e44-8277-7339cd0cd9b0', 'http://rdata2graph.sap.com/hilti_erp/data_cable_pow_95#6a54a6e3-dca1-42a1-a086-acd60f1ff7a1', 'http://rdata2graph.sap.com/hilti_erp/pivoting_guard_scm_assy_packed#199b0daa-63e5-405d-85d8-ac8114f086e8', 'http://rdata2graph.sap.com/hilti_erp/frame_clamp_poa_76#97e9ffe9-0e7a-4bc2-8d3b-180ef692aac1', 'http://rdata2graph.sap.com/hilti_erp/setting_plate_s_assy#028bfa15-cb60-40b0-b443-b163fdd859d1', 'http://rdata2graph.sap.com/hilti_erp/drilling_stand_dd_st_160_sfl#b5717606-dfc7-42ee-bfff-698505c074fb', 'http://rdata2graph.sap.com/hilti_erp/pivoting_guard_scw_wsc#b98efce7-294a-44fb-9351-c18484bd9ca4', 'http://rdata2graph.sap.com/hilti_erp/coupling_sleeve_te_6_a36_avr_03_set#bfb48b2a-5375-4e73-bbc6-248b9e11b5ff', 'http://rdata2graph.sap.com/hilti_erp/setting_tool_hda_m12#ea50aeb0-9118-43a9-b2e9-c8d8cd832b42', 'http://rdata2graph.sap.com/hilti_erp/drilling_stand_dd_st_120_sts#023c4ef5-7e2c-4dc3-8b13-7b03079194bf', 'http://rdata2graph.sap.com/hilti_erp/cutting_disc_eqd_spx_305_22_mas_#a090ecda-7780-4400-8bfa-567952168d4c', 'http://rdata2graph.sap.com/hilti_erp/setting_rod_assy#481e52ee-020a-4c59-94c1-ddf3870c911b', 'http://rdata2graph.sap.com/hilti_erp/transit_frame_cfs_t_ss_6x5_al#c00663af-cf2b-468b-af24-3a0063404537']
# ------------
# Difference for tgt_14
# ['http://rdata2graph.sap.com/hilti_erp/protective_sleeve_dag_dcg_180_230#50a4301a-7ac6-4736-a793-986a69c26ab2', 'http://rdata2graph.sap.com/hilti_erp/protective_sleeve_12#1273c1f0-1829-46de-af58-e5ff894c5ece', 'http://rdata2graph.sap.com/hilti_erp/protective_glass_scm_assy_packed#f7cf51cb-c9dc-45aa-aa48-1414d0953a94', 'http://rdata2graph.sap.com/hilti_erp/protective_cover_dsw_wg_30_kit#7703da67-1988-43bc-8b16-7614715b5105']
# ------------
# Difference for tgt_15
# ['http://rdata2graph.sap.com/hilti_erp/case_gx_3_typ_039#1cba226b-26fd-4d22-a4af-a04a4eb47e91', 'http://rdata2graph.sap.com/hilti_erp/diamond_cutting_disc_db_dm1_12x_125x20mm#e625c12b-7e58-4f13-809c-15167fb2a4f8', 'http://rdata2graph.sap.com/hilti_erp/case_te_905_avr_typ_47#a69ee52b-2b81-4fbf-9d65-791c3e14a437', 'http://rdata2graph.sap.com/hilti_erp/fastener_guide_dx_351_bt_tq_037#e63d3660-f411-4f23-b065-bd5d58b97f30', 'http://rdata2graph.sap.com/hilti_erp/double_sided_cutting_guard_180#535d3520-f429-49b9-a898-78317dbf1e84', 'http://rdata2graph.sap.com/hilti_erp/case_te_60_typ_37_#6a55c8ec-75e6-463c-b99d-277b93d44156', 'http://rdata2graph.sap.com/hilti_erp/diamond_cutting_disc_dd_125_pw#60c200be-f9fe-4195-920a-b10774c284bb', 'http://rdata2graph.sap.com/hilti_erp/install__channel_mq_41_f_2_m#cbf8c95f-177c-4ea1-9a74-41d5c6b0c32d', 'http://rdata2graph.sap.com/hilti_erp/__cutting_edge_right#44f7e52e-9a24-4311-8563-6c33a19bc2c8', 'http://rdata2graph.sap.com/hilti_erp/diamond_cutting_disc_dc230m#dd771fad-106e-469a-8b67-5f25a078815a', 'http://rdata2graph.sap.com/hilti_erp/case_te_1000_avr__typ047#ce9b6625-081e-409c-a506-eb493ee755ba', 'http://rdata2graph.sap.com/hilti_erp/marker_pen_pua_70_set#8b6676b3-b2e9-486b-bb38-e4d9190cc53e', 'http://rdata2graph.sap.com/hilti_erp/case_te_16_c_typ_17#3ea05356-86e6-4134-9df7-2c08afc1e0ce', 'http://rdata2graph.sap.com/hilti_erp/case_te_60_atc_typ_37_#d45251ef-ff0f-4018-bbca-36f5165a097e', 'http://rdata2graph.sap.com/hilti_erp/case_te_6_s_typ_17#8af16410-740e-4c22-bd24-6f0126a21d93']
# ------------
# Difference for tgt_16
# ['http://rdata2graph.sap.com/hilti_erp/rubber_washer_set#6d196cd5-0358-4065-a184-5006acebf5b2', 'http://rdata2graph.sap.com/hilti_erp/adjusting_lever_set#a807c3f9-5733-4ab2-b872-3c873db7b7fa', 'http://rdata2graph.sap.com/hilti_erp/accessory_kit_vc_20_40#6c16c9d6-289d-471b-a0a4-87b9ad591f2e', 'http://rdata2graph.sap.com/hilti_erp/chiselling_handle_assy#40a6af39-cb72-44a6-803d-7d213f143e54', 'http://rdata2graph.sap.com/hilti_erp/single_pair_pulley_dsw_spp_pr#9b95024c-9d90-4ca2-bc26-35f15e894b65', 'http://rdata2graph.sap.com/hilti_erp/feather_key_b_4x4x7#924e7789-f852-42af-aec5-534d02758e5c', 'http://rdata2graph.sap.com/hilti_erp/target_plate_pma_55__in___3_#c82575f8-0c03-48aa-9ecc-50caf7661428', 'http://rdata2graph.sap.com/hilti_erp/feather_key_a_4x4x10#51094cfd-dcbd-44e8-9514-03b7898345e5', 'http://rdata2graph.sap.com/hilti_erp/accessory_kit_dx_460_f10#ab9c6c0d-39e8-43c0-98d8-8e2d599a7893', 'http://rdata2graph.sap.com/hilti_erp/stylus_pen___tether_pow_94#4ba4aff2-38f8-4d9c-91b7-a78976aefd98', 'http://rdata2graph.sap.com/hilti_erp/feather_key_a_4x4x11#2123da5c-ef74-46f3-9944-20fbd80f97ac', 'http://rdata2graph.sap.com/hilti_erp/s_te_70_avr_starter_pack#b45e7e46-2ffd-4663-9f20-4282fc879793']
# ------------
# Difference for tgt_17
# ['http://rdata2graph.sap.com/hilti_erp/guide_plate_wsc_3xx_assy#806409cc-3a2c-4158-9a25-4a9e7a0fbd0f', 'http://rdata2graph.sap.com/hilti_erp/side_plate_ds_ws_spp_280_fix_left#c9d59a22-284a-49d5-a7d2-2b16dd0198dd', 'http://rdata2graph.sap.com/hilti_erp/hand_guard_packed#92b833f3-8560-4e46-b4e1-7ed331339a63', 'http://rdata2graph.sap.com/hilti_erp/target_plate_pda_50#da4846d4-9ffd-455e-b314-cb83a956ac97', 'http://rdata2graph.sap.com/hilti_erp/guide_plate_gx_2_assy#a9069e5f-899a-437a-ba6e-a088b907af41', 'http://rdata2graph.sap.com/hilti_erp/toothed_gear_z_26#b0a070e4-3997-4d44-8544-dca5d6bc2f38', 'http://rdata2graph.sap.com/hilti_erp/fs_identification_plate_us#fd64ce7b-cb0d-492e-a73d-e8fd4caf6470', 'http://rdata2graph.sap.com/hilti_erp/setting_rod_schalter#1b464534-9351-49f7-a558-c0d6b55c0fe6']
# ------------
# Difference for tgt_18
# ['http://rdata2graph.sap.com/hilti_erp/torx_soc_csk_head_scr_hlc_sk_m8x88#ae25cc09-adfd-4e71-bb28-94b488528599', 'http://rdata2graph.sap.com/hilti_erp/universal_nail_x_u_42_s36#23566ab1-4f69-4da8-8123-7bb2bfcd6ea5']
# ------------
# Difference for tgt_19
# ['http://rdata2graph.sap.com/hilti_erp/torx_soc_ov_screw_m6x25_mk_t30_black#dd314388-7c0f-4da0-bd0c-c789bd60c888', 'http://rdata2graph.sap.com/hilti_erp/tec_3_piece_chisel_pack_[30219_3022_2047#af85400d-98b9-4d60-a807-9b7cf060ac8c', 'http://rdata2graph.sap.com/hilti_erp/plastite_screw_45_5x35_t25_black#3181eb35-b288-4742-8652-0c1e54dd2ecb', 'http://rdata2graph.sap.com/hilti_erp/electronics_100v_120v_et_packed#8d2253aa-9750-48a3-ac34-4ce9f7626a7a', 'http://rdata2graph.sap.com/hilti_erp/taptite_screw_2000_sn40_6x70#240e6494-85ad-41b2-8802-95040e2153d2', 'http://rdata2graph.sap.com/hilti_erp/electronics_24v_packed#b1fd9385-e225-4af9-a0e8-e2ec531ea8e8', 'http://rdata2graph.sap.com/hilti_erp/plastite_screw_45_5x16#cb6f9ec1-0546-4fd8-830d-edc514ea22dc', 'http://rdata2graph.sap.com/hilti_erp/taptite_screw_m4x10_t20_mc#ac0b19c3-e047-4eb6-88c6-9549d139d1d5', 'http://rdata2graph.sap.com/hilti_erp/plastite_screw_45_6x40__t25#85fee2d5-ced7-404e-a530-d2709c3f4f6b']

# %%
out = list()
for header in ['src_'+str(i) for i in range(round((len(df.columns)-12)/2))] + ['tgt_'+str(i) for i in range(round((len(df.columns)-12)/2))]:
    dimlist_x = list()
    dimlist_y = list()
    for header2 in ['src_'+str(i) for i in range(round((len(df.columns)-12)/2))] + ['tgt_'+str(i) for i in range(round((len(df.columns)-12)/2))]:
        if not header2 == header:
            tmp = df.sort_values(by=[header2], ascending=False)
            dimlist_y = dimlist_y + (tmp[:10]['src_id'].tolist() + tmp[-10:]['src_id'].to_list() + tmp[round(len(tmp)/2)-5:round(len(tmp)/2)+5]['src_id'].to_list())
        else:
            tmp = df.sort_values(by=[header2], ascending=False)
            dimlist_x = dimlist_x + (tmp[:10]['src_id'].tolist() + tmp[-10:]['src_id'].to_list() + tmp[round(len(tmp)/2)-5:round(len(tmp)/2)+5]['src_id'].to_list())
    
    o = compute_diff(dimlist_x, dimlist_y, header)
    out.append(o)
    print("\n".join(list(set(o))))
# Out:
# ------------
# Difference for src_0:
# http://rdata2graph.sap.com/hilti_erp/#36244972-d63a-4c14-a0d4-685b9b890e35
# http://rdata2graph.sap.com/hilti_erp/toothed_gear_z_29#721a42e8-b48f-4e78-9665-a9d028478ff8
# http://rdata2graph.sap.com/hilti_erp/gear_housing_assy#64a13cbf-b805-44b4-90c8-d9019ba4dc54
# http://rdata2graph.sap.com/hilti_erp/centering_bushing#4b60d26d-2990-43c4-b2ae-179d2dc30ba0
# z29
# engin
# http://rdata2graph.sap.com/hilti_erp/insulating_washer#9b39e49b-7f4c-4840-808e-44497c74c56b
#
# ------------
# Difference for src_1:
# http://rdata2graph.sap.com/hilti_erp/wire_size_bit__47_12_bx_[vc12_3d_x_207sp#637328f9-ef5a-4a76-b770-94dabcb51fee
# http://rdata2graph.sap.com/hilti_erp/#fe1a5b9d-3603-4b71-a869-6b1119930022
# http://rdata2graph.sap.com/hilti_erp/#e87177ec-4aa5-44e2-8909-2cc7b99dbe6a
# s_6770_2
# 2day
# size
# http://rdata2graph.sap.com/hilti_erp/fastening_set_hvu_m20___has_e_r#f63b0be0-c74e-4553-888c-b3c9fd2410e7
# hvu
# http://rdata2graph.sap.com/hilti_erp/#90672adb-780b-4439-9d85-420d108a17ba
# [vc123dx207sp
# http://rdata2graph.sap.com/hilti_erp/#1a0f590d-127d-4be7-a071-776180f151bb
# http://rdata2graph.sap.com/hilti_erp/kit_wsr_900_pe___w_csr_cas#09bc6107-0f42-494f-ac82-a67d37869ef0
# wcsr
# 12bx
# m20
# 900pe
# haser
#
# ------------
# Difference for src_2:
# http://rdata2graph.sap.com/hilti_erp/#b7e37c80-974d-4a43-a498-c1898050576d
# 88uhdg
# lid
# mftbit
# http://rdata2graph.sap.com/hilti_erp/truss_head_bolt_m10_x_20__grade_8_8u_hdg#cc56c94c-16f2-4483-a81a-f22e6a845c61
# http://rdata2graph.sap.com/hilti_erp/#1230819d-d1ec-44c3-a3d9-95c379396a4a
# http://rdata2graph.sap.com/hilti_erp/side_handle_270_assy#b3d19247-84ba-489d-9cbe-dd7b48bd9b08
# http://rdata2graph.sap.com/hilti_erp/lid_220_240v_assy#cae210a7-3130-4123-8961-1b8c708685a4
# http://rdata2graph.sap.com/hilti_erp/socket_wrench_insert_mft_bit_sq#f0d152ea-7c4e-4cc9-9f7f-c95dbd688d6a
# 270
# http://rdata2graph.sap.com/hilti_erp/electric_plug_250v_16a_te_kpl_grip#b227f888-2123-4b91-a5f5-c845fdf2531a
# hdg
# 250v
# socket
# http://rdata2graph.sap.com/hilti_erp/#58e289f9-451f-4e25-8edf-fc1810b03b2e
# 16m
# http://rdata2graph.sap.com/hilti_erp/#b26a0b1b-34db-409a-b47a-36f0bef7b07e
# http://rdata2graph.sap.com/hilti_erp/grip_unit_wsr_assy#3bc063f7-4896-4c6a-958c-5c44d4f25413
# 16a
# kpl
# http://rdata2graph.sap.com/hilti_erp/rating_plate_te_16_m_120v_usa#29621c8a-243f-4fdf-9a20-5697d60d49a7
# http://rdata2graph.sap.com/hilti_erp/#f9f95cb0-6e98-4479-a60a-75b66f0c8139
# sq
# grade
# 220240v
# truss
# http://rdata2graph.sap.com/hilti_erp/identification_plate_qr_us#45e0c6e1-b850-4aa4-89cc-a75cfcefaed2
#
# ------------
# Difference for src_3:
# 60_03
# 135
# http://rdata2graph.sap.com/hilti_erp/s_pack_metal_cutting_disc_100_7#b0e2fc41-0715-4f49-b956-baf55fe16b70
# 534
# http://rdata2graph.sap.com/hilti_erp/#9e624353-a371-4328-ac12-2ae3f2f212da
# mine
# http://rdata2graph.sap.com/hilti_erp/bevel_pinion_te_60_03_packed#ed5f8029-72d5-4723-abd8-341a990d1704
# ug
# tubeschuck
# spack
# sme
# 70atcavr
# http://rdata2graph.sap.com/hilti_erp/#cf1dff63-595b-4981-b003-6fd70ac7057f
# smfmfoot
# 70atcteyx
# http://rdata2graph.sap.com/hilti_erp/#58081b09-f38b-4a14-9a54-b1cb786cbb35
# http://rdata2graph.sap.com/hilti_erp/extension_tube_sme_assy#d4e4efcb-b7d2-48b1-a49f-f9f0bb4e6a74
# http://rdata2graph.sap.com/hilti_erp/#51090743-92eb-4bfd-a64d-e8ceaecfd0fe
# http://rdata2graph.sap.com/hilti_erp/extension_tube_200_assy#5b41f3e0-d341-44f9-abba-f74d5d97e850
# http://rdata2graph.sap.com/hilti_erp/#611777f6-6992-4ccf-bb05-5b36a7b8072e
# http://rdata2graph.sap.com/hilti_erp/#919818aa-5b3b-4dbf-9f5d-39a55f332811
# http://rdata2graph.sap.com/hilti_erp/#270215ab-55b3-4fb0-909d-d66c867044b9
# tem
# http://rdata2graph.sap.com/hilti_erp/kit_te_70_atc_te_yx_22_te_yp_sm_fm_foot#37a3d384-0251-4500-9d6a-62879b897754
# 22teyp
# up
# 115
# http://rdata2graph.sap.com/hilti_erp/#8db86851-314d-42d7-af42-961746434044
# http://rdata2graph.sap.com/hilti_erp/cutting_disc_ac_d_115_stnls_#aa68c4ce-7bf6-4d53-a728-6b52ef93c87e
#
# ------------
# Difference for src_4:
# dswsthi
# http://rdata2graph.sap.com/hilti_erp/metal_anchor_hb_m8#ece9f5f5-0661-42c8-a1c8-337f7f56750e
# sl12
# z27
# hx4
# 3001500
# fm
# tp22
# http://rdata2graph.sap.com/hilti_erp/kit_dd_150_bidon_sac_f_t_x_ring_112_320#b5b25b42-15ac-4101-9677-faa75737de8c
# xring
# http://rdata2graph.sap.com/hilti_erp/crimping_pliers_ds_wsthy#63fbe04e-6903-43b7-bfe6-cb1c7b6fd8d6
# crimp
# bs
# 3ft
# http://rdata2graph.sap.com/hilti_erp/kit_dd_bs_300_1500_hx4s#cf38b13d-23c1-436f-a70f-47b34db11b15
# http://rdata2graph.sap.com/hilti_erp/o_ring_9_19x2_62#181b008c-9803-4320-a0fc-d93c08d12cf0
# narrowflat
# http://rdata2graph.sap.com/hilti_erp/#01742855-eae2-45e9-b400-9e62be824636
# ssd
# http://rdata2graph.sap.com/hilti_erp/coupler_magnet_assy#40a3bfe4-acdb-4292-80a0-23228fff4ffa
# coupler
# http://rdata2graph.sap.com/hilti_erp/#26a8251e-dd60-44c8-ae73-cfaf1b5e1aa9
# plier
# http://rdata2graph.sap.com/hilti_erp/#8bde58bb-6c5f-43b7-985f-ed48e22c50cd
# http://rdata2graph.sap.com/hilti_erp/bevel_gear_z_27#c28bf21a-311f-440c-96aa-0681039ee199
# 919x262
# 112320
# ct351
# http://rdata2graph.sap.com/hilti_erp/#9dc13708-4570-4dc7-9505-726088ff3e5b
# http://rdata2graph.sap.com/hilti_erp/#6a4ed052-53fe-41a1-b156-a91b674fc9fd
# http://rdata2graph.sap.com/hilti_erp/kit_dd_150_u___s_sd_sl1_2_x_7_0#4652d0fc-098c-42c6-8ba8-ba12a233a8ff
# m8
# wet
# http://rdata2graph.sap.com/hilti_erp/narrow_flat_chisel_tp_22_fm_50_assy#1abdbb66-8a1d-4f44-8b10-a9e62e2c0500
# clutch
# 150bidonsacft
# hb
# http://rdata2graph.sap.com/hilti_erp/#037bc32a-6936-4606-a105-e03a19508108
# http://rdata2graph.sap.com/hilti_erp/dag_100_grinding_disc_package_100_7#119dcf01-ddf8-4769-ba21-c5bf82dcfa0a
# http://rdata2graph.sap.com/hilti_erp/extension_tube_x_pt_ct_351_3ft#9f6672fc-f37e-4436-b926-8f2e8505b2c5
#
# ------------
# Difference for src_5:
# 35
# http://rdata2graph.sap.com/hilti_erp/drywall_screw_6_x_1_5_8_pbh_sd_zinc#7d176a7e-dd2b-4691-9a91-fcbdbd486c31
# ddwcshh150
# http://rdata2graph.sap.com/hilti_erp/case_dx_36_typ_7#d91fe1a1-0d25-41d9-8535-3a0817d46ac3
# drywal
# snapin
# ddhd30wch
# xcc
# http://rdata2graph.sap.com/hilti_erp/#2f5cfbd7-a359-42da-a0cd-e548b873e71b
# http://rdata2graph.sap.com/hilti_erp/water_collector_holder_dd_st_150_160_wch#59e168e2-30f7-44d6-9464-5a17423006df
# http://rdata2graph.sap.com/hilti_erp/water_collector_holder_dd_wcs_hh_150#1c4ed5b7-41a5-4d31-b14c-240d6274cdee
# 4
# http://rdata2graph.sap.com/hilti_erp/water_collector_holder_dd_hd30_wch#b7c894e1-7333-43b6-b24d-44813b238870
# ddst150160wch
# http://rdata2graph.sap.com/hilti_erp/gearing_te_80_atc_avr_assy#ddbfe019-e430-4e3f-97f9-a97afe31806b
# 7ft
# mppl
# http://rdata2graph.sap.com/hilti_erp/pole_tool_x_pt_351_7ft_assy#5f6cdb5d-1650-4bd8-b3a5-3fc9458c62e4
# http://rdata2graph.sap.com/hilti_erp/ceiling_hanger_x_cc_mx_4_12ga#c3a29976-6543-41ce-b415-8923158ef1b5
# http://rdata2graph.sap.com/hilti_erp/locking_snap_in_clip_mp_pl_20#4536af19-aca4-4d9c-ba80-93cc384bd919
# http://rdata2graph.sap.com/hilti_erp/#75acb7fd-6caf-479c-9d8d-d166b948321d
# http://rdata2graph.sap.com/hilti_erp/#a18dba39-aae4-437a-8adf-6d2041195754
# 007
# http://rdata2graph.sap.com/hilti_erp/#cbb49414-8f3c-4a20-9dc2-a8452697cf34
# 12ga
# http://rdata2graph.sap.com/hilti_erp/pole_tool_x_pt_35_7ft_assy#1b383f5e-723d-4f88-b93e-ed03794ed95e
# clip
#
# ------------
# Difference for src_6:
# dx36m
# retip
# http://rdata2graph.sap.com/hilti_erp/wsr_22_a_case_set_3_3ah__2_#b5ec8a3a-8e24-4a03-a097-d7c25bac738d
# http://rdata2graph.sap.com/hilti_erp/wall_saw_blade_ds_b_750_rc_retipped#b26d311e-ab57-4623-a924-3d8328f502a7
# rc
# http://rdata2graph.sap.com/hilti_erp/#a34a6c41-4c08-4a1f-8ac9-02964ed53398
# piston
# http://rdata2graph.sap.com/hilti_erp/vacuum_cleaner_dc_pp_25___1400spe#00bdab45-6f9c-4b83-a729-da63ac2e32d8
# 1400spe
# http://rdata2graph.sap.com/hilti_erp/connector_housing_ul_assy_packed#e73f69e3-9a09-4e26-b3f6-0b6c791d502c
# http://rdata2graph.sap.com/hilti_erp/#a21a4a78-f2da-4750-83f7-16f7fd3415d7
# 76atc
# http://rdata2graph.sap.com/hilti_erp/#85a37200-e1d2-484f-ad5d-bdb9b2392f8a
# http://rdata2graph.sap.com/hilti_erp/backplate_gx_120_packed#13256ed7-a7c9-41c2-beee-8f92273a655e
# http://rdata2graph.sap.com/hilti_erp/#be661d06-391c-4537-aa3a-e76c1fb5f502
# http://rdata2graph.sap.com/hilti_erp/connection_end_dd_bs#3849e74f-33a3-45d3-bbed-fe7e2a21e795
# 33ah
# pp
# http://rdata2graph.sap.com/hilti_erp/#ef03d475-803f-470d-8e80-62cf889761aa
# http://rdata2graph.sap.com/hilti_erp/slotted_wood_screw_4x30#daf507f4-41f8-4ffe-b5c4-f40490184b9a
# http://rdata2graph.sap.com/hilti_erp/piston_guide_dx36m_packed#dfeb23fe-102a-46e9-b0b6-ce2f786b4314
# http://rdata2graph.sap.com/hilti_erp/rating_plate_te_76_atc_110v_tw#1cd99e84-6c4e-46b7-94c4-8c67e84767c9
# http://rdata2graph.sap.com/hilti_erp/wall_saw_blade_ds_b_1000_24_cl_nbm#692ee1f4-9bcb-4992-82cb-07ceaef8bb51
# http://rdata2graph.sap.com/hilti_erp/#20a49c56-bc08-4480-8591-36ef649f8e84
# backplat
# 100024clnbm
# tw
# ------------
# Difference for src_7:
# cf126
# 5x5
# http://rdata2graph.sap.com/hilti_erp/cylindrical_roller_5x5#9eb6622c-1bbb-4437-b0dd-7b763933842b
# http://rdata2graph.sap.com/hilti_erp/operating_instructions_tdr_p3#eaaa1a69-e7b4-4d55-9eee-638989e61d72
# me
# plumbr
# tdr
# http://rdata2graph.sap.com/hilti_erp/install__channel_mq_41_f_2_2_m#c1bc6a00-bc1c-494a-8f7c-a957c764d527
# z24
# http://rdata2graph.sap.com/hilti_erp/me_and_plumbring_pack_7__cf126_#21eeb807-1277-4bd2-9205-908082484280
# http://rdata2graph.sap.com/hilti_erp/toothed_gear_z_24#9d820b5e-8b48-4cfc-a037-3cdc13e93587
#
# ------------
# Difference for src_8:
# http://rdata2graph.sap.com/hilti_erp/kit_te_1___dag_125_s#b1182a79-be2e-4c58-ae67-b3afae5c9008
# p
# do
# http://rdata2graph.sap.com/hilti_erp/torx_soc_re_scr_4x20_black#985bbf19-a403-4aca-9409-63bbf6f3a64d
# carri
# 4x20
# zn
# http://rdata2graph.sap.com/hilti_erp/amoladora_dag_125_s___kit_de_trabajo_seg#3d5c5397-9de0-4b32-bae2-f16ccb83f0c2
# seg
# http://rdata2graph.sap.com/hilti_erp/cartridge_holder_hit_cb_500#cab2a3f1-ff3f-423f-b8bd-560d7adad794
# http://rdata2graph.sap.com/hilti_erp/#7ab71789-5ae9-4489-9a44-a7a1bdc2f20f
# chees
# http://rdata2graph.sap.com/hilti_erp/#c4fc350c-9a80-4389-b322-5a94f49fa28e
# x351f8ct
# handel
# http://rdata2graph.sap.com/hilti_erp/insulating_connector#1f0f8cf6-75f9-491b-98ac-8ec72814291d
# bag
# 125se
# http://rdata2graph.sap.com/hilti_erp/#050bb044-789d-44f1-a420-fddb4154cc22
# quicklock
# amoladora
# standard
# more
# hitcb
# http://rdata2graph.sap.com/hilti_erp/#f2d6ba04-4357-4de6-b948-6f9ad388bb5b
# http://rdata2graph.sap.com/hilti_erp/tripod_bag_pua_44#6972deb8-d4c3-43f2-aada-67546bb0262c
# http://rdata2graph.sap.com/hilti_erp/#f9b5593c-0bd2-4dd0-8966-a957aa18b4bf
# http://rdata2graph.sap.com/hilti_erp/#beab0da6-2e1d-4c5e-8047-62470c35eb16
# sl
# trabajo
# m5x75
# fm48
# http://rdata2graph.sap.com/hilti_erp/fastener_guide_x_351_f8ct#a95f6108-2c39-4608-a674-c3878eeec347
# http://rdata2graph.sap.com/hilti_erp/#7e3ed40d-04c5-4dc9-91fd-a8334ab88419
# http://rdata2graph.sap.com/hilti_erp/fm48_p_dag_125_se_230v_quick_lock#c9715e55-ba2a-4761-bec3-64743ca0e8b7
# http://rdata2graph.sap.com/hilti_erp/#681a8bbd-b748-4305-80af-071d5c5b2934
# http://rdata2graph.sap.com/hilti_erp/sl_cheese_head_screw_m5x75_zn#f53ed383-bbdb-48b2-bc2c-b15fc643ac39
# ani
#
# ------------
# Difference for src_9:
# http://rdata2graph.sap.com/hilti_erp/#58b24062-c188-4316-9bda-93e4d7a4a3f5
# http://rdata2graph.sap.com/hilti_erp/hardmetal_tip_18__x_form#98cb9cba-3ea9-49f1-8a3d-637cf0cafddc
# wrcca
# http://rdata2graph.sap.com/hilti_erp/remote_control_ds_rc_ts20#9a940a8f-92a1-46b3-afd5-ab9a9dbcdec0
# namepl
# hilti
# http://rdata2graph.sap.com/hilti_erp/remote_control_dst_wrc_ca_ul_assy#6d91b6ba-4ded-4476-accf-4e3e26aa6ba8
# http://rdata2graph.sap.com/hilti_erp/hexagon_nut_m16x1_5#ae6b5d83-2057-4eac-829c-211a63b3d35e
# m24su
# cfspl
# m10x30
# sn140
# 18
# http://rdata2graph.sap.com/hilti_erp/#a4c6adcd-2a07-4526-938e-e08838c48f94
# dst
# http://rdata2graph.sap.com/hilti_erp/hex_skt_hd_cap_screw_m8x45_a4_70#e88f5da1-6372-49f8-aae9-4cd0a7d0aa24
# 316
# m12
# http://rdata2graph.sap.com/hilti_erp/firestop_plug_cfs_pl_158#dd355de5-406c-4eaa-9fb8-29cbbc220422
# m8x45
# http://rdata2graph.sap.com/hilti_erp/#90094b65-d4ec-4920-bf9f-f838a4bb4719
# http://rdata2graph.sap.com/hilti_erp/hexagon_nut_m12_zinced#6ebcbae2-1b45-43ea-b0a6-b44b172dd2e4
# http://rdata2graph.sap.com/hilti_erp/anchor_rod_hit_c_nut_m24_sus_316_#e4108e5f-18f2-47bc-bc61-4200b7a6a0b6
# http://rdata2graph.sap.com/hilti_erp/washer_holder_x_120_wh#51b4b008-38eb-41a5-98be-c8515fb33cef
# http://rdata2graph.sap.com/hilti_erp/hexagon_nut_m12__din_980__kl10_verzinkt_#5fd7b52f-abcf-4827-bcfd-5b9a986dff70
# http://rdata2graph.sap.com/hilti_erp/sticker_30_cm_hilti#0a9e9fe7-581e-4c6c-a5c8-7ae9ad040b0a
# xform
# advertis
# 158
# hardmet
# http://rdata2graph.sap.com/hilti_erp/torx_soc_tapt_scr_m10x30__sn140_black#ff37b0e9-6411-4559-bdf3-d3f0f8da278d
# din
# http://rdata2graph.sap.com/hilti_erp/bevel_pinion_packed#dc807012-59ba-4e04-85b3-626c7abbeeea
# verzinkt
# 658
# kl10
# rcts20
# m16x15
# t
# http://rdata2graph.sap.com/hilti_erp/#d42e4e7d-121c-421a-882c-6588495ac17a
# tip
# 980
#
# ------------
# Difference for src_10:
# http://rdata2graph.sap.com/hilti_erp/bracket_mft_foi_240_l_6_5#644870eb-4a36-4f54-bff4-5b790505b687
# pra90
# http://rdata2graph.sap.com/hilti_erp/#6c76bf70-225e-4cc0-ba79-2f06c7402bac
# http://rdata2graph.sap.com/hilti_erp/dx_cartridge_6_8_11_m_bulk_green#17992c23-154a-4532-9c69-7748afa05a97
# 30hsv
# 240
# http://rdata2graph.sap.com/hilti_erp/#003076bf-acf7-4385-b812-a9f6ae6e578d
# http://rdata2graph.sap.com/hilti_erp/#d97bf076-96fa-4e9f-ba18-e69ba5585755
# xjhc
# http://rdata2graph.sap.com/hilti_erp/#23b2c4e8-6160-4118-8268-e6761aaa8726
# te6a36avr
# mftfoi
# http://rdata2graph.sap.com/hilti_erp/toothed_gear_z_26__te6_a36avr_03_set#41dc3b1f-18b5-417f-b73b-9e08e236d0fd
# 30hv
# http://rdata2graph.sap.com/hilti_erp/cable_holder_x_jh_c_s_dni27#734cf3f6-6238-4c4b-aeec-e03ea695bfa6
# dni27
# xjh
# jay
# 229
# http://rdata2graph.sap.com/hilti_erp/bevel_pinion_te6_a36avr_03_assy_set#6c8d6ebb-b138-4e55-bf8a-1b2f6a829c57
# http://rdata2graph.sap.com/hilti_erp/set_pr_30_hsv___pra90___pua_53_slovenia#7bc28381-41cd-4c5c-b1fb-205f1111ef0a
# green
# l
# http://rdata2graph.sap.com/hilti_erp/#1f91073b-4712-4a75-ba6e-0c13d7ccd55f
# http://rdata2graph.sap.com/hilti_erp/#bdf700df-032b-4f58-99f5-4ff66c556b71
# slovenia
# 6811
# 53
#
# ------------
# Difference for src_11:
# http://rdata2graph.sap.com/hilti_erp/stabilizer_plate#d87e3226-f82b-4f90-8abe-698f6c24fe84
# 2m7ft
# incm
# z32
# bandag
# h
# http://rdata2graph.sap.com/hilti_erp/label_firestop_bandage_cfs_b#2adb84ec-8a09-4d72-9a52-e3cbc51008df
# std
# http://rdata2graph.sap.com/hilti_erp/bracket_mft_fox_h_275_m_5_assy#0225bd02-62f1-4ac7-9591-3a14fdc23214
# http://rdata2graph.sap.com/hilti_erp/toothed_gear_z_32__sint_#14941336-a7ef-490e-b189-2aeaab3bc1d7
# xhsw
# 275
# http://rdata2graph.sap.com/hilti_erp/spring_nut_mn_s_m6#e481d06b-a7d1-4f05-8558-c81a712f4166
# 21d300r
# http://rdata2graph.sap.com/hilti_erp/ceiling_hanger_x_hs_w_u16_p8_2m_7ft#a804da52-d812-4eb1-8c68-71f368748ac9
# u16
# tie
# http://rdata2graph.sap.com/hilti_erp/#c31caa11-a0d0-4622-926e-b624684c4715
# http://rdata2graph.sap.com/hilti_erp/#f8ca3b43-2e06-4dc8-a8e8-eb462d78cea1
# http://rdata2graph.sap.com/hilti_erp/bracket_mk_21d_300_r#0ff9ae8b-d111-412f-825f-655cd61700fc
# http://rdata2graph.sap.com/hilti_erp/#8340b92a-eff6-4838-b4a5-9d0a9dc6d512
# http://rdata2graph.sap.com/hilti_erp/rating_plate_te_6_s_230v_gb#100efd62-5065-4fc4-b554-6ae29f75df38
# powder
# 102
# http://rdata2graph.sap.com/hilti_erp/#abecf5b7-8767-45f5-994b-212203507337
# sint
# mn
# http://rdata2graph.sap.com/hilti_erp/measuring_rod_pua_56__in_cm_#499e7feb-dce1-49b9-b91a-71eb88773097
# http://rdata2graph.sap.com/hilti_erp/#f23a9442-7e30-4f77-b2ab-d4c5fb371dd3
# xh
# http://rdata2graph.sap.com/hilti_erp/protective_sleeve_10_2#01c99df5-615a-4657-8ad6-0039e811dde7
# cfsb
# http://rdata2graph.sap.com/hilti_erp/#d1915664-a5da-46c9-824b-3805cf41bffc
#
# ------------
# Difference for src_12:
# remov
# drs6a
# ldt
# http://rdata2graph.sap.com/hilti_erp/dust_removal_system_te_drs_6_a_box#c3bf0812-c664-4dcf-9e8a-bf3f52e035a8
# 10a
# http://rdata2graph.sap.com/hilti_erp/#d583439b-7985-483e-a10c-347ae8a31c1f
# http://rdata2graph.sap.com/hilti_erp/cordless_rotary_hammer_te_10_a_220v_used#ec61c533-f78d-40a9-b2fa-e060791d973e
# http://rdata2graph.sap.com/hilti_erp/#86ff74cd-f0a6-4f7f-8f3c-dd413ce4cc38
# http://rdata2graph.sap.com/hilti_erp/#f4718b66-55d2-4a88-84de-477c7b5a20d3
#
# ------------
# Difference for src_13:
# hitcr316
# hitcr
# t27
# http://rdata2graph.sap.com/hilti_erp/water_collector_holder_dd_hsm_s#86df033a-16a7-47b2-902b-54b997f8b44c
# ddhsm
# http://rdata2graph.sap.com/hilti_erp/#37956313-745c-409f-ac58-2f216c3239c9
# http://rdata2graph.sap.com/hilti_erp/anchor_hit_cr_316__washer_m30#5787f90d-e853-4edb-992d-a85919b4444b
# m6x22
# http://rdata2graph.sap.com/hilti_erp/screw_m6x22_t27_black#6bb84e6f-79aa-41e4-a8c2-357e9a98e44f
# m30
#
# ------------
# Difference for src_14:
# 92
# 80
# batter
# board
# http://rdata2graph.sap.com/hilti_erp/data_cable_psa_92_usb_b#083ae2b7-e68e-4bda-92e8-5a50576fbf92
# dsbgf
# http://rdata2graph.sap.com/hilti_erp/measuring_extension_pda_72#e0f2835c-168f-45f0-91fc-2d253d2a8e85
# http://rdata2graph.sap.com/hilti_erp/#87f71548-c1ca-4891-8e30-5d4560d3c41a
# http://rdata2graph.sap.com/hilti_erp/center_section_ds_bgf_80#74ba0074-ed2d-4bd2-9eec-83ecb82f736a
# http://rdata2graph.sap.com/hilti_erp/center_section_ds_bgf_120#e308f681-3a57-4fee-b2e5-7887a1741bad
# usbb
# http://rdata2graph.sap.com/hilti_erp/batter_board_adapter_pra_750#a283c267-66dd-43fe-8ca6-1b300cdb936a
# ------------
# Difference for src_15:
# slit
# slitt
# http://rdata2graph.sap.com/hilti_erp/cordless_combihammer_te_30_a36_cas#be867c7a-219d-4663-99d1-de16d8042394
# cutt
# hss
# metric
# combiham
# drsi
# dpc
# m16
# http://rdata2graph.sap.com/hilti_erp/kit_te_cx__12__l1___hss_1_10__s_m__box#07565e04-3097-483c-8f9f-b69f61290ece
# http://rdata2graph.sap.com/hilti_erp/stator_120v_assy#8f54106a-962f-4707-8e87-8e9b4eb22bcd
# 230240v
# 110
# l1
# http://rdata2graph.sap.com/hilti_erp/#611e1f96-acd6-4ff0-b6b3-9abc835c0498
# http://rdata2graph.sap.com/hilti_erp/power_conditioner_dpc_20_110v_wh#e198fc3d-0517-4355-9f9c-17625f8f5de6
# acc
# http://rdata2graph.sap.com/hilti_erp/stator_230_240v_assy#a23137b3-a8ed-4007-8a60-d8eaadea24f3
# 30a36
# tecx
# condition
# http://rdata2graph.sap.com/hilti_erp/case_te_drs_y__dust#af7cbe1f-c7e4-4747-9286-af4afcdbe801
# http://rdata2graph.sap.com/hilti_erp/#62d9f3a9-8098-446b-b762-9ae079b84380
# http://rdata2graph.sap.com/hilti_erp/#fe8c3e6d-b667-4a4b-af8e-0fbd96ed6d9a
# http://rdata2graph.sap.com/hilti_erp/spring_washer_ss_m16__20_#3dd446fd-cf75-492a-a875-cc22125cd66e
#
# ------------
# Difference for src_16:
# mftefi
# http://rdata2graph.sap.com/hilti_erp/tripod_adapter_pmw_30#42bbd691-0a8d-4c56-ab8b-26507057a9da
# pkg500
# xcpbooster
# uno
# http://rdata2graph.sap.com/hilti_erp/#4e0be76a-90c3-4327-b310-e8e13ddccf43
# pmw
# sill
# 460
# http://rdata2graph.sap.com/hilti_erp/#f844db5d-3c53-4f4b-b772-0e4b6dd376b3
# http://rdata2graph.sap.com/hilti_erp/#bd880d56-f927-4667-8232-762496fd75e1
# dx460f8
# mf
# wear
# design
# 060
# 600
# http://rdata2graph.sap.com/hilti_erp/accessory_kit_hit_profi_anchor_box#9e4fca75-4793-4126-9dea-368840ac4ef2
# http://rdata2graph.sap.com/hilti_erp/#7f180764-b562-46dc-b072-390d5452d2bc
# xdni
# http://rdata2graph.sap.com/hilti_erp/dx_fastening_design_c2f#553996ea-d77e-401c-8d8e-2ecbcb7f2f9c
# tear
# http://rdata2graph.sap.com/hilti_erp/#043da828-d3cd-4155-8c73-a8ac77bdd033
# dxfasten
# c2f
# u
# instr
# efi
# http://rdata2graph.sap.com/hilti_erp/bracket_mft_mf_060_m_6_5_s#fb8abcde-424c-4ff5-bed9-7211026c604c
# http://rdata2graph.sap.com/hilti_erp/#b3d20a41-3a6d-4756-9a2d-ef7f5a3f72e1
# http://rdata2graph.sap.com/hilti_erp/universal_nail_x_dni_72#6fb05590-3c4c-42d0-8edf-17e152120c0c
# http://rdata2graph.sap.com/hilti_erp/bracket_mft_efi_600_u_11#a0f626c9-2be5-461f-bddd-cf6230362fe4
# http://rdata2graph.sap.com/hilti_erp/dx460_f8_sill_plate_x_cp_booster_pkg_500#8e57e682-d656-4aba-9d87-5a11340ad72e
# http://rdata2graph.sap.com/hilti_erp/torx_soc_ov_screw_m6x25_t30_black#d225e23f-ad92-4166-a580-6cd39ba511b0
# mftmf
#
# ------------
# Difference for src_17:
# 230f
# 1555
# http://rdata2graph.sap.com/hilti_erp/air_duct_bracket_mva_l#86032528-00be-46f7-8fcb-8f723ebb5308
# http://rdata2graph.sap.com/hilti_erp/kit_te_50_avr___te_yp_fm___te_yx_15_55#80588148-3830-47c8-a64d-373a39a506e5
# accessoir
# http://rdata2graph.sap.com/hilti_erp/rf_screw_5x20_black#e542ab59-a033-4696-9f0e-4d798bbd6de2
# 4x35
# http://rdata2graph.sap.com/hilti_erp/#ffd2512c-8cdf-4b72-82eb-26f5c5a5e5c3
# http://rdata2graph.sap.com/hilti_erp/mains_adapter_pua_81#a001a5ed-fd21-4115-a200-f5b54894d2aa
# s1
# http://rdata2graph.sap.com/hilti_erp/#e8523491-3e96-4d2e-b77c-5814cabe2174
# http://rdata2graph.sap.com/hilti_erp/connecting_cable_psa_51#e9dc44b8-9649-44ff-ac5b-c3ef4ac9770c
# http://rdata2graph.sap.com/hilti_erp/#35ae557f-4201-481d-bbde-e75a35fb7b7a
# http://rdata2graph.sap.com/hilti_erp/kit_te_80_atc___yp_sm___te_yx_28_52_cas#23d3dca0-8075-48bc-bdc3-0b4ffe8569ba
# teyx
# ypfm
# mval
# http://rdata2graph.sap.com/hilti_erp/torx_soc_re_scr_sn65_4x35_black#30717fe7-a4d4-4521-a54a-681c6a4b69c2
# 190
# mv
# 2852
# http://rdata2graph.sap.com/hilti_erp/#a0f1ddea-c759-4338-860e-4f8ded1dfa56
# http://rdata2graph.sap.com/hilti_erp/#7f56d09e-d44c-4865-8dd2-6796d38248c8
# ypsm
# http://rdata2graph.sap.com/hilti_erp/cutting_disc_ac_d_230f_s1#1939d41b-1f5d-4223-8ad6-4898ff3f2eae
# 50avr
# gener
# duct
# http://rdata2graph.sap.com/hilti_erp/#361b9f53-149d-47ff-a51c-8c3f4174d6e9
# rf
#
# ------------
# Difference for src_18:
# 330ml
# http://rdata2graph.sap.com/hilti_erp/bearing_plate_assy#80f794c7-82db-48fb-865e-26b2071b35a3
# http://rdata2graph.sap.com/hilti_erp/#8c1134fb-061b-4f91-9f41-db58a5f0e75c
# http://rdata2graph.sap.com/hilti_erp/combo_200x_re_500_330___hdm500_dispenser#bd51b2fe-6f57-4049-bfb1-696b64573d51
# 330
# hdm500
# combo
# 200x
# http://rdata2graph.sap.com/hilti_erp/#c1121b33-8ed7-44f5-9f22-e28f659e4419
# http://rdata2graph.sap.com/hilti_erp/slotted_set_screw_m10x12#43efe5cb-2000-446f-b0ce-2b027e312cac
# m10x12
#
# ------------
# Difference for src_19:
# http://rdata2graph.sap.com/hilti_erp/#b93e6534-356f-4ee9-b8c9-3d1942eec588
# m33
# regul
# http://rdata2graph.sap.com/hilti_erp/#4b0d42c6-89ad-4ebc-accc-e299f7bf4ecf
# lightduti
# a450
# http://rdata2graph.sap.com/hilti_erp/#5b209b40-29a9-4c66-8164-8883b31025ef
# http://rdata2graph.sap.com/hilti_erp/regulating_wheel#24e5f299-a753-463c-ad35-f6a41bb8067e
# mpad
# nicd
# http://rdata2graph.sap.com/hilti_erp/#82fe6c82-f00f-40c5-aa50-9a273de71b0c
# http://rdata2graph.sap.com/hilti_erp/#fb104a2c-057c-411b-872c-035e67811abf
# http://rdata2graph.sap.com/hilti_erp/kit_te_2_a___b_24_2_0_nicd__2__assy#761415e2-5549-41c5-a7f2-abdad893f2e3
# http://rdata2graph.sap.com/hilti_erp/hexagon_nut_m33_a4_50#e99499ad-591c-439c-97db-528f385671b8
# http://rdata2graph.sap.com/hilti_erp/light_duty_pipe_ring_mp_ad_m6_22#39e92c3c-df2e-4ae4-adcd-3bfda54a6f6c
# 2420
#
# ------------
# Difference for tgt_0:
#
#
# ------------
# Difference for tgt_1:
# http://rdata2graph.sap.com/hilti_erp/return_pulley_dsw_w_280_pr_servicing_set#619d9d94-0dcf-4098-8e44-fd154f46fc41
# 27
# 82
# http://rdata2graph.sap.com/hilti_erp/wall_mount_with_magnetic_bracket_pma_82#6e924c02-c189-4473-88b7-603c1d24e407
# squar
# http://rdata2graph.sap.com/hilti_erp/target_plate_poa_27_square#02346cc8-e38c-4919-9fc0-b711a3dc0066
#
# ------------
# Difference for tgt_2:
# http://rdata2graph.sap.com/hilti_erp/te_4_a22__body_5_____nov_od#63f09ec8-be84-449d-9ee9-9482ef86c99e
# http://rdata2graph.sap.com/hilti_erp/self_tapping_screw_s_mp72s_6_3x63#2182202f-690c-404f-a772-12a9a989b635
# http://rdata2graph.sap.com/hilti_erp/#ce6b5b0e-d150-4d23-aaba-5278d60b5d5b
# http://rdata2graph.sap.com/hilti_erp/#dc0c5eca-7c20-4022-b2f7-e914050e9bf0
# http://rdata2graph.sap.com/hilti_erp/kit_te_4_a22___drs_4_a___b_22_3_3__2_#48d9d668-0d7f-4182-8705-8cbc0b371338
# http://rdata2graph.sap.com/hilti_erp/recess_tapping_screw_3_9x19#c40783be-34bf-468e-99ca-165123167ccd
# 436ac
# http://rdata2graph.sap.com/hilti_erp/#c17c5108-95fd-437f-8f51-0de246a658d4
# 22332
# http://rdata2graph.sap.com/hilti_erp/kit_te_4_a22___b22_3_3__2_#74dfefca-d867-427c-a837-781ebb8a8641
# p60m
# 500ml
# http://rdata2graph.sap.com/hilti_erp/nail_magazine_x_120_gm20#6c5a52cd-8492-4410-b262-11932682344a
# 2a22
# smp72
# m5x16
# c
# b2233
# 8ma22
# http://rdata2graph.sap.com/hilti_erp/flotte_p60m_te_4_a22___sf_22_a#b8989200-9902-4462-a642-6f5ba51181cf
# bodi
# smp
# st39x16
# 48x38
# http://rdata2graph.sap.com/hilti_erp/#fb2b8508-8e12-4272-8634-b1f0df0852a2
# gm20
# http://rdata2graph.sap.com/hilti_erp/kit_te_4_a22___sfh_22_a___b_22__2__cas#8c44c04c-6591-4778-a4f3-936a4f694225
# http://rdata2graph.sap.com/hilti_erp/kit_te_4_a22___b_22_3_3_2____c_4_36_acs#aba055ce-7990-40a7-b87e-1d93526fa9b6
# flott
# 2233
# http://rdata2graph.sap.com/hilti_erp/recess_tapping_screw_st3_9x16#7c525210-9935-42f9-a271-ecb05ccd01c3
# http://rdata2graph.sap.com/hilti_erp/kit_hit_re_500_500__25____te_2_a22#40b84fa6-8f7d-4aba-84c2-6157049e783b
# http://rdata2graph.sap.com/hilti_erp/recess_tapping_screw_4_8x38#56c12fde-56f6-4338-9428-b85dc2476a0c
# od
# 63x63
# 500500
# 39x19
# drs4a
# http://rdata2graph.sap.com/hilti_erp/taptite_screw_m5x16_t20_mc#2c380656-aa65-4cc5-bef9-4015585ef7cf
# nov
# http://rdata2graph.sap.com/hilti_erp/kit_te_4_a22___sf_8m_a22#d97a832d-aebf-457f-beb4-86aa3289e0ef
#
# ------------
# Difference for tgt_3:
# m1458
# http://rdata2graph.sap.com/hilti_erp/pin_type_face_wrench_m14_5_8#c234184d-61c9-429d-8b51-419629ff5316
# 75
# ws6350110v
# http://rdata2graph.sap.com/hilti_erp/installation_wrench_sw_24_10#e6aa49a7-7a02-421d-b9e7-66cbee489373
# larg
# http://rdata2graph.sap.com/hilti_erp/angle_grinder_ws6350_110v#d0907754-a400-4bdd-b543-e1133cd1fefd
# 2410
# http://rdata2graph.sap.com/hilti_erp/pin_type_face_wrench_b35#bbba90ba-25ef-48b4-a9ce-c2125f025022
# http://rdata2graph.sap.com/hilti_erp/side_handle_dd_sh_30#7a87857f-25df-49d8-999c-dffbc32c920d
# j
# face
# http://rdata2graph.sap.com/hilti_erp/rating_plate_te_14_230v_ch#a74980a0-ed23-43fe-a323-ece76c36c51a
# shstd
# http://rdata2graph.sap.com/hilti_erp/rating_plate_te_700_avr_220_230v#53d13d71-543b-400e-9b54-c6e121fcf728
# ddsh30
# http://rdata2graph.sap.com/hilti_erp/side_handle__m_14__assy#f3e91522-3f74-4d82-8015-3ace09b26e60
# 10mm
# xsag
# sw
# ch
# http://rdata2graph.sap.com/hilti_erp/side_handle_dd_sh_150#f0e9e174-f2b3-44c2-8292-6ee22b4ec4ac
# http://rdata2graph.sap.com/hilti_erp/#e48f6e42-4a5b-408c-8646-bcc3154e61db
# 100v
# kl
# http://rdata2graph.sap.com/hilti_erp/side_handle_assy#62b92546-ef15-43ef-8aaf-297d24f53ab0
# http://rdata2graph.sap.com/hilti_erp/#dabf9712-6827-4df2-8109-287fa4b10b44
# http://rdata2graph.sap.com/hilti_erp/side_handle__m10__assy#d414091f-7e68-4ce2-b4f2-69f406a1f77e
# http://rdata2graph.sap.com/hilti_erp/#c9b7094c-cbb5-4e4c-86d9-e63c2469dcaf
# repair
# 700avr
# b35
# http://rdata2graph.sap.com/hilti_erp/flat_wrench_10mm_insert_tool#4f16f56c-c67b-4524-8394-f1bae5a2ccad
# http://rdata2graph.sap.com/hilti_erp/side_handle_xsag#fefead91-ab03-4b2f-9b74-ed9751cfad42
# ddsh150
# 14
# http://rdata2graph.sap.com/hilti_erp/impact_wrench_si_100_230v_assy#ea04c4b3-d34f-4137-a93c-34848d1c0a5c
# http://rdata2graph.sap.com/hilti_erp/angle_grinder_ws_180_220v_kl_box#c71feca8-df88-4556-8479-4d37bc7d5605
# http://rdata2graph.sap.com/hilti_erp/#630ac0b4-9397-4987-8c87-5a5aa000369e
# http://rdata2graph.sap.com/hilti_erp/rating_plate_te_75_100v_j#ad19105a-90e4-4b5e-a4ff-ef636cc16bd0
# http://rdata2graph.sap.com/hilti_erp/side_handle_te_sh_std_2#bdc329e1-5c82-447b-9728-3ea9bb3d9d50
# ------------
# Difference for tgt_4:
# http://rdata2graph.sap.com/hilti_erp/hanger_clamping#cb383215-9365-4e13-a34a-a37181d1e3c3
# http://rdata2graph.sap.com/hilti_erp/hex_skt_hd_cap_screw_m4x12_mc#e7e467e2-9baa-4d3e-8d50-6058dec294fd
# m4x12
# http://rdata2graph.sap.com/hilti_erp/tension_lever_set#62b3f5c3-ff46-4714-a490-bf638f550be6
# http://rdata2graph.sap.com/hilti_erp/#287db36b-3e89-48eb-a39a-cc375e924734
#
# ------------
# Difference for tgt_5:
# 1250pe
# http://rdata2graph.sap.com/hilti_erp/plunging_wheel_dsw_pw_rotatable#eaae05d5-9f6c-479d-8eac-d63c562cc9e0
# dswpw
# http://rdata2graph.sap.com/hilti_erp/case_wsr_1250_pe#5db0ba2e-396d-4f15-ab52-88b1c2cb8df8
# plung
# http://rdata2graph.sap.com/hilti_erp/return_pulley_dsw_w_280_pr_assy#c3f5638b-54c0-4b44-8382-5403e412b879
# http://rdata2graph.sap.com/hilti_erp/guide_wheel_dsw_w_280_pr_servicing_set#e97dd03d-195b-4370-aac7-92cf6d702efc
# http://rdata2graph.sap.com/hilti_erp/guide_wheel_dsw_w_200_assy#c93d6181-ab78-481e-80c7-daf444fadf96
#
# ------------
# Difference for tgt_6:
# 79
# 73
# http://rdata2graph.sap.com/hilti_erp/torx_soc_cap_screw_m5x25#2356a0df-7977-452f-b4e9-b3340713666e
# wedg
# http://rdata2graph.sap.com/hilti_erp/#121c6d4d-56f1-484a-96c7-b439ed738eee
# http://rdata2graph.sap.com/hilti_erp/torx_soc_ov_screw__sn44_5x16_mc#1d11cd62-d2e7-48de-a4d9-69b3a8c3b865
# http://rdata2graph.sap.com/hilti_erp/filter_cartridge_inside#99c562ab-ac48-4e03-8320-b4f6afbdcde9
# http://rdata2graph.sap.com/hilti_erp/frame_clamp_poa_79#5c1c5baf-47ef-4da5-a40c-177f3e27cde2
# http://rdata2graph.sap.com/hilti_erp/frame_clamp_poa_73#8332f360-f3cf-478f-b439-bc7dca24b94d
# http://rdata2graph.sap.com/hilti_erp/torx_soc_ov_screw__sn44_6x14_mc#d3911552-9a0f-4d57-9b10-addecf520dea
# 6x14
# pul
# puller
# http://rdata2graph.sap.com/hilti_erp/wedge_puller_cfs_t_pul#3defae2f-9aaf-4693-8bc1-df1d93f6b2ad
#
# ------------
# Difference for tgt_7:
# crank
# http://rdata2graph.sap.com/hilti_erp/electrical_connection_eu_400v_63a#1ea8898d-7725-4b6a-963c-5717141b3488
# eu
# http://rdata2graph.sap.com/hilti_erp/crank_tripod_pua_32#2e523256-acda-438d-b3e4-809f384e2077
# 400v
# http://rdata2graph.sap.com/hilti_erp/electrical_assembly_set_assy#7e7b58b8-e44d-4c07-9ae1-8c25d7c0e9df
# 1394x262
# http://rdata2graph.sap.com/hilti_erp/o_ring_13_94x2_62#a6c238ab-5a39-4c21-9490-d368cb9b7646
# 63a
#
# ------------
# Difference for tgt_8:
# dsrf
# http://rdata2graph.sap.com/hilti_erp/#604a4340-3c5b-4c96-8d3f-fb0aa195b810
# http://rdata2graph.sap.com/hilti_erp/clamping_piece_ds_rf#1d935e1b-aa65-459f-8190-d8b31789e6da
# 4000a
# volt
# http://rdata2graph.sap.com/hilti_erp/reflector_rod_poa_54_kit#c6cacf29-9280-45ea-ba1b-5731073194e2
# 52
# siw
# poaw4
# http://rdata2graph.sap.com/hilti_erp/#8c1f2742-da30-4661-9f3b-dce5b7795281
# 4000
# foil
# 6a
# http://rdata2graph.sap.com/hilti_erp/gearing_ag_125_500_a_assy_packed#fefc2508-9338-47af-858d-8964ae9fd42e
# http://rdata2graph.sap.com/hilti_erp/#01979fdd-d5f3-48be-9af7-948a1f1ab7bf
# http://rdata2graph.sap.com/hilti_erp/reflector_rod_poa_52#f74d1f4d-c3a7-49a1-bfed-b64b5b0adc79
# 125500a
# http://rdata2graph.sap.com/hilti_erp/sf_121_a_12_volt_3_0_nimh__3_pack_#c91319e9-954a-4bff-bf30-8b2ad1d72085
# http://rdata2graph.sap.com/hilti_erp/#d218161b-8680-4d8e-b23e-193bfc51171e
# http://rdata2graph.sap.com/hilti_erp/kit_te_6_a___sf_144_a___b_36_3_0#4c439bed-1df2-4c43-915f-78a68ab9f69b
# cpc
# http://rdata2graph.sap.com/hilti_erp/kit_sf_4000_a___sf_4000#642e3959-5f6b-4dc8-9a84-e7b364f0d400
# http://rdata2graph.sap.com/hilti_erp/#38c6940a-f29b-46c1-95da-5fce6ecfe513
# http://rdata2graph.sap.com/hilti_erp/#8f46a030-3b95-4087-8e3b-603739adc506
# 3630
# liion
# http://rdata2graph.sap.com/hilti_erp/#d7139c88-9f03-48d1-bed8-938edffeec8b
# http://rdata2graph.sap.com/hilti_erp/#2e1a0240-c204-4077-b499-0dff1df0768f
# http://rdata2graph.sap.com/hilti_erp/rod_adapter_te_y_rd_5_8#15ec1940-fe74-4ede-b83e-95e56f9480e5
# 7a
# rail
# http://rdata2graph.sap.com/hilti_erp/reflector_foil_poaw_4_set#6e8892c4-1d4e-427a-869b-712f5db2a86e
# teyrd
# http://rdata2graph.sap.com/hilti_erp/siw_144_a___sf_144_a_p2#06a9f5b8-7661-48d6-83c9-2452940d95d1
# tey
# 121a
# rl
# http://rdata2graph.sap.com/hilti_erp/reflector_rod_poaw_50_adapter#1be2a53f-74e1-4aa5-b8f1-605d9a201bc8
# 144a
# 18a
# p2
# http://rdata2graph.sap.com/hilti_erp/te_7_a___sf_18_a_cpc_kit#358c4b21-4ca8-40ef-bcd8-a1fc8c902714
# nimh
# http://rdata2graph.sap.com/hilti_erp/reflector_rod_poa_51#7e43e35c-ff82-4776-9413-bd98ceaf6b8d
#
# ------------
# Difference for tgt_9:
# http://rdata2graph.sap.com/hilti_erp/control_cable_ds_ts20_e_10m#92b608d2-d537-4f27-a5cc-3d0c11919cee
#
# ------------
# Difference for tgt_10:
# http://rdata2graph.sap.com/hilti_erp/carbon_brush_6_3x10x19_100v_120v_ao_ml#9ab8a9c3-2087-4035-b3b9-9df71ef85f05
# http://rdata2graph.sap.com/hilti_erp/carbon_brush_100_120v#64a125bf-fbe7-4ac8-9069-11e391c904fe
# 100120v
# http://rdata2graph.sap.com/hilti_erp/carbon_brush_7x12_5x26_100v_120v_ao#5b1baab4-f7e5-48dc-bf6f-11763da64ee0
# http://rdata2graph.sap.com/hilti_erp/hex_skt_set_screw_m10x60#b675fdb3-43f4-49ca-b1ca-8e23f370bdc1
# m8x16
# http://rdata2graph.sap.com/hilti_erp/hex_skt_hd_cap_screw_m8x16#374e9789-6ae2-41a3-97e2-05d966f77d67
# m10x60
# 7x125x26
# http://rdata2graph.sap.com/hilti_erp/fastener_guide_x_460_f10#8fab7925-e18f-411a-906c-81bfe3c3b87b
# x460f10
#
# ------------
# Difference for tgt_11:
# http://rdata2graph.sap.com/hilti_erp/firestop_mortar_fs_635_40lb#be05d9e1-5dcf-4531-a831-a08ff0fc448a
# http://rdata2graph.sap.com/hilti_erp/10_black_plastic_closure_strip[vi1_cl10#3f5a8056-2cc4-42d8-9fc9-d48bd54a64f7
# be
# plaquett
# 10
# closur
# http://rdata2graph.sap.com/hilti_erp/ejot_screw_3x18_t10_black#f88f9f1b-00a8-49c8-98e7-600157fbc356
# http://rdata2graph.sap.com/hilti_erp/firestop_plaquette_de_conformit__be#8ca02836-d2a6-48dd-844e-09c14207c1f8
# cushion
# conformit
# 652
# ga
# aud
# 40lb
# http://rdata2graph.sap.com/hilti_erp/#8d08825b-e0b8-4e46-85cb-d6d9329e2e7c
# http://rdata2graph.sap.com/hilti_erp/foamed_plastic_strip#8be8be83-0907-4cba-b42a-3823834873b1
# 604
# t10
# http://rdata2graph.sap.com/hilti_erp/firestop_sealant_cp_604_5_ga#92ba3995-a9d5-4ec6-b138-74263199c93d
# ejot
# strip[vi1cl10
# 635
# sealant
# 3x18
# http://rdata2graph.sap.com/hilti_erp/firestop_cushion_cp_652_aud#a591f4a4-f48b-4310-8e15-94667fbe18ec
#
# ------------
# Difference for tgt_12:
# http://rdata2graph.sap.com/hilti_erp/pan_head_screw_m6x16_mc#10c86e03-6a62-4a89-bb7f-437bb3cb2c94
# m6x65
# http://rdata2graph.sap.com/hilti_erp/hex_skt_hd_cap_screw_m6x65#025bf54e-8998-4919-ab94-0b707fedc8d8
# http://rdata2graph.sap.com/hilti_erp/hex_skt_hd_cap_screw_m6x25#4ca3bf61-7764-47a5-877a-282701941673
#
# ------------
# Difference for tgt_13:
# http://rdata2graph.sap.com/hilti_erp/drilling_stand_dd_st_160_sfl#b5717606-dfc7-42ee-bfff-698505c074fb
# http://rdata2graph.sap.com/hilti_erp/setting_plate_s_assy#028bfa15-cb60-40b0-b443-b163fdd859d1
# alu
# http://rdata2graph.sap.com/hilti_erp/coupling_sleeve_te_6_a36_avr_03_set#bfb48b2a-5375-4e73-bbc6-248b9e11b5ff
# pivot
# http://rdata2graph.sap.com/hilti_erp/drilling_stand_dd_st_120_sts#023c4ef5-7e2c-4dc3-8b13-7b03079194bf
# http://rdata2graph.sap.com/hilti_erp/setting_rod_assy#481e52ee-020a-4c59-94c1-ddf3870c911b
# http://rdata2graph.sap.com/hilti_erp/telescopic_staff_pa_951__cm_#d5aa9ba3-737b-44b4-9f67-ee6f26b20279
# http://rdata2graph.sap.com/hilti_erp/drilling_stand_dd_st_30#52d186ed-1fb1-4e44-8277-7339cd0cd9b0
# 95
# 30522
# http://rdata2graph.sap.com/hilti_erp/#21ccdf88-98f9-41a2-b0af-8975f4f911be
# http://rdata2graph.sap.com/hilti_erp/setting_tool_hda_m12#ea50aeb0-9118-43a9-b2e9-c8d8cd832b42
# hdam12
# 951
# http://rdata2graph.sap.com/hilti_erp/pivoting_guard_scw_wsc#b98efce7-294a-44fb-9351-c18484bd9ca4
# http://rdata2graph.sap.com/hilti_erp/#17b85867-10b2-40f8-94ed-b9028a06d200
# scwwsc
# http://rdata2graph.sap.com/hilti_erp/cutting_disc_eqd_spx_305_22_mas_#a090ecda-7780-4400-8bfa-567952168d4c
# http://rdata2graph.sap.com/hilti_erp/#bbf0b804-7c5b-49ca-be24-02384d41d0b9
# ma
# spx
# http://rdata2graph.sap.com/hilti_erp/data_cable_pow_95#6a54a6e3-dca1-42a1-a086-acd60f1ff7a1
# hole
# http://rdata2graph.sap.com/hilti_erp/pivoting_guard_scm_assy_packed#199b0daa-63e5-405d-85d8-ac8114f086e8
# ss6x5
# 6a36
# http://rdata2graph.sap.com/hilti_erp/frame_clamp_poa_76#97e9ffe9-0e7a-4bc2-8d3b-180ef692aac1
# coupl
# sfl
# eqd
# http://rdata2graph.sap.com/hilti_erp/transit_frame_cfs_t_ss_6x5_al#c00663af-cf2b-468b-af24-3a0063404537
#
# ------------
# Difference for tgt_14:
# 180230
# glass
# dswwg
# http://rdata2graph.sap.com/hilti_erp/protective_sleeve_dag_dcg_180_230#50a4301a-7ac6-4736-a793-986a69c26ab2
# dagdcg
# http://rdata2graph.sap.com/hilti_erp/protective_glass_scm_assy_packed#f7cf51cb-c9dc-45aa-aa48-1414d0953a94
# http://rdata2graph.sap.com/hilti_erp/protective_cover_dsw_wg_30_kit#7703da67-1988-43bc-8b16-7614715b5105
# http://rdata2graph.sap.com/hilti_erp/protective_sleeve_12#1273c1f0-1829-46de-af58-e5ff894c5ece
#
# ------------
# Difference for tgt_15:
# http://rdata2graph.sap.com/hilti_erp/case_gx_3_typ_039#1cba226b-26fd-4d22-a4af-a04a4eb47e91
# http://rdata2graph.sap.com/hilti_erp/case_te_905_avr_typ_47#a69ee52b-2b81-4fbf-9d65-791c3e14a437
# http://rdata2graph.sap.com/hilti_erp/fastener_guide_dx_351_bt_tq_037#e63d3660-f411-4f23-b065-bd5d58b97f30
# http://rdata2graph.sap.com/hilti_erp/__cutting_edge_right#44f7e52e-9a24-4311-8563-6c33a19bc2c8
# http://rdata2graph.sap.com/hilti_erp/diamond_cutting_disc_dc230m#dd771fad-106e-469a-8b67-5f25a078815a
# http://rdata2graph.sap.com/hilti_erp/marker_pen_pua_70_set#8b6676b3-b2e9-486b-bb38-e4d9190cc53e
# 039
# http://rdata2graph.sap.com/hilti_erp/case_te_60_atc_typ_37_#d45251ef-ff0f-4018-bbca-36f5165a097e
# 560
# 60atc
# http://rdata2graph.sap.com/hilti_erp/double_sided_cutting_guard_180#535d3520-f429-49b9-a898-78317dbf1e84
# http://rdata2graph.sap.com/hilti_erp/#5ba38360-ad87-4ec3-a77e-860bd4055179
# profil
# 1000avr
# pw
# 60
# http://rdata2graph.sap.com/hilti_erp/case_te_16_c_typ_17#3ea05356-86e6-4134-9df7-2c08afc1e0ce
# http://rdata2graph.sap.com/hilti_erp/case_te_60_typ_37_#6a55c8ec-75e6-463c-b99d-277b93d44156
# doublesid
# edgeright
# http://rdata2graph.sap.com/hilti_erp/#898073b6-7d87-4fcd-aa4b-95b0d45bdbcd
# marker
# http://rdata2graph.sap.com/hilti_erp/case_te_6_s_typ_17#8af16410-740e-4c22-bd24-6f0126a21d93
# dbdm112x125x20mm
# http://rdata2graph.sap.com/hilti_erp/#efd87ea6-8e84-4605-adc1-a7a64ca650cc
# dc230m
# http://rdata2graph.sap.com/hilti_erp/diamond_cutting_disc_db_dm1_12x_125x20mm#e625c12b-7e58-4f13-809c-15167fb2a4f8
# http://rdata2graph.sap.com/hilti_erp/install__channel_mq_41_f_2_m#cbf8c95f-177c-4ea1-9a74-41d5c6b0c32d
# 905
# http://rdata2graph.sap.com/hilti_erp/case_te_1000_avr__typ047#ce9b6625-081e-409c-a506-eb493ee755ba
# http://rdata2graph.sap.com/hilti_erp/#dd9837a8-5c4f-4886-a79f-085db7f6a3a9
# typ047
# http://rdata2graph.sap.com/hilti_erp/diamond_cutting_disc_dd_125_pw#60c200be-f9fe-4195-920a-b10774c284bb
# http://rdata2graph.sap.com/hilti_erp/#126cfa17-6f2e-4ea2-868a-138ad8a552cf
# 16c
# 351bttq037
#
# ------------
# Difference for tgt_16:
# tether
# stylu
# http://rdata2graph.sap.com/hilti_erp/accessory_kit_dx_460_f10#ab9c6c0d-39e8-43c0-98d8-8e2d599a7893
# ste
# 460f10
# http://rdata2graph.sap.com/hilti_erp/stylus_pen___tether_pow_94#4ba4aff2-38f8-4d9c-91b7-a78976aefd98
# http://rdata2graph.sap.com/hilti_erp/feather_key_a_4x4x11#2123da5c-ef74-46f3-9944-20fbd80f97ac
# 4x4x7
# starter
# http://rdata2graph.sap.com/hilti_erp/#ca0deac3-b50d-4bf3-9a92-b37dfc544a0e
# 70avr
# adjust
# 398
# http://rdata2graph.sap.com/hilti_erp/#dae2f888-6e75-4154-98de-48b4fbaadbbe
# http://rdata2graph.sap.com/hilti_erp/rubber_washer_set#6d196cd5-0358-4065-a184-5006acebf5b2
# http://rdata2graph.sap.com/hilti_erp/adjusting_lever_set#a807c3f9-5733-4ab2-b872-3c873db7b7fa
# 94
# 4x4x10
# http://rdata2graph.sap.com/hilti_erp/chiselling_handle_assy#40a6af39-cb72-44a6-803d-7d213f143e54
# http://rdata2graph.sap.com/hilti_erp/s_te_70_avr_starter_pack#b45e7e46-2ffd-4663-9f20-4282fc879793
# http://rdata2graph.sap.com/hilti_erp/accessory_kit_vc_20_40#6c16c9d6-289d-471b-a0a4-87b9ad591f2e
# 4x4x11
# http://rdata2graph.sap.com/hilti_erp/single_pair_pulley_dsw_spp_pr#9b95024c-9d90-4ca2-bc26-35f15e894b65
# 55
# http://rdata2graph.sap.com/hilti_erp/feather_key_b_4x4x7#924e7789-f852-42af-aec5-534d02758e5c
# http://rdata2graph.sap.com/hilti_erp/target_plate_pma_55__in___3_#c82575f8-0c03-48aa-9ecc-50caf7661428
# http://rdata2graph.sap.com/hilti_erp/#69eb257f-5227-456a-af3a-6fabdaf60a63
# http://rdata2graph.sap.com/hilti_erp/feather_key_a_4x4x10#51094cfd-dcbd-44e8-9514-03b7898345e5
# breaker
#
# ------------
# Difference for tgt_17:
# http://rdata2graph.sap.com/hilti_erp/guide_plate_wsc_3xx_assy#806409cc-3a2c-4158-9a25-4a9e7a0fbd0f
# dswsspp280
# schalter
# http://rdata2graph.sap.com/hilti_erp/side_plate_ds_ws_spp_280_fix_left#c9d59a22-284a-49d5-a7d2-2b16dd0198dd
# http://rdata2graph.sap.com/hilti_erp/hand_guard_packed#92b833f3-8560-4e46-b4e1-7ed331339a63
# fix
# wsc
# http://rdata2graph.sap.com/hilti_erp/#7a577748-7abe-40ea-b099-02f71cd6828f
# http://rdata2graph.sap.com/hilti_erp/#7c7ce447-e172-4f7a-8d75-922e1ad2aa4e
# http://rdata2graph.sap.com/hilti_erp/target_plate_pda_50#da4846d4-9ffd-455e-b314-cb83a956ac97
# http://rdata2graph.sap.com/hilti_erp/guide_plate_gx_2_assy#a9069e5f-899a-437a-ba6e-a088b907af41
# 3xx
# http://rdata2graph.sap.com/hilti_erp/#aad5b4cf-5351-47dc-868e-1a0828a4efde
# left
# http://rdata2graph.sap.com/hilti_erp/toothed_gear_z_26#b0a070e4-3997-4d44-8544-dca5d6bc2f38
# http://rdata2graph.sap.com/hilti_erp/fs_identification_plate_us#fd64ce7b-cb0d-492e-a73d-e8fd4caf6470
# http://rdata2graph.sap.com/hilti_erp/setting_rod_schalter#1b464534-9351-49f7-a558-c0d6b55c0fe6
#
# ------------
# Difference for tgt_18:
# hlcsk
# s36
# m8x88
# http://rdata2graph.sap.com/hilti_erp/universal_nail_x_u_42_s36#23566ab1-4f69-4da8-8123-7bb2bfcd6ea5
# 42
# http://rdata2graph.sap.com/hilti_erp/torx_soc_csk_head_scr_hlc_sk_m8x88#ae25cc09-adfd-4e71-bb28-94b488528599
#
# ------------
# Difference for tgt_19:
# t25
# 6x70
# sn40
# m4x10
# [3021930222047
# http://rdata2graph.sap.com/hilti_erp/taptite_screw_2000_sn40_6x70#240e6494-85ad-41b2-8802-95040e2153d2
# http://rdata2graph.sap.com/hilti_erp/electronics_24v_packed#b1fd9385-e225-4af9-a0e8-e2ec531ea8e8
# http://rdata2graph.sap.com/hilti_erp/plastite_screw_45_6x40__t25#85fee2d5-ced7-404e-a530-d2709c3f4f6b
# et
# 6x40
# http://rdata2graph.sap.com/hilti_erp/taptite_screw_m4x10_t20_mc#ac0b19c3-e047-4eb6-88c6-9549d139d1d5
# 5x35
# http://rdata2graph.sap.com/hilti_erp/#4b61f342-7659-4967-b3d9-e771b0c403a1
# http://rdata2graph.sap.com/hilti_erp/torx_soc_ov_screw_m6x25_mk_t30_black#dd314388-7c0f-4da0-bd0c-c789bd60c888
# http://rdata2graph.sap.com/hilti_erp/tec_3_piece_chisel_pack_[30219_3022_2047#af85400d-98b9-4d60-a807-9b7cf060ac8c
# http://rdata2graph.sap.com/hilti_erp/plastite_screw_45_5x35_t25_black#3181eb35-b288-4742-8652-0c1e54dd2ecb
# 24v
# 45
# http://rdata2graph.sap.com/hilti_erp/electronics_100v_120v_et_packed#8d2253aa-9750-48a3-ac34-4ce9f7626a7a
# http://rdata2graph.sap.com/hilti_erp/plastite_screw_45_5x16#cb6f9ec1-0546-4fd8-830d-edc514ea22dc
# plastit

# %%
def search(word):
        val = list()
        for x in training_material:
            if word in x:
                print("---")
                print(x)
                yield x

# %%
def countit(x, word):
    return x.loc[word].count()

# %%
intersect = pd.DataFrame(intersect)
intersect = intersect.set_index(intersect[0])
countit(pd.DataFrame(intersect), "'http://rdata2graph.sap.com/hilti_web/property/categories.id',")
# Out:
# 2529

# %%
intersect.columns=['val']
set([x for x in intersect.sort_values(by=['val'])['val'].tolist() if not 'http' in x])
# Out:
# set()

# %%
# Out:
# <generator object search at 0x0000027440C11150>
