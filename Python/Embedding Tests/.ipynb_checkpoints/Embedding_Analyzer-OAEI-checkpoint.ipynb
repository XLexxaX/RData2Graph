# %%
import pandas as pd

# %%
df = pd.read_csv('C:\\Users\\D072202\\DeepAnyMatch\\DeepAnyMatch\\result_data\\oaei\\OAEI_w2v_steps_walklength1_2019_06_17_19_25_17_912781\\possible_matches.csv_merged.csv',sep="\t")
df.head()
# Out:
#    Unnamed: 0     src_0     src_1     src_2     src_3     src_4     src_5  \
# 0           0 -0.688035  0.328508  0.749358  0.465917  2.220693  1.358598
# 1           1  0.558271 -0.258508  0.231541 -1.289607 -0.460048  0.773343
# 2           2 -1.288753  0.208791  0.169619  0.036623  0.395973  0.919811
# 3           3  1.287702  0.994663 -1.258674 -0.052440 -0.445574  1.251380
# 4           4  0.631782 -0.296710 -0.207259 -0.249470 -0.216673  0.290483
#
#       src_6     src_7     src_8  ...  label  syntactic_diff  src_tgt_angle  \
# 0 -0.268002  1.494257  0.299485  ...      0        0.583333       0.449219
# 1  0.484746 -0.169333 -0.076424  ...      0        0.250000       0.485756
# 2  0.631572  1.176845  0.676133  ...      0        0.636364       0.607596
# 3  0.549688  0.200364  1.008683  ...      0        0.562500       0.475083
# 4  0.350945  0.650570  0.339422  ...      0        0.900000       0.416217
#
#    src_angle_to_origin  tgt_angle_to_origin  src_veclen  tgt_veclen  \
# 0             0.282007             0.063390    5.156428    4.861150
# 1            -0.192703             0.024317    3.604719    1.327940
# 2             0.087045             0.076842    4.040821    1.045358
# 3             0.150909             0.056997    3.979109    1.149002
# 4             0.147655            -0.054485    1.372529    1.938905
#
#    src_tgt_veclen                                             src_id  \
# 0        5.262998  http://dbkwik.webdatacommons.org/darkscape/pro...
# 1        3.179142  http://dbkwik.webdatacommons.org/darkscape/res...
# 2        3.505412  http://dbkwik.webdatacommons.org/darkscape/cla...
# 3        3.579015  http://dbkwik.webdatacommons.org/darkscape/pro...
# 4        1.851463  http://dbkwik.webdatacommons.org/darkscape/pro...
#
#                                               tgt_id
# 0  http://dbkwik.webdatacommons.org/oldschoolrune...
# 1  http://dbkwik.webdatacommons.org/oldschoolrune...
# 2  http://dbkwik.webdatacommons.org/oldschoolrune...
# 3  http://dbkwik.webdatacommons.org/oldschoolrune...
# 4  http://dbkwik.webdatacommons.org/oldschoolrune...
#
# [5 rows x 51 columns]

# %%
f = open('C:\\Users\\D072202\\DeepAnyMatch\\DeepAnyMatch\\result_data\\oaei\\OAEI_w2v_steps_walklength1_2019_06_17_19_25_17_912781\\w2v_training_material.csv','r', encoding='UTF-8')
#training_material = [x.split(" ") for x in f.read().replace("], ","").replace("[[","[".replace("]]","]").replace("'","").replace(",","").split("[") if not x.split(" ")==['']]
training_material = [x.split(" ") for x in f.read().split("\n") if not x.split(" ")==['']]

# %%
training_material[:2]
# Out:
# [['http://dbkwik.webdatacommons.org/darkscape/resource/symbol_of_life',
#   'http://dbkwik.webdatacommons.org/darkscape/property/members',
#   'ye',
#   ''],
#  ['http://dbkwik.webdatacommons.org/darkscape/resource/symbol_of_life',
#   'http://dbkwik.webdatacommons.org/darkscape/property/release',
#   '2007-02-19^^http://www.w3.org/2001/xmlschema#date',
#   '']]

# %%
tmp = list()
for t in training_material:
    tmp2 = list()
    for t2 in t:
        if not t2=='':
            tmp2.append(t2)
    tmp.append(tmp2)
training_material=tmp
training_material[:2]
# Out:
# [['http://dbkwik.webdatacommons.org/darkscape/resource/symbol_of_life',
#   'http://dbkwik.webdatacommons.org/darkscape/property/members',
#   'ye'],
#  ['http://dbkwik.webdatacommons.org/darkscape/resource/symbol_of_life',
#   'http://dbkwik.webdatacommons.org/darkscape/property/release',
#   '2007-02-19^^http://www.w3.org/2001/xmlschema#date']]

# %%
out = list()
for header in ['src_'+str(i) for i in range(round((len(df.columns)-12)/2))] + ['tgt_'+str(i) for i in range(round((len(df.columns)-12)/2))]:
    tmp = df.sort_values(by=[header])
    o = compute_intersect(tmp[:10]['src_id'].tolist() + tmp[-10:]['src_id'].to_list() + tmp[round(len(tmp)/2)-5:round(len(tmp)/2)+5]['src_id'].to_list(), header)
    out.append(o)
# Out:
# ------------
# Intersect for src_0:
# ['http://www.w3.org/2000/01/rdf-schema#label']
#
# ------------
# Intersect for src_1:
# ['http://www.w3.org/2000/01/rdf-schema#label', 'http://www.w3.org/2000/01/rdf-schema#label', 'http://www.w3.org/2000/01/rdf-schema#label']
#
# ------------
# Intersect for src_2:
# ['http://www.w3.org/2000/01/rdf-schema#label', 'http://www.w3.org/2000/01/rdf-schema#label', 'http://www.w3.org/2000/01/rdf-schema#label']
#
# ------------
# Intersect for src_3:
# ['http://www.w3.org/2000/01/rdf-schema#label', 'http://www.w3.org/2000/01/rdf-schema#label', 'http://www.w3.org/2000/01/rdf-schema#label', 'http://www.w3.org/2000/01/rdf-schema#label', 'http://www.w3.org/2000/01/rdf-schema#label', 'http://www.w3.org/2000/01/rdf-schema#label', 'http://www.w3.org/2000/01/rdf-schema#label']
#
# ------------
# Intersect for src_4:
# ['http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://www.w3.org/2000/01/rdf-schema#label', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://www.w3.org/2000/01/rdf-schema#label', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://www.w3.org/2000/01/rdf-schema#label', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://www.w3.org/2000/01/rdf-schema#label', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://www.w3.org/2000/01/rdf-schema#label', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://www.w3.org/2000/01/rdf-schema#label', 'http://www.w3.org/2000/01/rdf-schema#label', 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type', 'http://www.w3.org/2000/01/rdf-schema#label']
#
# ------------
# Intersect for src_5:
# ['http://www.w3.org/2000/01/rdf-schema#label']
#
# ------------
# Intersect for src_6:
# ['http://www.w3.org/2000/01/rdf-schema#label', 'http://www.w3.org/2000/01/rdf-schema#label', 'http://www.w3.org/2000/01/rdf-schema#label']
#
# ------------
# Intersect for src_7:
# ['http://www.w3.org/2000/01/rdf-schema#label', 'http://www.w3.org/2000/01/rdf-schema#label', 'http://www.w3.org/2000/01/rdf-schema#label', 'http://www.w3.org/2000/01/rdf-schema#label']
#
# ------------
# Intersect for src_8:
# ['http://www.w3.org/2000/01/rdf-schema#label']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-9ddac5d14e2d> in <module>
#       2 for header in ['src_'+str(i) for i in range(round((len(df.columns)-12)/2))] + ['tgt_'+str(i) for i in range(round((len(df.columns)-12)/2))]:
#       3     tmp = df.sort_values(by=[header])
# ----> 4     o = compute_intersect(tmp[:10]['src_id'].tolist() + tmp[-10:]['src_id'].to_list() + tmp[round(len(tmp)/2)-5:round(len(tmp)/2)+5]['src_id'].to_list(), header)
#       5     out.append(o)
#
# <ipython-input-16-c0b14c3a650e> in compute_intersect(id_list, headername)
#      24     x3 = list()
#      25     for i in range(0,len(x2)):
# ---> 26         x3.append([value for value in x2[i]])
#      27     intersect = x3[0]
#      28     for i in range(1,len(x3)):
#
# <ipython-input-16-c0b14c3a650e> in <listcomp>(.0)
#      24     x3 = list()
#      25     for i in range(0,len(x2)):
# ---> 26         x3.append([value for value in x2[i]])
#      27     intersect = x3[0]
#      28     for i in range(1,len(x3)):
#
# KeyboardInterrupt:

# %%
diff = set()
for an_intersect in out:
    diff = diff.difference(an_intersect)
    print(diff)

# %%
from operator import itemgetter
def getmax(listoftuples, no):
    return sorted(listoftuples,key=lambda x: x[1], reverse=True)[:no]

def compute_diff(id_list_x, id_list_y, headername):

    def search(word):
        val = list()
        for x in training_material:
            if word in x:
                yield x   

    def flatten(x):
        for y in x:
            for z in y:
                yield z

    x=[search(word) for word in id_list_x]
    y=[search(word) for word in id_list_y]
    
    
    x2 = list()
    for value in x:
        x2.append(flatten(value))
    y2 = list()
    for value in y:
        y2.append(flatten(value))


    def diff(l1, l2): 
        return [value for value in l1 if not value in l2]
    

    x3 = list()
    for i in range(0,len(x2)):
        x3 = x3 + ([value for value in x2[i]])
    y3 = list()
    for i in range(0,len(y2)):
        y3 = y3 + ([value for value in y2[i]])
    
    print('Difference for ' + headername+':')
    d = diff(x3, y3)
    out=list()
    out2=list()
    for val in d:
        ctr=0
        for tmp in training_material:
            if val in tmp:
                ctr = ctr + 1
        if not str(val)+" -> " + str(ctr) in out: 
            out.append(str(val)+" -> " + str(ctr))
            out2.append((str(val), int(ctr)))
    output1= getmax(out2,100)
    output1 = output1[int(len(output1)/2)-5:int(len(output1)/2)+5]
    d = diff(y3, x3)
    out=list()
    out2=list()
    for val in d:
        ctr=0
        for tmp in training_material:
            if val in tmp:
                ctr = ctr + 1
        if not str(val)+" -> " + str(ctr) in out: 
            out.append(str(val)+" -> " + str(ctr))
            out2.append((str(val), int(ctr)))
    output2 = getmax(out2,100)
    output2 = output2[int(len(output1)/2)-5:int(len(output1)/2)+5]
    return output1,output2
out = list()
for header in ['src_'+str(i) for i in range(round((len(df.columns)-12)/2))] + ['tgt_'+str(i) for i in range(round((len(df.columns)-12)/2))]:
    tmp = df.sort_values(by=[header])
    o1, o2 = compute_diff(tmp[:10]['src_id'].tolist(), tmp[-10:]['src_id'].to_list(), header)
    for x in o1:
        print(x[0] + " (" + str(x[1]) + ")")
    print("")
    for x in o2:
        print(x[0] + " (" + str(x[1]) + ")")
    print("\n")
    print("------------------")
# Out:
# Difference for src_0:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-44-caa89b1a3673> in <module>
#      69 for header in ['src_'+str(i) for i in range(round((len(df.columns)-12)/2))] + ['tgt_'+str(i) for i in range(round((len(df.columns)-12)/2))]:
#      70     tmp = df.sort_values(by=[header])
# ---> 71     o1, o2 = compute_diff(tmp[:10]['src_id'].tolist(), tmp[-10:]['src_id'].to_list(), header)
#      72     for x in o1:
#      73         print(x[0] + " (" + str(x[1]) + ")")
#
# <ipython-input-44-caa89b1a3673> in compute_diff(id_list_x, id_list_y, headername)
#      47         ctr=0
#      48         for tmp in training_material:
# ---> 49             if val in tmp:
#      50                 ctr = ctr + 1
#      51         if not str(val)+" -> " + str(ctr) in out:
#
# KeyboardInterrupt:

# %%
out = list()
for header in ['src_'+str(i) for i in range(round((len(df.columns)-12)/2))] + ['tgt_'+str(i) for i in range(round((len(df.columns)-12)/2))]:
    tmp = df.sort_values(by=[header])
    o = compute_max_occurence(tmp[:10]['src_id'].tolist() + tmp[-10:]['src_id'].to_list() + tmp[round(len(tmp)/2)-5:round(len(tmp)/2)+5]['src_id'].to_list(), header)
    out.append(o)
# Out:
# ------------
# Max occurence for src_0:
# to: 458
# it: 104
# and: 222
# in: 165
# with: 147
# no: 125
# monsteren: 8389
# from: 168
# for: 105
# hi: 145
# equippedpng: 230
# a: 407
# bone: 437
# equip: 106
# armour: 133
# the: 752
# king: 113
# of: 280
# is: 162
# you: 134
#
# ------------
# Max occurence for src_1:
# player: 158
# be: 171
# the: 951
# will: 143
# up: 137
# dragon: 133
# monkey: 278
# you: 350
# as: 147
# fire: 154
# a: 411
# by: 112
# magic: 111
# is: 336
# thi: 126
# from: 238
# use: 303
# can: 269
# in: 183
# onli: 124
# of: 334
# to: 581
# are: 173
# damag: 217
# that: 123
# or: 222
# for: 167
# more: 103
# dragonfir: 315
# and: 395
# it: 285
#
# ------------
# Max occurence for src_2:
# soul: 154
# dungeonen: 154
# varrock: 427
# you: 114
# by: 197
# is: 1218
# area: 538
# visit: 198
# order: 154
# sever: 245
# befor: 154
# ye: 105
# for: 445
# recommend: 221
# the: 4733
# complet: 197
# archaeolog: 154
# ritual: 154
# be: 495
# morytania: 147
# shilo: 180
# enter: 234
# and: 715
# bane: 154
# need: 168
# of: 1519
# gate: 154
# just: 312
# part: 164
# zaro: 154
# also: 111
# archer: 210
# a: 1556
# minigam: 111
# are: 367
# they: 185
# locat: 174
# quest: 891
# proceed: 154
# site: 540
# salv: 121
# excav: 154
# player: 883
# or: 240
# senntisten: 231
# digsit: 644
# arrow: 172
# talk: 143
# far: 154
# in: 709
# to: 1920
# find: 209
# do: 199
# dure: 478
# no: 140
# golem: 168
# citi: 157
# at: 365
# thi: 428
# as: 104
# northwest: 154
# hi: 136
# access: 277
# mahjarrat: 154
# into: 223
# who: 191
# can: 192
# north: 169
# will: 262
# use: 432
# from: 346
# dig: 539
# treasur: 171
# tower: 293
# karamja: 216
# winch: 308
# dungeon: 228
# there: 163
# after: 157
# level: 224
# through: 157
# provid: 170
# enough: 154
# three: 146
# membersonli: 154
# destroy: 154
# go: 103
# must: 154
# with: 369
# that: 201
# desert: 168
# wa: 316
# rope: 212
# an: 392
# east: 268
# na: 170
# river: 112
# templ: 234
# receiv: 104
# fulli: 154
# island: 105
# villag: 237
# which: 204
# have: 287
# it: 510
# king: 113
# age: 154
# teleport: 105
#
# ------------
# Max occurence for src_3:
# from: 133
# a: 387
# it: 125
# de: 134
# for: 103
# of: 554
# be: 115
# rott: 124
# town: 114
# he: 146
# in: 310
# vampyr: 103
# is: 139
# burgh: 124
# that: 122
# and: 314
# to: 446
# the: 1016
# you: 146
# with: 103
# food: 138
#
# ------------
# Max occurence for src_4:
# custom: 225
# cloth: 225
# oath: 150
# who: 225
# if: 190
# for: 466
# your: 182
# will: 427
# inn: 150
# to: 2059
# o: 225
# thi: 119
# want: 166
# piraci: 150
# go: 107
# no: 156
# into: 174
# rabid: 150
# he: 214
# you: 929
# ralph: 150
# arrest: 150
# offic: 233
# about: 150
# jack: 150
# 3: 158
# ask: 308
# piec: 231
# coin: 107
# of: 707
# him: 300
# prison: 153
# in: 758
# due: 150
# a: 798
# send: 150
# have: 163
# question: 150
# teach: 225
# treeen: 550
# doe: 150
# there: 107
# or: 410
# book: 225
# is: 230
# an: 244
# trick: 225
# ghost: 150
# deposit: 150
# when: 105
# pirat: 225
# green: 150
# need: 225
# ani: 164
# be: 408
# the: 1949
# by: 139
# not: 158
# port: 174
# rock: 375
# void: 208
# at: 174
# and: 367
# knight: 136
# with: 225
# island: 238
# are: 131
# requir: 123
# get: 107
# young: 150
# out: 190
# speak: 104
# imprison: 150
# bill: 225
# but: 174
# talk: 225
# tell: 257
# on: 463
# use: 115
# ye: 127
# which: 123
# answer: 225
# adventur: 152
#
# ------------
# Max occurence for src_5:
# of: 365
# for: 112
# and: 197
# rellekka: 160
# fremennik: 438
# to: 212
# be: 115
# in: 154
# rellekkaen: 108
# trial: 131
# player: 229
# by: 258
# will: 105
# a: 320
# it: 215
# complet: 102
# wa: 110
# the: 1071
# is: 188
#
# ------------
# Max occurence for src_6:
# of: 359
# get: 137
# and: 283
# guild: 140
# no: 206
# na: 167
# in: 173
# a: 346
# teleport: 120
# is: 127
# it: 106
# multien: 1597
# you: 254
# cook: 162
# digsit: 160
# or: 139
# constructionen: 395
# all: 132
# to: 352
# answer: 124
# monster: 1608
# the: 1088
# on: 105
#
# ------------
# Max occurence for src_7:
# of: 276
# to: 404
# the: 585
# skill: 112
# are: 184
# in: 112
# player: 114
# monsteren: 7456
# on: 104
# prayer: 126
# and: 333
# is: 143
# a: 169
#
# ------------
# Max occurence for src_8:
# of: 117
# repel: 110
# a: 118
# the: 212
# insect: 110
# constructionen: 395
# to: 128
# monsteren: 8388
#
# ------------
# Max occurence for src_9:
# can: 145
# to: 497
# it: 104
# player: 149
# and: 328
# be: 149
# a: 429
# in: 196
# you: 129
# no: 102
# of: 416
# is: 269
# the: 1007
#
# ------------
# Max occurence for src_10:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-8137aaf5d7e2> in <module>
#       2 for header in ['src_'+str(i) for i in range(round((len(df.columns)-12)/2))] + ['tgt_'+str(i) for i in range(round((len(df.columns)-12)/2))]:
#       3     tmp = df.sort_values(by=[header])
# ----> 4     o = compute_max_occurence(tmp[:10]['src_id'].tolist() + tmp[-10:]['src_id'].to_list() + tmp[round(len(tmp)/2)-5:round(len(tmp)/2)+5]['src_id'].to_list(), header)
#       5     out.append(o)
#
# <ipython-input-27-3a4a99c7a01f> in compute_max_occurence(id_list, headername)
#      29     print("\n------------")
#      30     print('Max occurence for ' + headername+':')
# ---> 31     r = [w + ': ' + str(pd.DataFrame([countit(tpd, w)])[0].to_list()[0]) for w in t if pd.DataFrame([countit(tpd, w)])[0].to_list()[0] > 100]
#      32     print("\n".join(list(set(r))))
#      33     return
#
# <ipython-input-27-3a4a99c7a01f> in <listcomp>(.0)
#      29     print("\n------------")
#      30     print('Max occurence for ' + headername+':')
# ---> 31     r = [w + ': ' + str(pd.DataFrame([countit(tpd, w)])[0].to_list()[0]) for w in t if pd.DataFrame([countit(tpd, w)])[0].to_list()[0] > 100]
#      32     print("\n".join(list(set(r))))
#      33     return
#
# <ipython-input-20-a0ebbe548ccd> in countit(x, word)
#       1 def countit(x, word):
# ----> 2     return x.loc[word].count()
#
# ~\AppData\Local\Continuum\anaconda3\envs\py36\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1498
#    1499             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1500             return self._getitem_axis(maybe_callable, axis=axis)
#    1501
#    1502     def _is_scalar_access(self, key):
#
# ~\AppData\Local\Continuum\anaconda3\envs\py36\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1911         # fall thru to straight lookup
#    1912         self._validate_key(key, axis)
# -> 1913         return self._get_label(key, axis=axis)
#    1914
#    1915
#
# ~\AppData\Local\Continuum\anaconda3\envs\py36\lib\site-packages\pandas\core\indexing.py in _get_label(self, label, axis)
#     139             raise IndexingError('no slices here, handle elsewhere')
#     140
# --> 141         return self.obj._xs(label, axis=axis)
#     142
#     143     def _get_loc(self, key, axis=None):
#
# ~\AppData\Local\Continuum\anaconda3\envs\py36\lib\site-packages\pandas\core\generic.py in xs(self, key, axis, level, drop_level)
#    3583                                                       drop_level=drop_level)
#    3584         else:
# -> 3585             loc = self.index.get_loc(key)
#    3586
#    3587             if isinstance(loc, np.ndarray):
#
# ~\AppData\Local\Continuum\anaconda3\envs\py36\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2654                                  'backfill or nearest lookups')
#    2655             try:
# -> 2656                 return self._engine.get_loc(key)
#    2657             except KeyError:
#    2658                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#
# KeyboardInterrupt:

# %%
out = list()
for header in ['src_'+str(i) for i in range(round((len(df.columns)-12)/2))] + ['tgt_'+str(i) for i in range(round((len(df.columns)-12)/2))]:
    dimlist_x = list()
    dimlist_y = list()
    for header2 in ['src_'+str(i) for i in range(round((len(df.columns)-12)/2))] + ['tgt_'+str(i) for i in range(round((len(df.columns)-12)/2))]:
        if not header2 == header:
            tmp = df.sort_values(by=[header], ascending=False)
            dimlist_y.append(tmp[:10]['src_id'].tolist() + tmp[-10:]['src_id'].to_list() + tmp[round(len(tmp)/2)-5:round(len(tmp)/2)+5]['src_id'].to_list())
        else:
            tmp = df.sort_values(by=[header])
            dimlist_x.append(tmp[:10]['src_id'].tolist() + tmp[-10:]['src_id'].to_list() + tmp[round(len(tmp)/2)-5:round(len(tmp)/2)+5]['src_id'].to_list())
    o = compute_diff(dimlist_x, dimlist_y, header)
    out.append(o)
    break
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-3c2f7da31f6d> in <module>
#      10             tmp = df.sort_values(by=[header])
#      11             dimlist_x.append(tmp[:10]['src_id'].tolist() + tmp[-10:]['src_id'].to_list() + tmp[round(len(tmp)/2)-5:round(len(tmp)/2)+5]['src_id'].to_list())
# ---> 12     o = compute_diff(dimlist_x, dimlist_y, header)
#      13     out.append(o)
#      14     break
#
# NameError: name 'compute_diff' is not defined

# %%
diff = set()
for an_intersect in out:
    diff = diff.difference(an_intersect)
    print(diff)
# Out:
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()
# set()

# %%
# Out:
# set()

# %%
def compute_intersect(id_list, headername):

    def search(word):
        val = list()
        for x in training_material:
            if word in x:
                yield x   

    def flatten(x):
        for y in x:
            for z in y:
                yield z

    x=[search(word) for word in id_list]

    x2 = list()
    for value in x:
        x2.append(flatten(value))


    def intersection(l1, l2): 
        return [value for value in l1 if value in l2]

    x3 = list()
    for i in range(0,len(x2)):
        x3.append([value for value in x2[i]])
    intersect = x3[0]
    for i in range(1,len(x3)):
        intersect = intersection(x3[i], intersect)
    print("\n------------")
    print('Intersect for ' + headername+':')
    print(intersect)
    return intersect

# %%
def compute_max_occurence(id_list, headername):
    
    def search(word):
        val = list()
        for x in training_material:
            if word in x:
                yield x   

    def flatten(x):
        for y in x:
            for z in y:
                yield z

    x=[search(word) for word in id_list]
    
    x2 = list()
    for value in x:
        x2.append(flatten(value))
    x3=list()
    for value in x2:
        for value2 in value:
            x3.append(value2)
    training = pd.DataFrame(x3)
    training = training.set_index(training[0])
    training.columns = ['values']
    t = [val for val in training['values'].values.tolist() if not 'http' in val]
    tpd = pd.DataFrame(t)
    tpd = tpd.set_index(tpd[0])
    print("\n------------")
    print('Max occurence for ' + headername+':')
    r = [w + ': ' + str(pd.DataFrame([countit(tpd, w)])[0].to_list()[0]) for w in t if pd.DataFrame([countit(tpd, w)])[0].to_list()[0] > 100]
    print("\n".join(list(set(r))))
    return

# %%
def compute_diff(id_list_x, id_list_y, headername):

    def search(word):
        val = list()
        for x in training_material:
            if word in x:
                yield x   

    def flatten(x):
        for y in x:
            for z in y:
                yield z

    x=[search(word) for word in id_list_x]
    y=[search(word) for word in id_list_y]
    
    
    x2 = list()
    for value in x:
        x2.append(flatten(value))
    y2 = list()
    for value in y:
        y2.append(flatten(value))

    def getmax(listoftuples, no):
        return sorted(listoftuples,key=lambda x: x[1], reverse=True)[:no]
    
    def diff(l1, l2): 
        return [value for value in l1 if not value in l2]

    x3 = list()
    for i in range(0,len(x2)):
        x3 = x3 + ([value for value in x2[i]])
    y3 = list()
    for i in range(0,len(y2)):
        y3 = y3 + ([value for value in y2[i]])
    
    print("\n------------")
    print('Difference for ' + headername+':')
    d = diff(x3, y3)
    #out = list()
    #for val in d:
    #    ctr=0
    #    for tmp in training_material:
    #        if val in tmp:
    #            ctr = ctr + 1
    #    #print(str(val)+" -> " + str(ctr))
    return d[:30]

# %%
out = list()
for header in ['src_'+str(i) for i in range(round((len(df.columns)-12)/2))] + ['tgt_'+str(i) for i in range(round((len(df.columns)-12)/2))]:
    dimlist_x = list()
    dimlist_y = list()
    for header2 in ['src_'+str(i) for i in range(round((len(df.columns)-12)/2))] + ['tgt_'+str(i) for i in range(round((len(df.columns)-12)/2))]:
        if not header2 == header:
            tmp = df.sort_values(by=[header2], ascending=False)
            dimlist_y = dimlist_y + (tmp[:10]['src_id'].tolist() + tmp[-10:]['src_id'].to_list() + tmp[round(len(tmp)/2)-5:round(len(tmp)/2)+5]['src_id'].to_list())
        else:
            tmp = df.sort_values(by=[header2], ascending=False)
            dimlist_x = dimlist_x + (tmp[:10]['src_id'].tolist() + tmp[-10:]['src_id'].to_list() + tmp[round(len(tmp)/2)-5:round(len(tmp)/2)+5]['src_id'].to_list())
    
    #o = compute_diff(dimlist_x, dimlist_y, header)
    #out.append(o)
    z = set(dimlist_x) - set(dimlist_y)
    out = list()
    print("------------")
    print("Difference for " + header)
    for val in z:
        if dimlist_x.count(val)>0:
            out.append(val)
    print(out)
# Out:
# ------------
# Difference for src_0
# ['http://dbkwik.webdatacommons.org/darkscape/resource/mutated_vine', "http://dbkwik.webdatacommons.org/darkscape/resource/slayer's_staff", 'http://dbkwik.webdatacommons.org/darkscape/resource/the_pharaoh', 'http://dbkwik.webdatacommons.org/darkscape/resource/buyers_and_cellars/quick_guide', 'http://dbkwik.webdatacommons.org/darkscape/property/image', 'http://dbkwik.webdatacommons.org/darkscape/resource/lord_iorwerth', 'http://dbkwik.webdatacommons.org/darkscape/resource/ailanthus_tree', "http://dbkwik.webdatacommons.org/darkscape/resource/raetul_and_co's_cloth_store"]
# ------------
# Difference for src_1
# ['http://dbkwik.webdatacommons.org/darkscape/resource/enchant_level_6_jewellery', 'http://dbkwik.webdatacommons.org/darkscape/resource/emerald_bolts_(e)', 'http://dbkwik.webdatacommons.org/darkscape/resource/armour/prayer_armour', 'http://dbkwik.webdatacommons.org/darkscape/resource/monkey_bones', "http://dbkwik.webdatacommons.org/darkscape/resource/yewnock's_notes", 'http://dbkwik.webdatacommons.org/darkscape/resource/fairy_tale_ii_-_cure_a_queen']
# ------------
# Difference for src_2
# ['http://dbkwik.webdatacommons.org/darkscape/resource/guthixian_cache', 'http://dbkwik.webdatacommons.org/darkscape/resource/super_attack', "http://dbkwik.webdatacommons.org/darkscape/resource/tzhaar-mej-roh's_rune_store"]
# ------------
# Difference for src_3
# ['http://dbkwik.webdatacommons.org/darkscape/resource/polished_fire_giant_bone', 'http://dbkwik.webdatacommons.org/darkscape/resource/dragonfire_shield_(ranged)', 'http://dbkwik.webdatacommons.org/darkscape/resource/food', 'http://dbkwik.webdatacommons.org/darkscape/class/prayer']
# ------------
# Difference for src_4
# ['http://dbkwik.webdatacommons.org/darkscape/resource/torva_full_helm']
# ------------
# Difference for src_5
# ['http://dbkwik.webdatacommons.org/darkscape/resource/penguin_hide_and_seek/spawn_locations', "http://dbkwik.webdatacommons.org/darkscape/resource/2015_hallowe'en_event", 'http://dbkwik.webdatacommons.org/darkscape/resource/dragonbane_arrow', 'http://dbkwik.webdatacommons.org/darkscape/resource/scrimshaw_of_attack', 'http://dbkwik.webdatacommons.org/darkscape/resource/fishing_boots', 'http://dbkwik.webdatacommons.org/darkscape/resource/bathus_full_helm']
# ------------
# Difference for src_6
# ['http://dbkwik.webdatacommons.org/darkscape/resource/ammonium_nitrate', 'http://dbkwik.webdatacommons.org/darkscape/resource/troll_mother', 'http://dbkwik.webdatacommons.org/darkscape/resource/enchant_crossbow_bolt_(sapphire)', 'http://dbkwik.webdatacommons.org/darkscape/resource/ranged_weapons_trader', 'http://dbkwik.webdatacommons.org/darkscape/resource/rune_kiteshield_(guthix)', 'http://dbkwik.webdatacommons.org/darkscape/resource/blood-soaked_feather', 'http://dbkwik.webdatacommons.org/darkscape/resource/cosmic_bar', 'http://dbkwik.webdatacommons.org/darkscape/resource/magic_slate', 'http://dbkwik.webdatacommons.org/darkscape/resource/moss_giant', 'http://dbkwik.webdatacommons.org/darkscape/resource/void_knight_seal_(festival_of_the_dead)']
# ------------
# Difference for src_7
# ['http://dbkwik.webdatacommons.org/darkscape/resource/swamp_weed', 'http://dbkwik.webdatacommons.org/darkscape/resource/emerald_lens', 'http://dbkwik.webdatacommons.org/darkscape/resource/beigarth', 'http://dbkwik.webdatacommons.org/darkscape/resource/lord_rolovanne', 'http://dbkwik.webdatacommons.org/darkscape/resource/category:shop_logo_images', 'http://dbkwik.webdatacommons.org/darkscape/resource/lord_rolomere', 'http://dbkwik.webdatacommons.org/darkscape/resource/anna_jones', 'http://dbkwik.webdatacommons.org/darkscape/resource/lord_rologray', "http://dbkwik.webdatacommons.org/darkscape/resource/'beedy-eye'_jones", 'http://dbkwik.webdatacommons.org/darkscape/resource/donovan_the_family_handyman', 'http://dbkwik.webdatacommons.org/darkscape/resource/construction']
# ------------
# Difference for src_8
# ['http://dbkwik.webdatacommons.org/darkscape/resource/enchant_level_2_jewellery', 'http://dbkwik.webdatacommons.org/darkscape/resource/wallasalkibane_bar']
# ------------
# Difference for src_9
# ["http://dbkwik.webdatacommons.org/darkscape/resource/servants'_guild", 'http://dbkwik.webdatacommons.org/darkscape/resource/ancient_full_helm', "http://dbkwik.webdatacommons.org/darkscape/resource/coeden's_seed_store", 'http://dbkwik.webdatacommons.org/darkscape/resource/unlocked_diary', 'http://dbkwik.webdatacommons.org/darkscape/resource/unfinished_broad_bolts', 'http://dbkwik.webdatacommons.org/darkscape/resource/smoke_diamond', "http://dbkwik.webdatacommons.org/darkscape/resource/merlin's_crystal"]
# ------------
# Difference for src_10
# ['http://dbkwik.webdatacommons.org/darkscape/resource/tears_of_guthix_cavern', 'http://dbkwik.webdatacommons.org/darkscape/resource/observatory_dungeon']
# ------------
# Difference for src_11
# ['http://dbkwik.webdatacommons.org/darkscape/resource/lumbridge_guardsman/dialogue', 'http://dbkwik.webdatacommons.org/darkscape/resource/cannonball_and_chain', 'http://dbkwik.webdatacommons.org/darkscape/resource/large_crate', 'http://dbkwik.webdatacommons.org/darkscape/resource/white_equipment', 'http://dbkwik.webdatacommons.org/darkscape/resource/zamorak_bow', 'http://dbkwik.webdatacommons.org/darkscape/resource/black_platelegs', 'http://dbkwik.webdatacommons.org/darkscape/resource/magic_tree', "http://dbkwik.webdatacommons.org/darkscape/resource/champions'_guild"]
# ------------
# Difference for src_12
# ['http://dbkwik.webdatacommons.org/darkscape/resource/battle_mage', 'http://dbkwik.webdatacommons.org/darkscape/resource/tchiki_monkey_nuts', 'http://dbkwik.webdatacommons.org/darkscape/resource/charm:ice_giant', 'http://dbkwik.webdatacommons.org/darkscape/resource/elemental_creature', 'http://dbkwik.webdatacommons.org/darkscape/resource/trouble', 'http://dbkwik.webdatacommons.org/darkscape/resource/sign_of_respite_i', 'http://dbkwik.webdatacommons.org/darkscape/resource/shrinking_recipe']
# ------------
# Difference for src_13
# ['http://dbkwik.webdatacommons.org/darkscape/resource/bandit_duty_free', 'http://dbkwik.webdatacommons.org/darkscape/resource/category:altar_images', 'http://dbkwik.webdatacommons.org/darkscape/resource/swamp_toad_(creature)']
# ------------
# Difference for src_14
# ['http://dbkwik.webdatacommons.org/darkscape/resource/crafting_guild', 'http://dbkwik.webdatacommons.org/darkscape/resource/uncut_diamond', 'http://dbkwik.webdatacommons.org/darkscape/resource/corrupt_vine', 'http://dbkwik.webdatacommons.org/darkscape/resource/clean_snake_weed']
# ------------
# Difference for src_15
# ['http://dbkwik.webdatacommons.org/darkscape/resource/artefact_empowerment_instructions', 'http://dbkwik.webdatacommons.org/darkscape/resource/off-hand_mithril_longsword', 'http://dbkwik.webdatacommons.org/darkscape/resource/equipment_tables/weapon', 'http://dbkwik.webdatacommons.org/darkscape/resource/category:divine_locations']
# ------------
# Difference for src_16
# ['http://dbkwik.webdatacommons.org/darkscape/resource/adamant_platelegs', 'http://dbkwik.webdatacommons.org/darkscape/property/instructions', "http://dbkwik.webdatacommons.org/darkscape/resource/wydin's_food_store", 'http://dbkwik.webdatacommons.org/darkscape/resource/taverley_hellhound_resource_dungeon', 'http://dbkwik.webdatacommons.org/darkscape/resource/gorajo_resource_dungeon', 'http://dbkwik.webdatacommons.org/darkscape/resource/silver_bar', 'http://dbkwik.webdatacommons.org/darkscape/resource/warpriest_of_armadyl_gauntlets', 'http://dbkwik.webdatacommons.org/darkscape/resource/armadylean_caravan', 'http://dbkwik.webdatacommons.org/darkscape/resource/scribbled_notes', 'http://dbkwik.webdatacommons.org/darkscape/resource/category:uncooked_food', 'http://dbkwik.webdatacommons.org/darkscape/resource/bandosian_caravan', 'http://dbkwik.webdatacommons.org/darkscape/resource/damaged_device', 'http://dbkwik.webdatacommons.org/darkscape/resource/exiled_kalphite_queen']
# ------------
# Difference for src_17
# ['http://dbkwik.webdatacommons.org/darkscape/resource/necromancer_(nadir)', 'http://dbkwik.webdatacommons.org/darkscape/resource/category:hunter', 'http://dbkwik.webdatacommons.org/darkscape/resource/flighted_ogre_arrow', 'http://dbkwik.webdatacommons.org/darkscape/resource/batwing_boots', 'http://dbkwik.webdatacommons.org/darkscape/resource/chunk_of_crystal', 'http://dbkwik.webdatacommons.org/darkscape/resource/blood_talisman', 'http://dbkwik.webdatacommons.org/darkscape/resource/basilisk_boss', 'http://dbkwik.webdatacommons.org/darkscape/resource/body_bar']
# ------------
# Difference for src_18
# ['http://dbkwik.webdatacommons.org/darkscape/resource/barker_toad', 'http://dbkwik.webdatacommons.org/darkscape/resource/earth_talisman', 'http://dbkwik.webdatacommons.org/darkscape/resource/barbed_bolts', 'http://dbkwik.webdatacommons.org/darkscape/resource/ancient_ceremonial_mask', 'http://dbkwik.webdatacommons.org/darkscape/resource/fire_talisman', 'http://dbkwik.webdatacommons.org/darkscape/resource/dungeoneering/construction', 'http://dbkwik.webdatacommons.org/darkscape/resource/top_of_sceptre', 'http://dbkwik.webdatacommons.org/darkscape/resource/shadow_hound', 'http://dbkwik.webdatacommons.org/darkscape/resource/ancient_mitre', 'http://dbkwik.webdatacommons.org/darkscape/resource/quest_points', 'http://dbkwik.webdatacommons.org/darkscape/resource/cosmic_talisman', 'http://dbkwik.webdatacommons.org/darkscape/resource/construction_training']
# ------------
# Difference for src_19
# ['http://dbkwik.webdatacommons.org/darkscape/resource/yew_composite_bow', 'http://dbkwik.webdatacommons.org/darkscape/resource/translation_manual', 'http://dbkwik.webdatacommons.org/darkscape/resource/green_power_crystal', 'http://dbkwik.webdatacommons.org/darkscape/resource/the_big_heist_lodge', 'http://dbkwik.webdatacommons.org/darkscape/resource/blood_diamond', "http://dbkwik.webdatacommons.org/darkscape/resource/ranael's_super_skirt_store", 'http://dbkwik.webdatacommons.org/darkscape/resource/guthix_coif', 'http://dbkwik.webdatacommons.org/darkscape/resource/cupric_ore_powder', 'http://dbkwik.webdatacommons.org/darkscape/resource/arboretum_(location)', "http://dbkwik.webdatacommons.org/darkscape/resource/explorer's_ring_4", 'http://dbkwik.webdatacommons.org/darkscape/resource/fishing_guild']
# ------------
# Difference for tgt_0
# ['http://dbkwik.webdatacommons.org/darkscape/resource/void_knight_commendation', 'http://dbkwik.webdatacommons.org/darkscape/resource/adamant_equipment', "http://dbkwik.webdatacommons.org/darkscape/resource/statius's_equipment"]
# ------------
# Difference for tgt_1
# []
# ------------
# Difference for tgt_2
# ['http://dbkwik.webdatacommons.org/darkscape/resource/ancient_magicks', 'http://dbkwik.webdatacommons.org/darkscape/resource/ancient_robe_legs', 'http://dbkwik.webdatacommons.org/darkscape/resource/ancient_effigies', 'http://dbkwik.webdatacommons.org/darkscape/resource/fellstalk_potion_(unf)']
# ------------
# Difference for tgt_3
# ['http://dbkwik.webdatacommons.org/darkscape/resource/healer_lvl_4', "http://dbkwik.webdatacommons.org/darkscape/resource/sir_ceril's_money_pouch"]
# ------------
# Difference for tgt_4
# ['http://dbkwik.webdatacommons.org/darkscape/resource/ingredients', 'http://dbkwik.webdatacommons.org/darkscape/resource/extreme_ranging', 'http://dbkwik.webdatacommons.org/darkscape/resource/box_of_summoning_ingredients', 'http://dbkwik.webdatacommons.org/darkscape/resource/rock_fragments', 'http://dbkwik.webdatacommons.org/darkscape/property/ingredient', 'http://dbkwik.webdatacommons.org/darkscape/property/requirements', 'http://dbkwik.webdatacommons.org/darkscape/resource/sacred_metal_fragments', 'http://dbkwik.webdatacommons.org/darkscape/resource/holiday_events']
# ------------
# Difference for tgt_5
# ['http://dbkwik.webdatacommons.org/darkscape/resource/combat_instructors', 'http://dbkwik.webdatacommons.org/darkscape/resource/falador_shield_3']
# ------------
# Difference for tgt_6
# ['http://dbkwik.webdatacommons.org/darkscape/resource/mahogany_treasure_chest', 'http://dbkwik.webdatacommons.org/darkscape/resource/mahogany_table', 'http://dbkwik.webdatacommons.org/darkscape/resource/war-chief_top', 'http://dbkwik.webdatacommons.org/darkscape/resource/firemaking/level_up_table', 'http://dbkwik.webdatacommons.org/darkscape/resource/war-chief_boots', 'http://dbkwik.webdatacommons.org/darkscape/resource/war-chief_trousers', 'http://dbkwik.webdatacommons.org/darkscape/resource/category:crucible', 'http://dbkwik.webdatacommons.org/darkscape/resource/chief_servant', 'http://dbkwik.webdatacommons.org/darkscape/resource/edible_seaweed', 'http://dbkwik.webdatacommons.org/darkscape/resource/war-chief_gloves', 'http://dbkwik.webdatacommons.org/darkscape/resource/war-chief_reeves', 'http://dbkwik.webdatacommons.org/darkscape/resource/mahogany_trapdoor', 'http://dbkwik.webdatacommons.org/darkscape/resource/mahogany_armour_case', 'http://dbkwik.webdatacommons.org/darkscape/resource/mahogany_magic_wardrobe', 'http://dbkwik.webdatacommons.org/darkscape/resource/fletching/level_up_table']
# ------------
# Difference for tgt_7
# ['http://dbkwik.webdatacommons.org/darkscape/resource/adamant_berserker_shield', 'http://dbkwik.webdatacommons.org/darkscape/resource/canopic_jar_with_oil_and_ring', "http://dbkwik.webdatacommons.org/darkscape/resource/'perfect'_ring", 'http://dbkwik.webdatacommons.org/darkscape/resource/lunar_ring_(i)', 'http://dbkwik.webdatacommons.org/darkscape/resource/hoardstalker_ring', 'http://dbkwik.webdatacommons.org/darkscape/resource/berserker_necklace', 'http://dbkwik.webdatacommons.org/darkscape/resource/berserker_helm', 'http://dbkwik.webdatacommons.org/darkscape/resource/canopic_jar_with_ring']
# ------------
# Difference for tgt_8
# ['http://dbkwik.webdatacommons.org/darkscape/resource/replica_statue_piece', 'http://dbkwik.webdatacommons.org/darkscape/resource/username', "http://dbkwik.webdatacommons.org/darkscape/resource/sliske's_endgame", 'http://dbkwik.webdatacommons.org/darkscape/resource/character_name', 'http://dbkwik.webdatacommons.org/darkscape/resource/ornamental_globe', 'http://dbkwik.webdatacommons.org/darkscape/resource/herblore_training', 'http://dbkwik.webdatacommons.org/darkscape/property/displayname', 'http://dbkwik.webdatacommons.org/darkscape/property/name']
# ------------
# Difference for tgt_9
# ['http://dbkwik.webdatacommons.org/darkscape/resource/lava-flow_miner_sven', 'http://dbkwik.webdatacommons.org/darkscape/resource/strong_mining_urn_(unf)', 'http://dbkwik.webdatacommons.org/darkscape/resource/fletching_master_cape', 'http://dbkwik.webdatacommons.org/darkscape/resource/strong_mining_urn_(full)', 'http://dbkwik.webdatacommons.org/darkscape/resource/farming_master_cape', 'http://dbkwik.webdatacommons.org/darkscape/resource/soaked_kindling', 'http://dbkwik.webdatacommons.org/darkscape/resource/mithril_ceremonial_sword_v', 'http://dbkwik.webdatacommons.org/darkscape/resource/off-hand_mithril_sword', 'http://dbkwik.webdatacommons.org/darkscape/resource/mithril_2h_sword']
# ------------
# Difference for tgt_10
# ['http://dbkwik.webdatacommons.org/darkscape/resource/spirit_of_the_body', 'http://dbkwik.webdatacommons.org/darkscape/resource/mostafa_the_camel', 'http://dbkwik.webdatacommons.org/darkscape/resource/key_(the_lost_tribe)', 'http://dbkwik.webdatacommons.org/darkscape/resource/the_lost_tribe/transcript']
# ------------
# Difference for tgt_11
# ['http://dbkwik.webdatacommons.org/darkscape/resource/polished_giant_rat_bone', 'http://dbkwik.webdatacommons.org/darkscape/resource/giant_rat_bone', 'http://dbkwik.webdatacommons.org/darkscape/resource/polished_moss_giant_bone', 'http://dbkwik.webdatacommons.org/darkscape/resource/fire_giant_(daemonheim)', 'http://dbkwik.webdatacommons.org/darkscape/resource/little_worldbearer']
# ------------
# Difference for tgt_12
# ['http://dbkwik.webdatacommons.org/darkscape/resource/brooch_(the_lost_tribe)', 'http://dbkwik.webdatacommons.org/darkscape/resource/guthixian_moss_giant', 'http://dbkwik.webdatacommons.org/darkscape/resource/lumbridge_and_draynor_tasks', 'http://dbkwik.webdatacommons.org/darkscape/resource/ice_giant']
# ------------
# Difference for tgt_13
# ['http://dbkwik.webdatacommons.org/darkscape/resource/recipe_for_disaster/freeing_pirate_pete/quick_guide', 'http://dbkwik.webdatacommons.org/darkscape/resource/recipe_for_disaster/freeing_the_goblin_generals/quick_guide', 'http://dbkwik.webdatacommons.org/darkscape/resource/blurberry_special', 'http://dbkwik.webdatacommons.org/darkscape/resource/digsite_workman_(senntisten_temple)', 'http://dbkwik.webdatacommons.org/darkscape/resource/digsite_pendant', 'http://dbkwik.webdatacommons.org/darkscape/resource/bathus_bar', 'http://dbkwik.webdatacommons.org/darkscape/resource/vase_(digsite)', 'http://dbkwik.webdatacommons.org/darkscape/resource/blurite_bar', 'http://dbkwik.webdatacommons.org/darkscape/resource/barberry_seed', 'http://dbkwik.webdatacommons.org/darkscape/resource/recipe_for_disaster/freeing_sir_amik_varze/quick_guide', 'http://dbkwik.webdatacommons.org/darkscape/resource/marmaros_bar', 'http://dbkwik.webdatacommons.org/darkscape/resource/mixed_blurberry_special', 'http://dbkwik.webdatacommons.org/darkscape/resource/workman_(digsite)']
# ------------
# Difference for tgt_14
# ['http://dbkwik.webdatacommons.org/darkscape/resource/category:dungeoneering_farming_images', 'http://dbkwik.webdatacommons.org/darkscape/resource/bitternut', 'http://dbkwik.webdatacommons.org/darkscape/resource/rune_arrow', 'http://dbkwik.webdatacommons.org/darkscape/resource/fairy_resistance_hideout', 'http://dbkwik.webdatacommons.org/darkscape/resource/combined_observation:_the_madness_of_friends', 'http://dbkwik.webdatacommons.org/darkscape/resource/category:mines_and_mining_sites', 'http://dbkwik.webdatacommons.org/darkscape/resource/ground_bat_bones', 'http://dbkwik.webdatacommons.org/darkscape/resource/grand_exchange_market_watch/minigames', 'http://dbkwik.webdatacommons.org/darkscape/resource/iorwerth_scout', 'http://dbkwik.webdatacommons.org/darkscape/resource/snotgut']
# ------------
# Difference for tgt_15
# ["http://dbkwik.webdatacommons.org/darkscape/resource/barricade_shop_owner_(seers'_village)", 'http://dbkwik.webdatacommons.org/darkscape/resource/tree_gnome_village', "http://dbkwik.webdatacommons.org/darkscape/resource/seers'_village_tasks"]
# ------------
# Difference for tgt_16
# ['http://dbkwik.webdatacommons.org/darkscape/resource/bronze_gauntlets', 'http://dbkwik.webdatacommons.org/darkscape/property/food', 'http://dbkwik.webdatacommons.org/darkscape/resource/fractite_gauntlets', 'http://dbkwik.webdatacommons.org/darkscape/resource/warrior_gauntlets_(steel)', 'http://dbkwik.webdatacommons.org/darkscape/resource/miner_gauntlets_(steel)', 'http://dbkwik.webdatacommons.org/darkscape/resource/monster_killing']
# ------------
# Difference for tgt_17
# ['http://dbkwik.webdatacommons.org/darkscape/resource/super_prayer', 'http://dbkwik.webdatacommons.org/darkscape/resource/calculator:prayer/drain_rate', 'http://dbkwik.webdatacommons.org/darkscape/resource/lumbridge_and_draynor_tasks/quick_guide', 'http://dbkwik.webdatacommons.org/darkscape/resource/prayer_tutor', 'http://dbkwik.webdatacommons.org/darkscape/resource/dungeoneering/prayer']
# ------------
# Difference for tgt_18
# ['http://dbkwik.webdatacommons.org/darkscape/resource/mysterious_shade', 'http://dbkwik.webdatacommons.org/darkscape/resource/rune_kiteshield_(dorgeshuun)', 'http://dbkwik.webdatacommons.org/darkscape/resource/rune_kiteshield_(horse)', 'http://dbkwik.webdatacommons.org/darkscape/resource/rune_kiteshield_(arrav)', 'http://dbkwik.webdatacommons.org/darkscape/resource/category:priests', 'http://dbkwik.webdatacommons.org/darkscape/resource/kraka', "http://dbkwik.webdatacommons.org/darkscape/resource/shades_of_mort'ton/quick_guide", 'http://dbkwik.webdatacommons.org/darkscape/resource/asyn_shade', 'http://dbkwik.webdatacommons.org/darkscape/resource/cave_nightshade', 'http://dbkwik.webdatacommons.org/darkscape/resource/rune_kiteshield_(saradomin)', 'http://dbkwik.webdatacommons.org/darkscape/resource/shadow_of_the_storm/quick_guide', 'http://dbkwik.webdatacommons.org/darkscape/resource/lord_rologarth', 'http://dbkwik.webdatacommons.org/darkscape/resource/rune_kiteshield_(skull)']
# ------------
# Difference for tgt_19
# ['http://dbkwik.webdatacommons.org/darkscape/resource/swamp_creature', 'http://dbkwik.webdatacommons.org/darkscape/resource/argonite_boots', 'http://dbkwik.webdatacommons.org/darkscape/resource/shadow_diamond']

# %%
out = list()
for header in ['src_'+str(i) for i in range(round((len(df.columns)-12)/2))] + ['tgt_'+str(i) for i in range(round((len(df.columns)-12)/2))]:
    dimlist_x = list()
    dimlist_y = list()
    for header2 in ['src_'+str(i) for i in range(round((len(df.columns)-12)/2))] + ['tgt_'+str(i) for i in range(round((len(df.columns)-12)/2))]:
        if not header2 == header:
            tmp = df.sort_values(by=[header2], ascending=False)
            dimlist_y = dimlist_y + (tmp[:10]['src_id'].tolist() + tmp[-10:]['src_id'].to_list() + tmp[round(len(tmp)/2)-5:round(len(tmp)/2)+5]['src_id'].to_list())
        else:
            tmp = df.sort_values(by=[header2], ascending=False)
            dimlist_x = dimlist_x + (tmp[:10]['src_id'].tolist() + tmp[-10:]['src_id'].to_list() + tmp[round(len(tmp)/2)-5:round(len(tmp)/2)+5]['src_id'].to_list())
    
    o= compute_diff(dimlist_x, dimlist_y, header)
    print("\n".join(list(set(o))))
    #z = set(dimlist_x) - set(dimlist_y)
    #out = list()
    #print("------------")
    #print("Difference for " + header)
    #for val in z:
    #    if dimlist_x.count(val)>0:
    #        out.append(val)
    #print(out)
# Out:
# ------------
# Difference for src_0:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-41-7aeb2e342911> in <module>
#      11             dimlist_x = dimlist_x + (tmp[:10]['src_id'].tolist() + tmp[-10:]['src_id'].to_list() + tmp[round(len(tmp)/2)-5:round(len(tmp)/2)+5]['src_id'].to_list())
#      12
# ---> 13     o= compute_diff(dimlist_x, dimlist_y, header)
#      14     print("\n".join(list(set(o))))
#      15     #z = set(dimlist_x) - set(dimlist_y)
#
# <ipython-input-40-4be5398ffcfd> in compute_diff(id_list_x, id_list_y, headername)
#      38     print("\n------------")
#      39     print('Difference for ' + headername+':')
# ---> 40     d = diff(x3, y3)
#      41     #out = list()
#      42     #for val in d:
#
# <ipython-input-40-4be5398ffcfd> in diff(l1, l2)
#      27
#      28     def diff(l1, l2):
# ---> 29         return [value for value in l1 if not value in l2]
#      30
#      31     x3 = list()
#
# <ipython-input-40-4be5398ffcfd> in <listcomp>(.0)
#      27
#      28     def diff(l1, l2):
# ---> 29         return [value for value in l1 if not value in l2]
#      30
#      31     x3 = list()
#
# KeyboardInterrupt:

# %%
def search(word):
        val = list()
        for x in training_material:
            if word in x:
                print("---")
                print(x)
                yield x

# %%
def countit(x, word):
    return x.loc[word].count()

# %%
x = list()
x.append((1,5))
x.append((1,7))
from operator import itemgetter
def getmax(listoftuples, no):
    return sorted(listoftuples,key=lambda x: x[1], reverse=True)[:no]
getmax(x,10)
# Out:
# [(1, 7), (1, 5)]

# %%
intersect = pd.DataFrame(intersect)
intersect = intersect.set_index(intersect[0])
countit(pd.DataFrame(intersect), "'http://rdata2graph.sap.com/hilti_web/property/categories.id',")
# Out:
# 2529

# %%
intersect.columns=['val']
set([x for x in intersect.sort_values(by=['val'])['val'].tolist() if not 'http' in x])
# Out:
# set()

# %%
# Out:
# <generator object search at 0x0000027440C11150>
